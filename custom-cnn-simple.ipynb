# %%
from pathlib import Path

import json
import random
import time
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

from tensorflow.keras.preprocessing.image import ImageDataGenerator


SEED = 12345
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 35

RUN_NAME = "custom_cnn_clean_split_seed12345"

OUTPUT_DIR = Path("/kaggle/working") / RUN_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)


print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))

print("\nRun:", RUN_NAME)
print("Image size:", IMAGE_SIZE)
print("Batch size:", BATCH_SIZE)
print("Classes:", NUM_CLASSES)
print("Output directory:", OUTPUT_DIR)
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Run: custom_cnn_clean_split_seed12345
# Image size: (128, 128)
# Batch size: 32
# Classes: 35
# Output directory: /kaggle/working/custom_cnn_clean_split_seed12345

# %%
KAGGLE_INPUT = Path("/kaggle/input")


MANIFEST_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_clean_split_manifest.csv")
)

CLASS_NAMES_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_class_names.json")
)

DATASET_ROOT = next(
    path
    for path in KAGGLE_INPUT.rglob("zooplankton_0p5x")
    if path.is_dir()
)


manifest = pd.read_csv(MANIFEST_PATH)

with open(CLASS_NAMES_PATH, "r") as file:
    CLASS_NAMES = json.load(file)


manifest["filepath"] = manifest["relative_filepath"].apply(
    lambda path: str(DATASET_ROOT / path)
)


train_df = (
    manifest[manifest["split"] == "train"]
    .copy()
    .reset_index(drop=True)
)

val_df = (
    manifest[manifest["split"] == "validation"]
    .copy()
    .reset_index(drop=True)
)

test_df = (
    manifest[manifest["split"] == "test"]
    .copy()
    .reset_index(drop=True)
)


print("Manifest:", MANIFEST_PATH)
print("Class names:", CLASS_NAMES_PATH)
print("Dataset root:", DATASET_ROOT)

print("\nTraining:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
print("Classes:", len(CLASS_NAMES))
# Out:
# Manifest: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_clean_split_manifest.csv
# Class names: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_class_names.json
# Dataset root: /kaggle/input/datasets/petroskontos/zoolake-full/zooplankton_0p5x
#
# Training: 12558
# Validation: 2691
# Test: 2691
# Classes: 35

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.20,
    shear_range=10,
)

eval_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED,
)

val_generator = eval_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)


print("\nTraining batches:", len(train_generator))
print("Validation batches:", len(val_generator))
# Out:
# Found 12558 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.
#
# Training batches: 393
# Validation batches: 85

# %%
tf.keras.backend.clear_session()


model = tf.keras.Sequential([
    tf.keras.layers.Input(
        shape=(*IMAGE_SIZE, 3)
    ),

    tf.keras.layers.Conv2D(
        32,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        64,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(
        128,
        activation="relu",
    ),

    tf.keras.layers.Dropout(
        0.5
    ),

    tf.keras.layers.Dense(
        NUM_CLASSES,
        activation="softmax",
    ),
])


model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786705563.495782      23 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 35)             │         4,515 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 263,267 (1.00 MB)
#  Trainable params: 262,563 (1.00 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
LEARNING_RATE = 1e-4
MAX_EPOCHS = 200
EARLY_STOPPING_PATIENCE = 30


BEST_MODEL_PATH = OUTPUT_DIR / "best_custom_cnn.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.csv"


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_MODEL_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        verbose=1,
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.CSVLogger(
        str(HISTORY_PATH)
    ),
]


print("Learning rate:", LEARNING_RATE)
print("Maximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", EARLY_STOPPING_PATIENCE)
print("Total parameters:", model.count_params())
print("Best model:", BEST_MODEL_PATH)
print("History:", HISTORY_PATH)
# Out:
# Learning rate: 0.0001
# Maximum epochs: 200
# Early-stopping patience: 30
# Total parameters: 263267
# Best model: /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# History: /kaggle/working/custom_cnn_clean_split_seed12345/training_history.csv

# %%
train_generator.reset()
val_generator.reset()


training_started = time.time()


history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=MAX_EPOCHS,
    callbacks=callbacks,
    verbose=2,
)


training_seconds = time.time() - training_started
training_hours = training_seconds / 3600


history_df = pd.DataFrame(history.history)

history_df.insert(
    0,
    "epoch",
    np.arange(1, len(history_df) + 1),
)

history_df.to_csv(
    HISTORY_PATH,
    index=False,
)


best_epoch = int(
    history_df.loc[
        history_df["val_loss"].idxmin(),
        "epoch",
    ]
)

best_val_loss = float(
    history_df["val_loss"].min()
)


training_info = {
    "epochs_completed": len(history_df),
    "best_epoch": best_epoch,
    "best_validation_loss": best_val_loss,
    "training_seconds": training_seconds,
    "training_hours": training_hours,
}

with open(
    OUTPUT_DIR / "training_info.json",
    "w",
) as file:
    json.dump(
        training_info,
        file,
        indent=2,
    )


print("\nTraining completed.")
print("Epochs completed:", len(history_df))
print("Best epoch:", best_epoch)
print("Best validation loss:", best_val_loss)
print("Training hours:", training_hours)
# Out:
# Epoch 1/200
# I0000 00:00:1786705573.935324      69 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from None to 3.82088, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 1: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 154s - 392ms/step - accuracy: 0.3145 - loss: 2.6886 - top2_accuracy: 0.4288 - val_accuracy: 0.0613 - val_loss: 3.8209 - val_top2_accuracy: 0.2471
# Epoch 2/200
#
# Epoch 2: val_loss improved from 3.82088 to 1.84433, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 2: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 61s - 154ms/step - accuracy: 0.4635 - loss: 2.0126 - top2_accuracy: 0.6123 - val_accuracy: 0.4679 - val_loss: 1.8443 - val_top2_accuracy: 0.5972
# Epoch 3/200
#
# Epoch 3: val_loss improved from 1.84433 to 1.42329, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 3: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 60s - 152ms/step - accuracy: 0.5380 - loss: 1.7047 - top2_accuracy: 0.6879 - val_accuracy: 0.5749 - val_loss: 1.4233 - val_top2_accuracy: 0.7462
# Epoch 4/200
#
# Epoch 4: val_loss improved from 1.42329 to 1.36235, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 4: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 59s - 151ms/step - accuracy: 0.5866 - loss: 1.5164 - top2_accuracy: 0.7273 - val_accuracy: 0.6321 - val_loss: 1.3624 - val_top2_accuracy: 0.7707
# Epoch 5/200
#
# Epoch 5: val_loss improved from 1.36235 to 1.22825, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 5: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 60s - 153ms/step - accuracy: 0.6301 - loss: 1.3840 - top2_accuracy: 0.7646 - val_accuracy: 0.6492 - val_loss: 1.2283 - val_top2_accuracy: 0.8090
# Epoch 6/200
#
# Epoch 6: val_loss did not improve from 1.22825
# 393/393 - 61s - 154ms/step - accuracy: 0.6573 - loss: 1.2752 - top2_accuracy: 0.7835 - val_accuracy: 0.5128 - val_loss: 1.7675 - val_top2_accuracy: 0.7116
# Epoch 7/200
#
# Epoch 7: val_loss did not improve from 1.22825
# 393/393 - 61s - 155ms/step - accuracy: 0.6752 - loss: 1.1959 - top2_accuracy: 0.8015 - val_accuracy: 0.6039 - val_loss: 1.3769 - val_top2_accuracy: 0.7952
# Epoch 8/200
#
# Epoch 8: val_loss improved from 1.22825 to 0.96449, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 8: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 60s - 151ms/step - accuracy: 0.6946 - loss: 1.1295 - top2_accuracy: 0.8122 - val_accuracy: 0.7131 - val_loss: 0.9645 - val_top2_accuracy: 0.8365
# Epoch 9/200
#
# Epoch 9: val_loss did not improve from 0.96449
# 393/393 - 59s - 151ms/step - accuracy: 0.7086 - loss: 1.0620 - top2_accuracy: 0.8283 - val_accuracy: 0.6626 - val_loss: 1.1475 - val_top2_accuracy: 0.8201
# Epoch 10/200
#
# Epoch 10: val_loss improved from 0.96449 to 0.83904, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 10: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 61s - 155ms/step - accuracy: 0.7227 - loss: 1.0108 - top2_accuracy: 0.8321 - val_accuracy: 0.7651 - val_loss: 0.8390 - val_top2_accuracy: 0.8711
# Epoch 11/200
#
# Epoch 11: val_loss did not improve from 0.83904
# 393/393 - 59s - 151ms/step - accuracy: 0.7335 - loss: 0.9684 - top2_accuracy: 0.8436 - val_accuracy: 0.5700 - val_loss: 1.4837 - val_top2_accuracy: 0.7187
# Epoch 12/200
#
# Epoch 12: val_loss did not improve from 0.83904
# 393/393 - 58s - 148ms/step - accuracy: 0.7406 - loss: 0.9368 - top2_accuracy: 0.8495 - val_accuracy: 0.5652 - val_loss: 1.5278 - val_top2_accuracy: 0.7009
# Epoch 13/200
#
# Epoch 13: val_loss did not improve from 0.83904
# 393/393 - 57s - 146ms/step - accuracy: 0.7543 - loss: 0.8964 - top2_accuracy: 0.8601 - val_accuracy: 0.6485 - val_loss: 1.1630 - val_top2_accuracy: 0.8131
# Epoch 14/200
#
# Epoch 14: val_loss did not improve from 0.83904
# 393/393 - 57s - 146ms/step - accuracy: 0.7636 - loss: 0.8584 - top2_accuracy: 0.8609 - val_accuracy: 0.6555 - val_loss: 1.1499 - val_top2_accuracy: 0.8045
# Epoch 15/200
#
# Epoch 15: val_loss did not improve from 0.83904
# 393/393 - 57s - 145ms/step - accuracy: 0.7625 - loss: 0.8450 - top2_accuracy: 0.8665 - val_accuracy: 0.7391 - val_loss: 0.8432 - val_top2_accuracy: 0.8711
# Epoch 16/200
#
# Epoch 16: val_loss did not improve from 0.83904
# 393/393 - 58s - 148ms/step - accuracy: 0.7721 - loss: 0.8188 - top2_accuracy: 0.8711 - val_accuracy: 0.7243 - val_loss: 0.8764 - val_top2_accuracy: 0.8506
# Epoch 17/200
#
# Epoch 17: val_loss did not improve from 0.83904
# 393/393 - 57s - 146ms/step - accuracy: 0.7807 - loss: 0.7886 - top2_accuracy: 0.8809 - val_accuracy: 0.6596 - val_loss: 1.1974 - val_top2_accuracy: 0.8060
# Epoch 18/200
#
# Epoch 18: val_loss did not improve from 0.83904
# 393/393 - 58s - 146ms/step - accuracy: 0.7862 - loss: 0.7660 - top2_accuracy: 0.8833 - val_accuracy: 0.7414 - val_loss: 0.8581 - val_top2_accuracy: 0.8514
# Epoch 19/200
#
# Epoch 19: val_loss did not improve from 0.83904
# 393/393 - 57s - 146ms/step - accuracy: 0.7891 - loss: 0.7608 - top2_accuracy: 0.8823 - val_accuracy: 0.7105 - val_loss: 0.9716 - val_top2_accuracy: 0.8339
# Epoch 20/200
#
# Epoch 20: val_loss did not improve from 0.83904
# 393/393 - 58s - 148ms/step - accuracy: 0.7942 - loss: 0.7336 - top2_accuracy: 0.8902 - val_accuracy: 0.6971 - val_loss: 1.0485 - val_top2_accuracy: 0.8265
# Epoch 21/200
#
# Epoch 21: val_loss improved from 0.83904 to 0.65588, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 21: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 57s - 145ms/step - accuracy: 0.7970 - loss: 0.7170 - top2_accuracy: 0.8904 - val_accuracy: 0.8053 - val_loss: 0.6559 - val_top2_accuracy: 0.9038
# Epoch 22/200
#
# Epoch 22: val_loss did not improve from 0.65588
# 393/393 - 58s - 148ms/step - accuracy: 0.8023 - loss: 0.7017 - top2_accuracy: 0.8913 - val_accuracy: 0.6076 - val_loss: 1.3675 - val_top2_accuracy: 0.7298
# Epoch 23/200
#
# Epoch 23: val_loss did not improve from 0.65588
# 393/393 - 58s - 148ms/step - accuracy: 0.8047 - loss: 0.6837 - top2_accuracy: 0.8970 - val_accuracy: 0.7637 - val_loss: 0.7776 - val_top2_accuracy: 0.8792
# Epoch 24/200
#
# Epoch 24: val_loss did not improve from 0.65588
# 393/393 - 57s - 146ms/step - accuracy: 0.8122 - loss: 0.6667 - top2_accuracy: 0.9001 - val_accuracy: 0.7131 - val_loss: 0.9485 - val_top2_accuracy: 0.8350
# Epoch 25/200
#
# Epoch 25: val_loss did not improve from 0.65588
# 393/393 - 59s - 150ms/step - accuracy: 0.8100 - loss: 0.6655 - top2_accuracy: 0.9036 - val_accuracy: 0.7284 - val_loss: 0.9078 - val_top2_accuracy: 0.8473
# Epoch 26/200
#
# Epoch 26: val_loss did not improve from 0.65588
# 393/393 - 59s - 150ms/step - accuracy: 0.8150 - loss: 0.6477 - top2_accuracy: 0.9045 - val_accuracy: 0.7250 - val_loss: 0.9131 - val_top2_accuracy: 0.8320
# Epoch 27/200
#
# Epoch 27: val_loss did not improve from 0.65588
# 393/393 - 59s - 151ms/step - accuracy: 0.8187 - loss: 0.6351 - top2_accuracy: 0.9047 - val_accuracy: 0.6436 - val_loss: 1.2095 - val_top2_accuracy: 0.7570
# Epoch 28/200
#
# Epoch 28: val_loss did not improve from 0.65588
# 393/393 - 59s - 149ms/step - accuracy: 0.8168 - loss: 0.6352 - top2_accuracy: 0.9052 - val_accuracy: 0.7023 - val_loss: 0.9854 - val_top2_accuracy: 0.8205
# Epoch 29/200
#
# Epoch 29: val_loss did not improve from 0.65588
# 393/393 - 60s - 152ms/step - accuracy: 0.8211 - loss: 0.6224 - top2_accuracy: 0.9091 - val_accuracy: 0.7637 - val_loss: 0.7524 - val_top2_accuracy: 0.8956
# Epoch 30/200
#
# Epoch 30: val_loss did not improve from 0.65588
# 393/393 - 59s - 151ms/step - accuracy: 0.8266 - loss: 0.6058 - top2_accuracy: 0.9115 - val_accuracy: 0.7949 - val_loss: 0.6853 - val_top2_accuracy: 0.8881
# Epoch 31/200
#
# Epoch 31: val_loss did not improve from 0.65588
# 393/393 - 60s - 153ms/step - accuracy: 0.8294 - loss: 0.5946 - top2_accuracy: 0.9117 - val_accuracy: 0.7533 - val_loss: 0.7595 - val_top2_accuracy: 0.8889
# Epoch 32/200
#
# Epoch 32: val_loss did not improve from 0.65588
# 393/393 - 60s - 152ms/step - accuracy: 0.8290 - loss: 0.5860 - top2_accuracy: 0.9150 - val_accuracy: 0.7540 - val_loss: 0.7831 - val_top2_accuracy: 0.8759
# Epoch 33/200
#
# Epoch 33: val_loss improved from 0.65588 to 0.56383, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 33: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 60s - 152ms/step - accuracy: 0.8351 - loss: 0.5811 - top2_accuracy: 0.9164 - val_accuracy: 0.8201 - val_loss: 0.5638 - val_top2_accuracy: 0.9257
# Epoch 34/200
#
# Epoch 34: val_loss did not improve from 0.56383
# 393/393 - 59s - 151ms/step - accuracy: 0.8348 - loss: 0.5699 - top2_accuracy: 0.9168 - val_accuracy: 0.8109 - val_loss: 0.6213 - val_top2_accuracy: 0.9138
# Epoch 35/200
#
# Epoch 35: val_loss did not improve from 0.56383
# 393/393 - 59s - 150ms/step - accuracy: 0.8380 - loss: 0.5611 - top2_accuracy: 0.9195 - val_accuracy: 0.7611 - val_loss: 0.7748 - val_top2_accuracy: 0.8666
# Epoch 36/200
#
# Epoch 36: val_loss improved from 0.56383 to 0.55720, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 36: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 58s - 149ms/step - accuracy: 0.8417 - loss: 0.5553 - top2_accuracy: 0.9216 - val_accuracy: 0.8328 - val_loss: 0.5572 - val_top2_accuracy: 0.9190
# Epoch 37/200
#
# Epoch 37: val_loss did not improve from 0.55720
# 393/393 - 58s - 149ms/step - accuracy: 0.8443 - loss: 0.5400 - top2_accuracy: 0.9233 - val_accuracy: 0.8131 - val_loss: 0.6367 - val_top2_accuracy: 0.9052
# Epoch 38/200
#
# Epoch 38: val_loss did not improve from 0.55720
# 393/393 - 57s - 145ms/step - accuracy: 0.8411 - loss: 0.5459 - top2_accuracy: 0.9219 - val_accuracy: 0.6971 - val_loss: 1.0715 - val_top2_accuracy: 0.8436
# Epoch 39/200
#
# Epoch 39: val_loss did not improve from 0.55720
# 393/393 - 58s - 148ms/step - accuracy: 0.8477 - loss: 0.5353 - top2_accuracy: 0.9247 - val_accuracy: 0.7473 - val_loss: 0.8043 - val_top2_accuracy: 0.8919
# Epoch 40/200
#
# Epoch 40: val_loss did not improve from 0.55720
# 393/393 - 59s - 151ms/step - accuracy: 0.8492 - loss: 0.5241 - top2_accuracy: 0.9282 - val_accuracy: 0.7488 - val_loss: 0.8152 - val_top2_accuracy: 0.8640
# Epoch 41/200
#
# Epoch 41: val_loss did not improve from 0.55720
# 393/393 - 59s - 149ms/step - accuracy: 0.8471 - loss: 0.5192 - top2_accuracy: 0.9284 - val_accuracy: 0.7250 - val_loss: 0.8636 - val_top2_accuracy: 0.8658
# Epoch 42/200
#
# Epoch 42: val_loss improved from 0.55720 to 0.55346, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 42: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 58s - 148ms/step - accuracy: 0.8477 - loss: 0.5189 - top2_accuracy: 0.9257 - val_accuracy: 0.8250 - val_loss: 0.5535 - val_top2_accuracy: 0.9190
# Epoch 43/200
#
# Epoch 43: val_loss did not improve from 0.55346
# 393/393 - 59s - 149ms/step - accuracy: 0.8509 - loss: 0.5178 - top2_accuracy: 0.9263 - val_accuracy: 0.7436 - val_loss: 0.8408 - val_top2_accuracy: 0.8525
# Epoch 44/200
#
# Epoch 44: val_loss did not improve from 0.55346
# 393/393 - 59s - 151ms/step - accuracy: 0.8577 - loss: 0.4909 - top2_accuracy: 0.9290 - val_accuracy: 0.7116 - val_loss: 0.9598 - val_top2_accuracy: 0.8305
# Epoch 45/200
#
# Epoch 45: val_loss did not improve from 0.55346
# 393/393 - 58s - 147ms/step - accuracy: 0.8550 - loss: 0.4918 - top2_accuracy: 0.9320 - val_accuracy: 0.7480 - val_loss: 0.8671 - val_top2_accuracy: 0.8618
# Epoch 46/200
#
# Epoch 46: val_loss improved from 0.55346 to 0.49454, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 46: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 57s - 146ms/step - accuracy: 0.8578 - loss: 0.4974 - top2_accuracy: 0.9302 - val_accuracy: 0.8506 - val_loss: 0.4945 - val_top2_accuracy: 0.9283
# Epoch 47/200
#
# Epoch 47: val_loss did not improve from 0.49454
# 393/393 - 58s - 147ms/step - accuracy: 0.8604 - loss: 0.4883 - top2_accuracy: 0.9300 - val_accuracy: 0.8042 - val_loss: 0.6401 - val_top2_accuracy: 0.9049
# Epoch 48/200
#
# Epoch 48: val_loss did not improve from 0.49454
# 393/393 - 59s - 150ms/step - accuracy: 0.8579 - loss: 0.4865 - top2_accuracy: 0.9318 - val_accuracy: 0.7603 - val_loss: 0.8461 - val_top2_accuracy: 0.8800
# Epoch 49/200
#
# Epoch 49: val_loss did not improve from 0.49454
# 393/393 - 59s - 149ms/step - accuracy: 0.8615 - loss: 0.4804 - top2_accuracy: 0.9324 - val_accuracy: 0.7729 - val_loss: 0.7893 - val_top2_accuracy: 0.8785
# Epoch 50/200
#
# Epoch 50: val_loss did not improve from 0.49454
# 393/393 - 58s - 148ms/step - accuracy: 0.8622 - loss: 0.4774 - top2_accuracy: 0.9337 - val_accuracy: 0.7168 - val_loss: 0.9625 - val_top2_accuracy: 0.8384
# Epoch 51/200
#
# Epoch 51: val_loss did not improve from 0.49454
# 393/393 - 60s - 153ms/step - accuracy: 0.8640 - loss: 0.4630 - top2_accuracy: 0.9350 - val_accuracy: 0.7666 - val_loss: 0.7556 - val_top2_accuracy: 0.8737
# Epoch 52/200
#
# Epoch 52: val_loss did not improve from 0.49454
# 393/393 - 61s - 155ms/step - accuracy: 0.8633 - loss: 0.4595 - top2_accuracy: 0.9371 - val_accuracy: 0.7837 - val_loss: 0.7196 - val_top2_accuracy: 0.8829
# Epoch 53/200
#
# Epoch 53: val_loss did not improve from 0.49454
# 393/393 - 59s - 150ms/step - accuracy: 0.8661 - loss: 0.4570 - top2_accuracy: 0.9376 - val_accuracy: 0.8357 - val_loss: 0.5098 - val_top2_accuracy: 0.9301
# Epoch 54/200
#
# Epoch 54: val_loss did not improve from 0.49454
# 393/393 - 58s - 147ms/step - accuracy: 0.8640 - loss: 0.4656 - top2_accuracy: 0.9357 - val_accuracy: 0.7923 - val_loss: 0.6544 - val_top2_accuracy: 0.8937
# Epoch 55/200
#
# Epoch 55: val_loss did not improve from 0.49454
# 393/393 - 58s - 148ms/step - accuracy: 0.8645 - loss: 0.4545 - top2_accuracy: 0.9352 - val_accuracy: 0.7755 - val_loss: 0.7548 - val_top2_accuracy: 0.8963
# Epoch 56/200
#
# Epoch 56: val_loss did not improve from 0.49454
# 393/393 - 59s - 150ms/step - accuracy: 0.8697 - loss: 0.4446 - top2_accuracy: 0.9403 - val_accuracy: 0.7778 - val_loss: 0.7450 - val_top2_accuracy: 0.8781
# Epoch 57/200
#
# Epoch 57: val_loss did not improve from 0.49454
# 393/393 - 59s - 151ms/step - accuracy: 0.8634 - loss: 0.4464 - top2_accuracy: 0.9388 - val_accuracy: 0.7860 - val_loss: 0.7852 - val_top2_accuracy: 0.8904
# Epoch 58/200
#
# Epoch 58: val_loss did not improve from 0.49454
# 393/393 - 58s - 148ms/step - accuracy: 0.8696 - loss: 0.4426 - top2_accuracy: 0.9401 - val_accuracy: 0.8153 - val_loss: 0.6404 - val_top2_accuracy: 0.8989
# Epoch 59/200
#
# Epoch 59: val_loss did not improve from 0.49454
# 393/393 - 59s - 151ms/step - accuracy: 0.8675 - loss: 0.4372 - top2_accuracy: 0.9403 - val_accuracy: 0.8406 - val_loss: 0.5328 - val_top2_accuracy: 0.9208
# Epoch 60/200
#
# Epoch 60: val_loss did not improve from 0.49454
# 393/393 - 61s - 156ms/step - accuracy: 0.8685 - loss: 0.4361 - top2_accuracy: 0.9411 - val_accuracy: 0.7473 - val_loss: 0.9199 - val_top2_accuracy: 0.8551
# Epoch 61/200
#
# Epoch 61: val_loss did not improve from 0.49454
# 393/393 - 59s - 149ms/step - accuracy: 0.8693 - loss: 0.4336 - top2_accuracy: 0.9404 - val_accuracy: 0.8012 - val_loss: 0.6474 - val_top2_accuracy: 0.8971
# Epoch 62/200
#
# Epoch 62: val_loss did not improve from 0.49454
# 393/393 - 58s - 146ms/step - accuracy: 0.8712 - loss: 0.4252 - top2_accuracy: 0.9443 - val_accuracy: 0.8060 - val_loss: 0.6338 - val_top2_accuracy: 0.9034
# Epoch 63/200
#
# Epoch 63: val_loss did not improve from 0.49454
# 393/393 - 58s - 147ms/step - accuracy: 0.8735 - loss: 0.4335 - top2_accuracy: 0.9409 - val_accuracy: 0.7120 - val_loss: 0.9720 - val_top2_accuracy: 0.8558
# Epoch 64/200
#
# Epoch 64: val_loss did not improve from 0.49454
# 393/393 - 58s - 147ms/step - accuracy: 0.8705 - loss: 0.4274 - top2_accuracy: 0.9408 - val_accuracy: 0.8008 - val_loss: 0.6665 - val_top2_accuracy: 0.8900
# Epoch 65/200
#
# Epoch 65: val_loss did not improve from 0.49454
# 393/393 - 58s - 147ms/step - accuracy: 0.8735 - loss: 0.4196 - top2_accuracy: 0.9429 - val_accuracy: 0.8224 - val_loss: 0.5762 - val_top2_accuracy: 0.9112
# Epoch 66/200
#
# Epoch 66: val_loss did not improve from 0.49454
# 393/393 - 57s - 145ms/step - accuracy: 0.8754 - loss: 0.4165 - top2_accuracy: 0.9420 - val_accuracy: 0.8183 - val_loss: 0.6219 - val_top2_accuracy: 0.9108
# Epoch 67/200
#
# Epoch 67: val_loss improved from 0.49454 to 0.45356, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 67: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 57s - 146ms/step - accuracy: 0.8786 - loss: 0.4100 - top2_accuracy: 0.9471 - val_accuracy: 0.8662 - val_loss: 0.4536 - val_top2_accuracy: 0.9394
# Epoch 68/200
#
# Epoch 68: val_loss did not improve from 0.45356
# 393/393 - 58s - 148ms/step - accuracy: 0.8791 - loss: 0.4098 - top2_accuracy: 0.9459 - val_accuracy: 0.8097 - val_loss: 0.6124 - val_top2_accuracy: 0.9038
# Epoch 69/200
#
# Epoch 69: val_loss did not improve from 0.45356
# 393/393 - 58s - 148ms/step - accuracy: 0.8805 - loss: 0.4049 - top2_accuracy: 0.9447 - val_accuracy: 0.7993 - val_loss: 0.6495 - val_top2_accuracy: 0.9034
# Epoch 70/200
#
# Epoch 70: val_loss did not improve from 0.45356
# 393/393 - 59s - 149ms/step - accuracy: 0.8803 - loss: 0.3993 - top2_accuracy: 0.9486 - val_accuracy: 0.8480 - val_loss: 0.4931 - val_top2_accuracy: 0.9402
# Epoch 71/200
#
# Epoch 71: val_loss improved from 0.45356 to 0.44721, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 71: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 59s - 150ms/step - accuracy: 0.8811 - loss: 0.4045 - top2_accuracy: 0.9420 - val_accuracy: 0.8584 - val_loss: 0.4472 - val_top2_accuracy: 0.9405
# Epoch 72/200
#
# Epoch 72: val_loss improved from 0.44721 to 0.44029, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 72: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 58s - 148ms/step - accuracy: 0.8778 - loss: 0.4012 - top2_accuracy: 0.9465 - val_accuracy: 0.8647 - val_loss: 0.4403 - val_top2_accuracy: 0.9443
# Epoch 73/200
#
# Epoch 73: val_loss did not improve from 0.44029
# 393/393 - 57s - 144ms/step - accuracy: 0.8820 - loss: 0.3958 - top2_accuracy: 0.9466 - val_accuracy: 0.8220 - val_loss: 0.5819 - val_top2_accuracy: 0.9186
# Epoch 74/200
#
# Epoch 74: val_loss did not improve from 0.44029
# 393/393 - 57s - 145ms/step - accuracy: 0.8804 - loss: 0.4014 - top2_accuracy: 0.9498 - val_accuracy: 0.8484 - val_loss: 0.5192 - val_top2_accuracy: 0.9216
# Epoch 75/200
#
# Epoch 75: val_loss did not improve from 0.44029
# 393/393 - 57s - 145ms/step - accuracy: 0.8825 - loss: 0.3931 - top2_accuracy: 0.9480 - val_accuracy: 0.7729 - val_loss: 0.7831 - val_top2_accuracy: 0.8621
# Epoch 76/200
#
# Epoch 76: val_loss did not improve from 0.44029
# 393/393 - 56s - 143ms/step - accuracy: 0.8829 - loss: 0.3927 - top2_accuracy: 0.9457 - val_accuracy: 0.7763 - val_loss: 0.7480 - val_top2_accuracy: 0.8785
# Epoch 77/200
#
# Epoch 77: val_loss improved from 0.44029 to 0.39878, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 77: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 58s - 147ms/step - accuracy: 0.8826 - loss: 0.3902 - top2_accuracy: 0.9486 - val_accuracy: 0.8826 - val_loss: 0.3988 - val_top2_accuracy: 0.9528
# Epoch 78/200
#
# Epoch 78: val_loss did not improve from 0.39878
# 393/393 - 56s - 142ms/step - accuracy: 0.8836 - loss: 0.3894 - top2_accuracy: 0.9488 - val_accuracy: 0.7715 - val_loss: 0.7659 - val_top2_accuracy: 0.8699
# Epoch 79/200
#
# Epoch 79: val_loss did not improve from 0.39878
# 393/393 - 57s - 145ms/step - accuracy: 0.8821 - loss: 0.3881 - top2_accuracy: 0.9473 - val_accuracy: 0.8462 - val_loss: 0.4975 - val_top2_accuracy: 0.9324
# Epoch 80/200
#
# Epoch 80: val_loss did not improve from 0.39878
# 393/393 - 57s - 145ms/step - accuracy: 0.8860 - loss: 0.3829 - top2_accuracy: 0.9472 - val_accuracy: 0.8279 - val_loss: 0.5509 - val_top2_accuracy: 0.9134
# Epoch 81/200
#
# Epoch 81: val_loss did not improve from 0.39878
# 393/393 - 57s - 146ms/step - accuracy: 0.8859 - loss: 0.3746 - top2_accuracy: 0.9500 - val_accuracy: 0.8540 - val_loss: 0.4668 - val_top2_accuracy: 0.9342
# Epoch 82/200
#
# Epoch 82: val_loss did not improve from 0.39878
# 393/393 - 59s - 149ms/step - accuracy: 0.8877 - loss: 0.3821 - top2_accuracy: 0.9494 - val_accuracy: 0.8305 - val_loss: 0.5276 - val_top2_accuracy: 0.9242
# Epoch 83/200
#
# Epoch 83: val_loss did not improve from 0.39878
# 393/393 - 57s - 144ms/step - accuracy: 0.8849 - loss: 0.3780 - top2_accuracy: 0.9488 - val_accuracy: 0.8469 - val_loss: 0.5030 - val_top2_accuracy: 0.9324
# Epoch 84/200
#
# Epoch 84: val_loss did not improve from 0.39878
# 393/393 - 57s - 146ms/step - accuracy: 0.8853 - loss: 0.3786 - top2_accuracy: 0.9511 - val_accuracy: 0.8343 - val_loss: 0.5249 - val_top2_accuracy: 0.9272
# Epoch 85/200
#
# Epoch 85: val_loss did not improve from 0.39878
# 393/393 - 57s - 144ms/step - accuracy: 0.8892 - loss: 0.3705 - top2_accuracy: 0.9498 - val_accuracy: 0.8495 - val_loss: 0.5118 - val_top2_accuracy: 0.9272
# Epoch 86/200
#
# Epoch 86: val_loss did not improve from 0.39878
# 393/393 - 58s - 147ms/step - accuracy: 0.8853 - loss: 0.3758 - top2_accuracy: 0.9498 - val_accuracy: 0.7354 - val_loss: 0.8711 - val_top2_accuracy: 0.8484
# Epoch 87/200
#
# Epoch 87: val_loss did not improve from 0.39878
# 393/393 - 57s - 145ms/step - accuracy: 0.8900 - loss: 0.3611 - top2_accuracy: 0.9539 - val_accuracy: 0.8584 - val_loss: 0.4482 - val_top2_accuracy: 0.9394
# Epoch 88/200
#
# Epoch 88: val_loss did not improve from 0.39878
# 393/393 - 56s - 142ms/step - accuracy: 0.8911 - loss: 0.3643 - top2_accuracy: 0.9528 - val_accuracy: 0.8320 - val_loss: 0.5394 - val_top2_accuracy: 0.9301
# Epoch 89/200
#
# Epoch 89: val_loss did not improve from 0.39878
# 393/393 - 56s - 144ms/step - accuracy: 0.8907 - loss: 0.3633 - top2_accuracy: 0.9515 - val_accuracy: 0.7599 - val_loss: 0.8478 - val_top2_accuracy: 0.8629
# Epoch 90/200
#
# Epoch 90: val_loss did not improve from 0.39878
# 393/393 - 56s - 144ms/step - accuracy: 0.8902 - loss: 0.3555 - top2_accuracy: 0.9537 - val_accuracy: 0.7696 - val_loss: 0.7248 - val_top2_accuracy: 0.8829
# Epoch 91/200
#
# Epoch 91: val_loss did not improve from 0.39878
# 393/393 - 59s - 150ms/step - accuracy: 0.8920 - loss: 0.3560 - top2_accuracy: 0.9557 - val_accuracy: 0.8235 - val_loss: 0.5727 - val_top2_accuracy: 0.9231
# Epoch 92/200
#
# Epoch 92: val_loss did not improve from 0.39878
# 393/393 - 58s - 147ms/step - accuracy: 0.8899 - loss: 0.3562 - top2_accuracy: 0.9557 - val_accuracy: 0.7696 - val_loss: 0.7487 - val_top2_accuracy: 0.8822
# Epoch 93/200
#
# Epoch 93: val_loss did not improve from 0.39878
# 393/393 - 57s - 145ms/step - accuracy: 0.8919 - loss: 0.3603 - top2_accuracy: 0.9526 - val_accuracy: 0.8540 - val_loss: 0.4913 - val_top2_accuracy: 0.9391
# Epoch 94/200
#
# Epoch 94: val_loss improved from 0.39878 to 0.35588, saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
#
# Epoch 94: finished saving model to /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# 393/393 - 58s - 147ms/step - accuracy: 0.8918 - loss: 0.3565 - top2_accuracy: 0.9528 - val_accuracy: 0.8911 - val_loss: 0.3559 - val_top2_accuracy: 0.9550
# Epoch 95/200
#
# Epoch 95: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.8923 - loss: 0.3545 - top2_accuracy: 0.9546 - val_accuracy: 0.8577 - val_loss: 0.4549 - val_top2_accuracy: 0.9398
# Epoch 96/200
#
# Epoch 96: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.8926 - loss: 0.3486 - top2_accuracy: 0.9540 - val_accuracy: 0.7146 - val_loss: 1.0830 - val_top2_accuracy: 0.8476
# Epoch 97/200
#
# Epoch 97: val_loss did not improve from 0.35588
# 393/393 - 56s - 144ms/step - accuracy: 0.8912 - loss: 0.3519 - top2_accuracy: 0.9524 - val_accuracy: 0.7570 - val_loss: 0.8472 - val_top2_accuracy: 0.8636
# Epoch 98/200
#
# Epoch 98: val_loss did not improve from 0.35588
# 393/393 - 57s - 146ms/step - accuracy: 0.8931 - loss: 0.3490 - top2_accuracy: 0.9522 - val_accuracy: 0.6878 - val_loss: 1.1332 - val_top2_accuracy: 0.7945
# Epoch 99/200
#
# Epoch 99: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.8958 - loss: 0.3458 - top2_accuracy: 0.9540 - val_accuracy: 0.8339 - val_loss: 0.5489 - val_top2_accuracy: 0.9246
# Epoch 100/200
#
# Epoch 100: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.8927 - loss: 0.3491 - top2_accuracy: 0.9544 - val_accuracy: 0.8800 - val_loss: 0.3854 - val_top2_accuracy: 0.9524
# Epoch 101/200
#
# Epoch 101: val_loss did not improve from 0.35588
# 393/393 - 57s - 144ms/step - accuracy: 0.8986 - loss: 0.3360 - top2_accuracy: 0.9574 - val_accuracy: 0.7826 - val_loss: 0.8167 - val_top2_accuracy: 0.8703
# Epoch 102/200
#
# Epoch 102: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.8990 - loss: 0.3365 - top2_accuracy: 0.9569 - val_accuracy: 0.7752 - val_loss: 0.7822 - val_top2_accuracy: 0.8718
# Epoch 103/200
#
# Epoch 103: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.8939 - loss: 0.3408 - top2_accuracy: 0.9541 - val_accuracy: 0.8725 - val_loss: 0.4056 - val_top2_accuracy: 0.9472
# Epoch 104/200
#
# Epoch 104: val_loss did not improve from 0.35588
# 393/393 - 56s - 144ms/step - accuracy: 0.8970 - loss: 0.3427 - top2_accuracy: 0.9553 - val_accuracy: 0.7770 - val_loss: 0.8112 - val_top2_accuracy: 0.8733
# Epoch 105/200
#
# Epoch 105: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.8984 - loss: 0.3346 - top2_accuracy: 0.9568 - val_accuracy: 0.8116 - val_loss: 0.7243 - val_top2_accuracy: 0.9064
# Epoch 106/200
#
# Epoch 106: val_loss did not improve from 0.35588
# 393/393 - 57s - 144ms/step - accuracy: 0.8963 - loss: 0.3413 - top2_accuracy: 0.9556 - val_accuracy: 0.7886 - val_loss: 0.7288 - val_top2_accuracy: 0.8937
# Epoch 107/200
#
# Epoch 107: val_loss did not improve from 0.35588
# 393/393 - 57s - 144ms/step - accuracy: 0.8974 - loss: 0.3301 - top2_accuracy: 0.9576 - val_accuracy: 0.8510 - val_loss: 0.4894 - val_top2_accuracy: 0.9335
# Epoch 108/200
#
# Epoch 108: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.8995 - loss: 0.3320 - top2_accuracy: 0.9546 - val_accuracy: 0.8677 - val_loss: 0.4364 - val_top2_accuracy: 0.9428
# Epoch 109/200
#
# Epoch 109: val_loss did not improve from 0.35588
# 393/393 - 56s - 144ms/step - accuracy: 0.8994 - loss: 0.3334 - top2_accuracy: 0.9572 - val_accuracy: 0.7648 - val_loss: 0.7706 - val_top2_accuracy: 0.8740
# Epoch 110/200
#
# Epoch 110: val_loss did not improve from 0.35588
# 393/393 - 56s - 142ms/step - accuracy: 0.8989 - loss: 0.3357 - top2_accuracy: 0.9570 - val_accuracy: 0.8618 - val_loss: 0.4551 - val_top2_accuracy: 0.9357
# Epoch 111/200
#
# Epoch 111: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9013 - loss: 0.3309 - top2_accuracy: 0.9585 - val_accuracy: 0.8562 - val_loss: 0.4825 - val_top2_accuracy: 0.9320
# Epoch 112/200
#
# Epoch 112: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9001 - loss: 0.3302 - top2_accuracy: 0.9565 - val_accuracy: 0.8703 - val_loss: 0.4172 - val_top2_accuracy: 0.9472
# Epoch 113/200
#
# Epoch 113: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.9018 - loss: 0.3237 - top2_accuracy: 0.9588 - val_accuracy: 0.8406 - val_loss: 0.5021 - val_top2_accuracy: 0.9279
# Epoch 114/200
#
# Epoch 114: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9013 - loss: 0.3175 - top2_accuracy: 0.9615 - val_accuracy: 0.8183 - val_loss: 0.5947 - val_top2_accuracy: 0.9086
# Epoch 115/200
#
# Epoch 115: val_loss did not improve from 0.35588
# 393/393 - 56s - 142ms/step - accuracy: 0.9006 - loss: 0.3250 - top2_accuracy: 0.9581 - val_accuracy: 0.8569 - val_loss: 0.4486 - val_top2_accuracy: 0.9394
# Epoch 116/200
#
# Epoch 116: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.9026 - loss: 0.3223 - top2_accuracy: 0.9582 - val_accuracy: 0.8317 - val_loss: 0.5350 - val_top2_accuracy: 0.9227
# Epoch 117/200
#
# Epoch 117: val_loss did not improve from 0.35588
# 393/393 - 58s - 146ms/step - accuracy: 0.9043 - loss: 0.3200 - top2_accuracy: 0.9590 - val_accuracy: 0.8707 - val_loss: 0.4511 - val_top2_accuracy: 0.9402
# Epoch 118/200
#
# Epoch 118: val_loss did not improve from 0.35588
# 393/393 - 59s - 150ms/step - accuracy: 0.9007 - loss: 0.3225 - top2_accuracy: 0.9573 - val_accuracy: 0.8696 - val_loss: 0.4348 - val_top2_accuracy: 0.9431
# Epoch 119/200
#
# Epoch 119: val_loss did not improve from 0.35588
# 393/393 - 57s - 145ms/step - accuracy: 0.9014 - loss: 0.3164 - top2_accuracy: 0.9596 - val_accuracy: 0.8123 - val_loss: 0.6348 - val_top2_accuracy: 0.9052
# Epoch 120/200
#
# Epoch 120: val_loss did not improve from 0.35588
# 393/393 - 56s - 144ms/step - accuracy: 0.9032 - loss: 0.3175 - top2_accuracy: 0.9609 - val_accuracy: 0.8759 - val_loss: 0.4102 - val_top2_accuracy: 0.9547
# Epoch 121/200
#
# Epoch 121: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9050 - loss: 0.3139 - top2_accuracy: 0.9601 - val_accuracy: 0.8889 - val_loss: 0.3691 - val_top2_accuracy: 0.9554
# Epoch 122/200
#
# Epoch 122: val_loss did not improve from 0.35588
# 393/393 - 56s - 144ms/step - accuracy: 0.9020 - loss: 0.3163 - top2_accuracy: 0.9588 - val_accuracy: 0.8514 - val_loss: 0.5029 - val_top2_accuracy: 0.9335
# Epoch 123/200
#
# Epoch 123: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9016 - loss: 0.3115 - top2_accuracy: 0.9601 - val_accuracy: 0.8220 - val_loss: 0.5836 - val_top2_accuracy: 0.9127
# Epoch 124/200
#
# Epoch 124: val_loss did not improve from 0.35588
# 393/393 - 56s - 143ms/step - accuracy: 0.9063 - loss: 0.3085 - top2_accuracy: 0.9612 - val_accuracy: 0.8172 - val_loss: 0.5774 - val_top2_accuracy: 0.9212
# Epoch 124: early stopping
# Restoring model weights from the end of the best epoch: 94.
#
# Training completed.
# Epochs completed: 124
# Best epoch: 94
# Best validation loss: 0.35588476061820984
# Training hours: 2.0208082562685012

# %%
LEARNING_RATE = 1e-4
MAX_EPOCHS = 200
EARLY_STOPPING_PATIENCE = 30


BEST_MODEL_PATH = OUTPUT_DIR / "best_custom_cnn.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.csv"


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_MODEL_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        verbose=1,
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.CSVLogger(
        str(HISTORY_PATH)
    ),
]


print("Learning rate:", LEARNING_RATE)
print("Maximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", EARLY_STOPPING_PATIENCE)
print("Total parameters:", model.count_params())
print("Best model:", BEST_MODEL_PATH)
print("History:", HISTORY_PATH)
# Out:
# Learning rate: 0.0001
# Maximum epochs: 200
# Early-stopping patience: 30
# Total parameters: 263267
# Best model: /kaggle/working/custom_cnn_clean_split_seed12345/best_custom_cnn.keras
# History: /kaggle/working/custom_cnn_clean_split_seed12345/training_history.csv

# %%
best_model = tf.keras.models.load_model(
    BEST_MODEL_PATH,
    compile=False,
)


test_generator = eval_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)


test_generator.reset()

y_prob = best_model.predict(
    test_generator,
    verbose=1,
)


y_true = np.asarray(
    test_generator.classes,
    dtype=np.int64,
)

y_pred = np.argmax(
    y_prob,
    axis=1,
)


test_loss = float(
    -np.mean(
        np.log(
            np.clip(
                y_prob[
                    np.arange(len(y_true)),
                    y_true,
                ],
                1e-7,
                1.0,
            )
        )
    )
)

test_accuracy = float(
    accuracy_score(
        y_true,
        y_pred,
    )
)

macro_precision = float(
    precision_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_recall = float(
    recall_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_f1 = float(
    f1_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

top2_predictions = np.argsort(
    y_prob,
    axis=1,
)[:, -2:]

top2_accuracy = float(
    np.mean(
        np.any(
            top2_predictions == y_true[:, None],
            axis=1,
        )
    )
)


metrics = {
    "model": "Custom CNN",
    "split": "test",
    "samples": len(y_true),
    "loss": test_loss,
    "accuracy": test_accuracy,
    "macro_precision": macro_precision,
    "macro_recall": macro_recall,
    "macro_f1": macro_f1,
    "top2_accuracy": top2_accuracy,
    "best_epoch": best_epoch,
    "seed": SEED,
}


with open(
    OUTPUT_DIR / "test_metrics.json",
    "w",
) as file:
    json.dump(
        metrics,
        file,
        indent=2,
    )


print("\nTEST RESULTS")

for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# Found 2691 validated image filenames belonging to 35 classes.
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 18s 206ms/step
#
# TEST RESULTS
# model: Custom CNN
# split: test
# samples: 2691
# loss: 0.3229752779006958
# accuracy: 0.903010033444816
# macro_precision: 0.7377183429785933
# macro_recall: 0.6761538646159686
# macro_f1: 0.6912671418138664
# top2_accuracy: 0.9617242660720922
# best_epoch: 94
# seed: 12345

# %%
classification_results = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=CLASS_NAMES,
    output_dict=True,
    zero_division=0,
)


classification_df = (
    pd.DataFrame(classification_results)
    .transpose()
)

classification_df.to_csv(
    OUTPUT_DIR / "classification_report.csv"
)


predictions_df = pd.DataFrame({
    "image_name": [
        Path(path).name
        for path in test_generator.filepaths
    ],
    "true_class": [
        CLASS_NAMES[index]
        for index in y_true
    ],
    "predicted_class": [
        CLASS_NAMES[index]
        for index in y_pred
    ],
    "confidence": np.max(
        y_prob,
        axis=1,
    ),
    "correct": y_true == y_pred,
})


predictions_df.to_csv(
    OUTPUT_DIR / "test_predictions.csv",
    index=False,
)


np.savez_compressed(
    OUTPUT_DIR / "predictions.npz",
    y_true=y_true,
    y_pred=y_pred,
    y_prob=y_prob.astype(np.float32),
    class_names=np.asarray(CLASS_NAMES),
    image_names=np.asarray(
        [
            Path(path).name
            for path in test_generator.filepaths
        ]
    ),
)


print("Classification report saved.")
print("Test predictions saved.")
print("Prediction arrays saved.")
# Out:
# Classification report saved.
# Test predictions saved.
# Prediction arrays saved.

# %%
cm = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
)


cm_normalized = (
    cm.astype(float)
    / np.maximum(
        cm.sum(axis=1, keepdims=True),
        1,
    )
)


support = cm.sum(axis=1)

sort_order = np.argsort(
    support
)[::-1]


cm_sorted = cm[
    sort_order
][:, sort_order]

cm_normalized_sorted = cm_normalized[
    sort_order
][:, sort_order]


class_names_sorted = [
    CLASS_NAMES[index]
    for index in sort_order
]

support_sorted = support[
    sort_order
]


class_labels_with_support = [
    f"{name} ({int(class_support)})"
    for name, class_support in zip(
        class_names_sorted,
        support_sorted,
    )
]


pd.DataFrame(
    cm_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_counts.csv"
)


pd.DataFrame(
    cm_normalized_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_normalized.csv"
)


figure_size = max(
    12,
    0.38 * NUM_CLASSES,
)

plt.figure(
    figsize=(
        figure_size,
        figure_size,
    )
)


image = plt.imshow(
    cm_normalized_sorted,
    interpolation="nearest",
    cmap="Blues",
    vmin=0,
    vmax=1,
)


plt.colorbar(
    image,
    fraction=0.046,
    pad=0.04,
    label="Normalized count",
)


tick_positions = np.arange(
    NUM_CLASSES
)


plt.xticks(
    tick_positions,
    class_names_sorted,
    rotation=90,
    fontsize=7,
)

plt.yticks(
    tick_positions,
    class_labels_with_support,
    fontsize=7,
)


plt.title(
    "Custom CNN - Normalized Confusion Matrix"
)

plt.xlabel(
    "Predicted class"
)

plt.ylabel(
    "True class"
)


for row in range(NUM_CLASSES):
    for column in range(NUM_CLASSES):

        value = cm_normalized_sorted[
            row,
            column,
        ]

        if row == column or value >= 0.05:

            text_color = (
                "white"
                if value >= 0.50
                else "black"
            )

            plt.text(
                column,
                row,
                f"{value:.2f}",
                ha="center",
                va="center",
                color=text_color,
                fontsize=5,
            )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "confusion_matrix_normalized.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
per_class_df = (
    classification_df
    .loc[CLASS_NAMES]
    .reset_index()
    .rename(
        columns={
            "index": "class",
            "f1-score": "f1_score",
        }
    )
)


per_class_df = per_class_df.sort_values(
    "support",
    ascending=False,
)


per_class_df.to_csv(
    OUTPUT_DIR / "per_class_metrics.csv",
    index=False,
)


per_class_df["class_with_support"] = (
    per_class_df.apply(
        lambda row: (
            f"{row['class']} "
            f"({int(row['support'])})"
        ),
        axis=1,
    )
)


heatmap_data = per_class_df.set_index(
    "class_with_support"
)[
    [
        "precision",
        "recall",
        "f1_score",
    ]
]


figure_height = max(
    8,
    0.35 * len(heatmap_data),
)


plt.figure(
    figsize=(
        8,
        figure_height,
    )
)


image = plt.imshow(
    heatmap_data.values,
    aspect="auto",
    vmin=0,
    vmax=1,
    cmap="RdBu",
)


plt.colorbar(
    image,
    label="Score",
)


plt.xticks(
    np.arange(3),
    [
        "Precision",
        "Recall",
        "F1-score",
    ],
)


plt.yticks(
    np.arange(
        len(heatmap_data)
    ),
    heatmap_data.index,
)


plt.title(
    "Custom CNN - Per-Class Metrics"
)

plt.xlabel(
    "Metric"
)

plt.ylabel(
    "Class"
)


for row in range(
    len(heatmap_data)
):
    for column in range(3):

        value = heatmap_data.values[
            row,
            column,
        ]

        text_color = (
            "white"
            if value >= 0.75
            else "black"
        )

        plt.text(
            column,
            row,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontsize=8,
        )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "per_class_metrics.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
run_config = {
    "run_name": RUN_NAME,
    "model": "Custom CNN",
    "training_type": "from scratch",
    "seed": SEED,
    "image_size": list(IMAGE_SIZE),
    "batch_size": BATCH_SIZE,
    "classes": NUM_CLASSES,
    "train_samples": len(train_df),
    "validation_samples": len(val_df),
    "test_samples": len(test_df),
    "learning_rate": LEARNING_RATE,
    "maximum_epochs": MAX_EPOCHS,
    "early_stopping_patience": EARLY_STOPPING_PATIENCE,
    "checkpoint_monitor": "val_loss",
    "loss": "categorical_crossentropy",
    "sampling": "natural",
    "class_weights": None,
    "augmentation": {
        "rotation_range": 180,
        "horizontal_flip": True,
        "vertical_flip": True,
        "zoom_range": 0.20,
        "shear_range": 10,
    },
}


with open(
    OUTPUT_DIR / "run_config.json",
    "w",
) as file:
    json.dump(
        run_config,
        file,
        indent=2,
    )


pd.DataFrame(
    [metrics]
).to_csv(
    OUTPUT_DIR / "summary_metrics.csv",
    index=False,
)


with open(
    OUTPUT_DIR / "model_summary.txt",
    "w",
) as file:

    best_model.summary(
        print_fn=lambda line: file.write(
            line + "\n"
        )
    )


ARCHIVE_PATH = (
    Path("/kaggle/working")
    / f"{RUN_NAME}_results.zip"
)


with zipfile.ZipFile(
    ARCHIVE_PATH,
    "w",
    compression=zipfile.ZIP_DEFLATED,
) as archive:

    for path in sorted(
        OUTPUT_DIR.rglob("*")
    ):
        if path.is_file():

            archive.write(
                path,
                arcname=path.relative_to(
                    OUTPUT_DIR
                ),
            )


print("Final results archive:")
print(ARCHIVE_PATH)

print("\nFiles included:")

for path in sorted(
    OUTPUT_DIR.rglob("*")
):
    if path.is_file():
        print(" -", path.name)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final results archive:
# /kaggle/working/custom_cnn_clean_split_seed12345_results.zip
#
# Files included:
#  - best_custom_cnn.keras
#  - classification_report.csv
#  - confusion_matrix_counts.csv
#  - confusion_matrix_normalized.csv
#  - confusion_matrix_normalized.png
#  - model_summary.txt
#  - per_class_metrics.csv
#  - per_class_metrics.png
#  - predictions.npz
#  - run_config.json
#  - summary_metrics.csv
#  - test_metrics.json
#  - test_predictions.csv
#  - training_history.csv
#  - training_info.json
