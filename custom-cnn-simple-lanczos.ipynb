# %%
from pathlib import Path

import json
import random
import time
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

from tensorflow.keras.preprocessing.image import ImageDataGenerator


SEED = 12345
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 35

RUN_NAME = "custom_cnn_clean_split_lanczos_seed12345"

OUTPUT_DIR = Path("/kaggle/working") / RUN_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)


print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))

print("\nRun:", RUN_NAME)
print("Image size:", IMAGE_SIZE)
print("Batch size:", BATCH_SIZE)
print("Classes:", NUM_CLASSES)
print("Output directory:", OUTPUT_DIR)
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Run: custom_cnn_clean_split_lanczos_seed12345
# Image size: (128, 128)
# Batch size: 32
# Classes: 35
# Output directory: /kaggle/working/custom_cnn_clean_split_lanczos_seed12345

# %%
KAGGLE_INPUT = Path("/kaggle/input")


MANIFEST_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_clean_split_manifest.csv")
)

CLASS_NAMES_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_class_names.json")
)

DATASET_ROOT = next(
    path
    for path in KAGGLE_INPUT.rglob("zooplankton_0p5x")
    if path.is_dir()
)


manifest = pd.read_csv(MANIFEST_PATH)

with open(CLASS_NAMES_PATH, "r") as file:
    CLASS_NAMES = json.load(file)


manifest["filepath"] = manifest["relative_filepath"].apply(
    lambda path: str(DATASET_ROOT / path)
)


train_df = (
    manifest[manifest["split"] == "train"]
    .copy()
    .reset_index(drop=True)
)

val_df = (
    manifest[manifest["split"] == "validation"]
    .copy()
    .reset_index(drop=True)
)

test_df = (
    manifest[manifest["split"] == "test"]
    .copy()
    .reset_index(drop=True)
)


print("Manifest:", MANIFEST_PATH)
print("Class names:", CLASS_NAMES_PATH)
print("Dataset root:", DATASET_ROOT)

print("\nTraining:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
print("Classes:", len(CLASS_NAMES))
# Out:
# Manifest: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_clean_split_manifest.csv
# Class names: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_class_names.json
# Dataset root: /kaggle/input/datasets/petroskontos/zoolake-full/zooplankton_0p5x
#
# Training: 12558
# Validation: 2691
# Test: 2691
# Classes: 35

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.20,
    shear_range=10,
)

eval_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED,
    interpolation="lanczos",
)

val_generator = eval_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)


print("\nTraining batches:", len(train_generator))
print("Validation batches:", len(val_generator))
# Out:
# Found 12558 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.
#
# Training batches: 393
# Validation batches: 85

# %%
tf.keras.backend.clear_session()


model = tf.keras.Sequential([
    tf.keras.layers.Input(
        shape=(*IMAGE_SIZE, 3)
    ),

    tf.keras.layers.Conv2D(
        32,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        64,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(
        128,
        activation="relu",
    ),

    tf.keras.layers.Dropout(
        0.5
    ),

    tf.keras.layers.Dense(
        NUM_CLASSES,
        activation="softmax",
    ),
])


model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787225061.675292      23 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 35)             │         4,515 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 263,267 (1.00 MB)
#  Trainable params: 262,563 (1.00 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
LEARNING_RATE = 1e-4
MAX_EPOCHS = 200
EARLY_STOPPING_PATIENCE = 30


BEST_MODEL_PATH = OUTPUT_DIR / "best_custom_cnn.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.csv"


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_MODEL_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        verbose=1,
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.CSVLogger(
        str(HISTORY_PATH)
    ),
]


print("Learning rate:", LEARNING_RATE)
print("Maximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", EARLY_STOPPING_PATIENCE)
print("Total parameters:", model.count_params())
print("Best model:", BEST_MODEL_PATH)
print("History:", HISTORY_PATH)
# Out:
# Learning rate: 0.0001
# Maximum epochs: 200
# Early-stopping patience: 30
# Total parameters: 263267
# Best model: /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# History: /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/training_history.csv

# %%
train_generator.reset()
val_generator.reset()


training_started = time.time()


history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=MAX_EPOCHS,
    callbacks=callbacks,
    verbose=2,
)


training_seconds = time.time() - training_started
training_hours = training_seconds / 3600


history_df = pd.DataFrame(history.history)

history_df.insert(
    0,
    "epoch",
    np.arange(1, len(history_df) + 1),
)

history_df.to_csv(
    HISTORY_PATH,
    index=False,
)


best_epoch = int(
    history_df.loc[
        history_df["val_loss"].idxmin(),
        "epoch",
    ]
)

best_val_loss = float(
    history_df["val_loss"].min()
)


training_info = {
    "epochs_completed": len(history_df),
    "best_epoch": best_epoch,
    "best_validation_loss": best_val_loss,
    "training_seconds": training_seconds,
    "training_hours": training_hours,
}

with open(
    OUTPUT_DIR / "training_info.json",
    "w",
) as file:
    json.dump(
        training_info,
        file,
        indent=2,
    )


print("\nTraining completed.")
print("Epochs completed:", len(history_df))
print("Best epoch:", best_epoch)
print("Best validation loss:", best_val_loss)
print("Training hours:", training_hours)
# Out:
# Epoch 1/200
# I0000 00:00:1787225072.042556      69 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from None to 4.93185, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 1: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 136s - 345ms/step - accuracy: 0.3236 - loss: 2.6647 - top2_accuracy: 0.4384 - val_accuracy: 0.0613 - val_loss: 4.9319 - val_top2_accuracy: 0.2271
# Epoch 2/200
#
# Epoch 2: val_loss improved from 4.93185 to 2.29044, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 2: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 84s - 214ms/step - accuracy: 0.4727 - loss: 1.9892 - top2_accuracy: 0.6185 - val_accuracy: 0.4043 - val_loss: 2.2904 - val_top2_accuracy: 0.5191
# Epoch 3/200
#
# Epoch 3: val_loss improved from 2.29044 to 1.41888, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 3: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 85s - 215ms/step - accuracy: 0.5474 - loss: 1.6792 - top2_accuracy: 0.6894 - val_accuracy: 0.6039 - val_loss: 1.4189 - val_top2_accuracy: 0.7484
# Epoch 4/200
#
# Epoch 4: val_loss improved from 1.41888 to 1.37279, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 4: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 82s - 209ms/step - accuracy: 0.5909 - loss: 1.4932 - top2_accuracy: 0.7320 - val_accuracy: 0.6165 - val_loss: 1.3728 - val_top2_accuracy: 0.7640
# Epoch 5/200
#
# Epoch 5: val_loss improved from 1.37279 to 1.18293, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 5: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 200ms/step - accuracy: 0.6335 - loss: 1.3587 - top2_accuracy: 0.7660 - val_accuracy: 0.6540 - val_loss: 1.1829 - val_top2_accuracy: 0.8016
# Epoch 6/200
#
# Epoch 6: val_loss did not improve from 1.18293
# 393/393 - 78s - 198ms/step - accuracy: 0.6617 - loss: 1.2496 - top2_accuracy: 0.7883 - val_accuracy: 0.6525 - val_loss: 1.2027 - val_top2_accuracy: 0.7938
# Epoch 7/200
#
# Epoch 7: val_loss did not improve from 1.18293
# 393/393 - 80s - 203ms/step - accuracy: 0.6792 - loss: 1.1755 - top2_accuracy: 0.8118 - val_accuracy: 0.5875 - val_loss: 1.3460 - val_top2_accuracy: 0.7614
# Epoch 8/200
#
# Epoch 8: val_loss did not improve from 1.18293
# 393/393 - 81s - 207ms/step - accuracy: 0.6972 - loss: 1.1047 - top2_accuracy: 0.8176 - val_accuracy: 0.6399 - val_loss: 1.2113 - val_top2_accuracy: 0.7908
# Epoch 9/200
#
# Epoch 9: val_loss improved from 1.18293 to 1.01046, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 9: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.7174 - loss: 1.0393 - top2_accuracy: 0.8344 - val_accuracy: 0.7165 - val_loss: 1.0105 - val_top2_accuracy: 0.8380
# Epoch 10/200
#
# Epoch 10: val_loss improved from 1.01046 to 0.84449, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 10: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.7250 - loss: 0.9944 - top2_accuracy: 0.8395 - val_accuracy: 0.7599 - val_loss: 0.8445 - val_top2_accuracy: 0.8696
# Epoch 11/200
#
# Epoch 11: val_loss did not improve from 0.84449
# 393/393 - 79s - 202ms/step - accuracy: 0.7367 - loss: 0.9508 - top2_accuracy: 0.8488 - val_accuracy: 0.7009 - val_loss: 0.9755 - val_top2_accuracy: 0.8402
# Epoch 12/200
#
# Epoch 12: val_loss improved from 0.84449 to 0.81108, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 12: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 200ms/step - accuracy: 0.7438 - loss: 0.9270 - top2_accuracy: 0.8540 - val_accuracy: 0.7819 - val_loss: 0.8111 - val_top2_accuracy: 0.8841
# Epoch 13/200
#
# Epoch 13: val_loss improved from 0.81108 to 0.77454, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 13: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.7568 - loss: 0.8775 - top2_accuracy: 0.8621 - val_accuracy: 0.7949 - val_loss: 0.7745 - val_top2_accuracy: 0.8837
# Epoch 14/200
#
# Epoch 14: val_loss did not improve from 0.77454
# 393/393 - 79s - 202ms/step - accuracy: 0.7678 - loss: 0.8416 - top2_accuracy: 0.8677 - val_accuracy: 0.7741 - val_loss: 0.7844 - val_top2_accuracy: 0.8751
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.77454 to 0.69282, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 15: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 203ms/step - accuracy: 0.7663 - loss: 0.8274 - top2_accuracy: 0.8711 - val_accuracy: 0.7990 - val_loss: 0.6928 - val_top2_accuracy: 0.8922
# Epoch 16/200
#
# Epoch 16: val_loss did not improve from 0.69282
# 393/393 - 82s - 208ms/step - accuracy: 0.7777 - loss: 0.7973 - top2_accuracy: 0.8744 - val_accuracy: 0.7952 - val_loss: 0.7103 - val_top2_accuracy: 0.8881
# Epoch 17/200
#
# Epoch 17: val_loss did not improve from 0.69282
# 393/393 - 82s - 208ms/step - accuracy: 0.7845 - loss: 0.7782 - top2_accuracy: 0.8817 - val_accuracy: 0.6979 - val_loss: 0.9672 - val_top2_accuracy: 0.8525
# Epoch 18/200
#
# Epoch 18: val_loss did not improve from 0.69282
# 393/393 - 83s - 210ms/step - accuracy: 0.7918 - loss: 0.7494 - top2_accuracy: 0.8859 - val_accuracy: 0.7499 - val_loss: 0.8261 - val_top2_accuracy: 0.8755
# Epoch 19/200
#
# Epoch 19: val_loss improved from 0.69282 to 0.67652, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 19: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 83s - 211ms/step - accuracy: 0.7973 - loss: 0.7411 - top2_accuracy: 0.8886 - val_accuracy: 0.8138 - val_loss: 0.6765 - val_top2_accuracy: 0.9078
# Epoch 20/200
#
# Epoch 20: val_loss improved from 0.67652 to 0.65577, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 20: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 203ms/step - accuracy: 0.8022 - loss: 0.7187 - top2_accuracy: 0.8913 - val_accuracy: 0.8127 - val_loss: 0.6558 - val_top2_accuracy: 0.8997
# Epoch 21/200
#
# Epoch 21: val_loss did not improve from 0.65577
# 393/393 - 79s - 201ms/step - accuracy: 0.8018 - loss: 0.7031 - top2_accuracy: 0.8955 - val_accuracy: 0.8127 - val_loss: 0.6601 - val_top2_accuracy: 0.9041
# Epoch 22/200
#
# Epoch 22: val_loss improved from 0.65577 to 0.61445, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 22: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.8079 - loss: 0.6901 - top2_accuracy: 0.8965 - val_accuracy: 0.8272 - val_loss: 0.6144 - val_top2_accuracy: 0.9127
# Epoch 23/200
#
# Epoch 23: val_loss did not improve from 0.61445
# 393/393 - 80s - 203ms/step - accuracy: 0.8113 - loss: 0.6745 - top2_accuracy: 0.8999 - val_accuracy: 0.8094 - val_loss: 0.6618 - val_top2_accuracy: 0.9060
# Epoch 24/200
#
# Epoch 24: val_loss did not improve from 0.61445
# 393/393 - 80s - 204ms/step - accuracy: 0.8161 - loss: 0.6510 - top2_accuracy: 0.9028 - val_accuracy: 0.8094 - val_loss: 0.6245 - val_top2_accuracy: 0.9149
# Epoch 25/200
#
# Epoch 25: val_loss did not improve from 0.61445
# 393/393 - 89s - 226ms/step - accuracy: 0.8133 - loss: 0.6513 - top2_accuracy: 0.9041 - val_accuracy: 0.8164 - val_loss: 0.6406 - val_top2_accuracy: 0.9012
# Epoch 26/200
#
# Epoch 26: val_loss did not improve from 0.61445
# 393/393 - 83s - 212ms/step - accuracy: 0.8190 - loss: 0.6330 - top2_accuracy: 0.9071 - val_accuracy: 0.8157 - val_loss: 0.6156 - val_top2_accuracy: 0.9049
# Epoch 27/200
#
# Epoch 27: val_loss did not improve from 0.61445
# 393/393 - 82s - 209ms/step - accuracy: 0.8238 - loss: 0.6215 - top2_accuracy: 0.9078 - val_accuracy: 0.7848 - val_loss: 0.7242 - val_top2_accuracy: 0.8826
# Epoch 28/200
#
# Epoch 28: val_loss did not improve from 0.61445
# 393/393 - 81s - 205ms/step - accuracy: 0.8200 - loss: 0.6266 - top2_accuracy: 0.9055 - val_accuracy: 0.8138 - val_loss: 0.6203 - val_top2_accuracy: 0.9060
# Epoch 29/200
#
# Epoch 29: val_loss did not improve from 0.61445
# 393/393 - 80s - 204ms/step - accuracy: 0.8219 - loss: 0.6150 - top2_accuracy: 0.9088 - val_accuracy: 0.7978 - val_loss: 0.6756 - val_top2_accuracy: 0.8881
# Epoch 30/200
#
# Epoch 30: val_loss did not improve from 0.61445
# 393/393 - 81s - 205ms/step - accuracy: 0.8273 - loss: 0.6013 - top2_accuracy: 0.9118 - val_accuracy: 0.7837 - val_loss: 0.6962 - val_top2_accuracy: 0.9000
# Epoch 31/200
#
# Epoch 31: val_loss improved from 0.61445 to 0.56507, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 31: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 201ms/step - accuracy: 0.8324 - loss: 0.5834 - top2_accuracy: 0.9178 - val_accuracy: 0.8305 - val_loss: 0.5651 - val_top2_accuracy: 0.9260
# Epoch 32/200
#
# Epoch 32: val_loss did not improve from 0.56507
# 393/393 - 79s - 201ms/step - accuracy: 0.8357 - loss: 0.5741 - top2_accuracy: 0.9163 - val_accuracy: 0.7785 - val_loss: 0.7362 - val_top2_accuracy: 0.8781
# Epoch 33/200
#
# Epoch 33: val_loss did not improve from 0.56507
# 393/393 - 80s - 204ms/step - accuracy: 0.8338 - loss: 0.5778 - top2_accuracy: 0.9176 - val_accuracy: 0.7852 - val_loss: 0.7024 - val_top2_accuracy: 0.9019
# Epoch 34/200
#
# Epoch 34: val_loss improved from 0.56507 to 0.52321, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 34: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 205ms/step - accuracy: 0.8344 - loss: 0.5696 - top2_accuracy: 0.9163 - val_accuracy: 0.8424 - val_loss: 0.5232 - val_top2_accuracy: 0.9231
# Epoch 35/200
#
# Epoch 35: val_loss did not improve from 0.52321
# 393/393 - 80s - 203ms/step - accuracy: 0.8407 - loss: 0.5558 - top2_accuracy: 0.9205 - val_accuracy: 0.8157 - val_loss: 0.6418 - val_top2_accuracy: 0.9015
# Epoch 36/200
#
# Epoch 36: val_loss did not improve from 0.52321
# 393/393 - 80s - 203ms/step - accuracy: 0.8437 - loss: 0.5454 - top2_accuracy: 0.9210 - val_accuracy: 0.8339 - val_loss: 0.5733 - val_top2_accuracy: 0.9123
# Epoch 37/200
#
# Epoch 37: val_loss did not improve from 0.52321
# 393/393 - 80s - 204ms/step - accuracy: 0.8481 - loss: 0.5412 - top2_accuracy: 0.9224 - val_accuracy: 0.7350 - val_loss: 0.9241 - val_top2_accuracy: 0.8380
# Epoch 38/200
#
# Epoch 38: val_loss did not improve from 0.52321
# 393/393 - 83s - 212ms/step - accuracy: 0.8437 - loss: 0.5464 - top2_accuracy: 0.9221 - val_accuracy: 0.7882 - val_loss: 0.7070 - val_top2_accuracy: 0.8822
# Epoch 39/200
#
# Epoch 39: val_loss did not improve from 0.52321
# 393/393 - 88s - 223ms/step - accuracy: 0.8447 - loss: 0.5320 - top2_accuracy: 0.9240 - val_accuracy: 0.8038 - val_loss: 0.6292 - val_top2_accuracy: 0.9064
# Epoch 40/200
#
# Epoch 40: val_loss improved from 0.52321 to 0.49114, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 40: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 85s - 217ms/step - accuracy: 0.8491 - loss: 0.5233 - top2_accuracy: 0.9268 - val_accuracy: 0.8510 - val_loss: 0.4911 - val_top2_accuracy: 0.9357
# Epoch 41/200
#
# Epoch 41: val_loss did not improve from 0.49114
# 393/393 - 81s - 207ms/step - accuracy: 0.8501 - loss: 0.5123 - top2_accuracy: 0.9273 - val_accuracy: 0.7410 - val_loss: 0.8174 - val_top2_accuracy: 0.8499
# Epoch 42/200
#
# Epoch 42: val_loss improved from 0.49114 to 0.42100, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 42: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 203ms/step - accuracy: 0.8472 - loss: 0.5191 - top2_accuracy: 0.9267 - val_accuracy: 0.8692 - val_loss: 0.4210 - val_top2_accuracy: 0.9417
# Epoch 43/200
#
# Epoch 43: val_loss did not improve from 0.42100
# 393/393 - 80s - 203ms/step - accuracy: 0.8488 - loss: 0.5092 - top2_accuracy: 0.9267 - val_accuracy: 0.8655 - val_loss: 0.4472 - val_top2_accuracy: 0.9365
# Epoch 44/200
#
# Epoch 44: val_loss did not improve from 0.42100
# 393/393 - 80s - 203ms/step - accuracy: 0.8585 - loss: 0.4917 - top2_accuracy: 0.9312 - val_accuracy: 0.7596 - val_loss: 0.7948 - val_top2_accuracy: 0.8629
# Epoch 45/200
#
# Epoch 45: val_loss did not improve from 0.42100
# 393/393 - 79s - 201ms/step - accuracy: 0.8589 - loss: 0.4922 - top2_accuracy: 0.9313 - val_accuracy: 0.8488 - val_loss: 0.4935 - val_top2_accuracy: 0.9324
# Epoch 46/200
#
# Epoch 46: val_loss did not improve from 0.42100
# 393/393 - 81s - 205ms/step - accuracy: 0.8563 - loss: 0.4979 - top2_accuracy: 0.9292 - val_accuracy: 0.7596 - val_loss: 0.7744 - val_top2_accuracy: 0.8989
# Epoch 47/200
#
# Epoch 47: val_loss did not improve from 0.42100
# 393/393 - 81s - 205ms/step - accuracy: 0.8606 - loss: 0.4837 - top2_accuracy: 0.9345 - val_accuracy: 0.8521 - val_loss: 0.4925 - val_top2_accuracy: 0.9335
# Epoch 48/200
#
# Epoch 48: val_loss did not improve from 0.42100
# 393/393 - 80s - 203ms/step - accuracy: 0.8600 - loss: 0.4848 - top2_accuracy: 0.9334 - val_accuracy: 0.8357 - val_loss: 0.5292 - val_top2_accuracy: 0.9227
# Epoch 49/200
#
# Epoch 49: val_loss did not improve from 0.42100
# 393/393 - 79s - 202ms/step - accuracy: 0.8602 - loss: 0.4838 - top2_accuracy: 0.9300 - val_accuracy: 0.8443 - val_loss: 0.5449 - val_top2_accuracy: 0.9275
# Epoch 50/200
#
# Epoch 50: val_loss did not improve from 0.42100
# 393/393 - 82s - 208ms/step - accuracy: 0.8655 - loss: 0.4702 - top2_accuracy: 0.9341 - val_accuracy: 0.8376 - val_loss: 0.5409 - val_top2_accuracy: 0.9153
# Epoch 51/200
#
# Epoch 51: val_loss did not improve from 0.42100
# 393/393 - 79s - 202ms/step - accuracy: 0.8615 - loss: 0.4658 - top2_accuracy: 0.9325 - val_accuracy: 0.8488 - val_loss: 0.5205 - val_top2_accuracy: 0.9231
# Epoch 52/200
#
# Epoch 52: val_loss did not improve from 0.42100
# 393/393 - 82s - 208ms/step - accuracy: 0.8651 - loss: 0.4578 - top2_accuracy: 0.9360 - val_accuracy: 0.7752 - val_loss: 0.7275 - val_top2_accuracy: 0.8841
# Epoch 53/200
#
# Epoch 53: val_loss did not improve from 0.42100
# 393/393 - 80s - 204ms/step - accuracy: 0.8630 - loss: 0.4580 - top2_accuracy: 0.9364 - val_accuracy: 0.8644 - val_loss: 0.4412 - val_top2_accuracy: 0.9327
# Epoch 54/200
#
# Epoch 54: val_loss did not improve from 0.42100
# 393/393 - 80s - 204ms/step - accuracy: 0.8639 - loss: 0.4680 - top2_accuracy: 0.9340 - val_accuracy: 0.8276 - val_loss: 0.5534 - val_top2_accuracy: 0.9134
# Epoch 55/200
#
# Epoch 55: val_loss did not improve from 0.42100
# 393/393 - 80s - 203ms/step - accuracy: 0.8672 - loss: 0.4534 - top2_accuracy: 0.9364 - val_accuracy: 0.8569 - val_loss: 0.4757 - val_top2_accuracy: 0.9331
# Epoch 56/200
#
# Epoch 56: val_loss did not improve from 0.42100
# 393/393 - 79s - 202ms/step - accuracy: 0.8645 - loss: 0.4503 - top2_accuracy: 0.9387 - val_accuracy: 0.7287 - val_loss: 0.8752 - val_top2_accuracy: 0.8543
# Epoch 57/200
#
# Epoch 57: val_loss did not improve from 0.42100
# 393/393 - 80s - 203ms/step - accuracy: 0.8653 - loss: 0.4441 - top2_accuracy: 0.9384 - val_accuracy: 0.8573 - val_loss: 0.4549 - val_top2_accuracy: 0.9402
# Epoch 58/200
#
# Epoch 58: val_loss did not improve from 0.42100
# 393/393 - 79s - 202ms/step - accuracy: 0.8708 - loss: 0.4437 - top2_accuracy: 0.9373 - val_accuracy: 0.8592 - val_loss: 0.4706 - val_top2_accuracy: 0.9279
# Epoch 59/200
#
# Epoch 59: val_loss improved from 0.42100 to 0.40277, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 59: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 81s - 206ms/step - accuracy: 0.8735 - loss: 0.4345 - top2_accuracy: 0.9401 - val_accuracy: 0.8777 - val_loss: 0.4028 - val_top2_accuracy: 0.9446
# Epoch 60/200
#
# Epoch 60: val_loss did not improve from 0.40277
# 393/393 - 79s - 202ms/step - accuracy: 0.8692 - loss: 0.4427 - top2_accuracy: 0.9395 - val_accuracy: 0.8343 - val_loss: 0.5238 - val_top2_accuracy: 0.9301
# Epoch 61/200
#
# Epoch 61: val_loss did not improve from 0.40277
# 393/393 - 79s - 200ms/step - accuracy: 0.8716 - loss: 0.4347 - top2_accuracy: 0.9427 - val_accuracy: 0.8324 - val_loss: 0.5320 - val_top2_accuracy: 0.9194
# Epoch 62/200
#
# Epoch 62: val_loss did not improve from 0.40277
# 393/393 - 77s - 196ms/step - accuracy: 0.8698 - loss: 0.4306 - top2_accuracy: 0.9423 - val_accuracy: 0.8220 - val_loss: 0.5898 - val_top2_accuracy: 0.9108
# Epoch 63/200
#
# Epoch 63: val_loss did not improve from 0.40277
# 393/393 - 77s - 197ms/step - accuracy: 0.8684 - loss: 0.4357 - top2_accuracy: 0.9400 - val_accuracy: 0.8198 - val_loss: 0.5976 - val_top2_accuracy: 0.9160
# Epoch 64/200
#
# Epoch 64: val_loss did not improve from 0.40277
# 393/393 - 78s - 197ms/step - accuracy: 0.8726 - loss: 0.4241 - top2_accuracy: 0.9426 - val_accuracy: 0.7926 - val_loss: 0.7059 - val_top2_accuracy: 0.8974
# Epoch 65/200
#
# Epoch 65: val_loss did not improve from 0.40277
# 393/393 - 78s - 198ms/step - accuracy: 0.8769 - loss: 0.4210 - top2_accuracy: 0.9435 - val_accuracy: 0.8644 - val_loss: 0.4411 - val_top2_accuracy: 0.9402
# Epoch 66/200
#
# Epoch 66: val_loss did not improve from 0.40277
# 393/393 - 78s - 198ms/step - accuracy: 0.8738 - loss: 0.4196 - top2_accuracy: 0.9417 - val_accuracy: 0.8298 - val_loss: 0.5364 - val_top2_accuracy: 0.9201
# Epoch 67/200
#
# Epoch 67: val_loss did not improve from 0.40277
# 393/393 - 78s - 199ms/step - accuracy: 0.8766 - loss: 0.4122 - top2_accuracy: 0.9439 - val_accuracy: 0.8201 - val_loss: 0.5886 - val_top2_accuracy: 0.9112
# Epoch 68/200
#
# Epoch 68: val_loss improved from 0.40277 to 0.38626, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 68: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 201ms/step - accuracy: 0.8771 - loss: 0.4162 - top2_accuracy: 0.9440 - val_accuracy: 0.8774 - val_loss: 0.3863 - val_top2_accuracy: 0.9450
# Epoch 69/200
#
# Epoch 69: val_loss did not improve from 0.38626
# 393/393 - 79s - 202ms/step - accuracy: 0.8767 - loss: 0.4104 - top2_accuracy: 0.9450 - val_accuracy: 0.8770 - val_loss: 0.3989 - val_top2_accuracy: 0.9461
# Epoch 70/200
#
# Epoch 70: val_loss did not improve from 0.38626
# 393/393 - 79s - 202ms/step - accuracy: 0.8794 - loss: 0.4038 - top2_accuracy: 0.9468 - val_accuracy: 0.8458 - val_loss: 0.5081 - val_top2_accuracy: 0.9290
# Epoch 71/200
#
# Epoch 71: val_loss did not improve from 0.38626
# 393/393 - 79s - 201ms/step - accuracy: 0.8814 - loss: 0.4027 - top2_accuracy: 0.9442 - val_accuracy: 0.8016 - val_loss: 0.6364 - val_top2_accuracy: 0.9071
# Epoch 72/200
#
# Epoch 72: val_loss did not improve from 0.38626
# 393/393 - 80s - 203ms/step - accuracy: 0.8762 - loss: 0.4058 - top2_accuracy: 0.9447 - val_accuracy: 0.8803 - val_loss: 0.3946 - val_top2_accuracy: 0.9498
# Epoch 73/200
#
# Epoch 73: val_loss did not improve from 0.38626
# 393/393 - 79s - 201ms/step - accuracy: 0.8806 - loss: 0.3992 - top2_accuracy: 0.9458 - val_accuracy: 0.7856 - val_loss: 0.6924 - val_top2_accuracy: 0.8997
# Epoch 74/200
#
# Epoch 74: val_loss did not improve from 0.38626
# 393/393 - 79s - 201ms/step - accuracy: 0.8810 - loss: 0.3974 - top2_accuracy: 0.9493 - val_accuracy: 0.8740 - val_loss: 0.4013 - val_top2_accuracy: 0.9506
# Epoch 75/200
#
# Epoch 75: val_loss improved from 0.38626 to 0.36545, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 75: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.8809 - loss: 0.3922 - top2_accuracy: 0.9459 - val_accuracy: 0.8833 - val_loss: 0.3654 - val_top2_accuracy: 0.9509
# Epoch 76/200
#
# Epoch 76: val_loss did not improve from 0.36545
# 393/393 - 80s - 202ms/step - accuracy: 0.8814 - loss: 0.4004 - top2_accuracy: 0.9449 - val_accuracy: 0.8907 - val_loss: 0.3719 - val_top2_accuracy: 0.9543
# Epoch 77/200
#
# Epoch 77: val_loss did not improve from 0.36545
# 393/393 - 80s - 205ms/step - accuracy: 0.8802 - loss: 0.3950 - top2_accuracy: 0.9470 - val_accuracy: 0.8302 - val_loss: 0.5355 - val_top2_accuracy: 0.9275
# Epoch 78/200
#
# Epoch 78: val_loss did not improve from 0.36545
# 393/393 - 90s - 228ms/step - accuracy: 0.8837 - loss: 0.3899 - top2_accuracy: 0.9487 - val_accuracy: 0.8120 - val_loss: 0.6113 - val_top2_accuracy: 0.9026
# Epoch 79/200
#
# Epoch 79: val_loss did not improve from 0.36545
# 393/393 - 79s - 201ms/step - accuracy: 0.8849 - loss: 0.3925 - top2_accuracy: 0.9469 - val_accuracy: 0.8770 - val_loss: 0.4019 - val_top2_accuracy: 0.9443
# Epoch 80/200
#
# Epoch 80: val_loss did not improve from 0.36545
# 393/393 - 80s - 203ms/step - accuracy: 0.8837 - loss: 0.3854 - top2_accuracy: 0.9493 - val_accuracy: 0.8632 - val_loss: 0.4587 - val_top2_accuracy: 0.9379
# Epoch 81/200
#
# Epoch 81: val_loss improved from 0.36545 to 0.36115, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 81: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 203ms/step - accuracy: 0.8858 - loss: 0.3812 - top2_accuracy: 0.9478 - val_accuracy: 0.8911 - val_loss: 0.3611 - val_top2_accuracy: 0.9532
# Epoch 82/200
#
# Epoch 82: val_loss did not improve from 0.36115
# 393/393 - 82s - 208ms/step - accuracy: 0.8890 - loss: 0.3762 - top2_accuracy: 0.9498 - val_accuracy: 0.8763 - val_loss: 0.3957 - val_top2_accuracy: 0.9420
# Epoch 83/200
#
# Epoch 83: val_loss did not improve from 0.36115
# 393/393 - 79s - 201ms/step - accuracy: 0.8876 - loss: 0.3798 - top2_accuracy: 0.9491 - val_accuracy: 0.8272 - val_loss: 0.5527 - val_top2_accuracy: 0.9234
# Epoch 84/200
#
# Epoch 84: val_loss did not improve from 0.36115
# 393/393 - 80s - 203ms/step - accuracy: 0.8839 - loss: 0.3800 - top2_accuracy: 0.9488 - val_accuracy: 0.8625 - val_loss: 0.4580 - val_top2_accuracy: 0.9350
# Epoch 85/200
#
# Epoch 85: val_loss did not improve from 0.36115
# 393/393 - 87s - 222ms/step - accuracy: 0.8892 - loss: 0.3727 - top2_accuracy: 0.9502 - val_accuracy: 0.8551 - val_loss: 0.4777 - val_top2_accuracy: 0.9365
# Epoch 86/200
#
# Epoch 86: val_loss did not improve from 0.36115
# 393/393 - 81s - 205ms/step - accuracy: 0.8843 - loss: 0.3764 - top2_accuracy: 0.9515 - val_accuracy: 0.8257 - val_loss: 0.5625 - val_top2_accuracy: 0.9134
# Epoch 87/200
#
# Epoch 87: val_loss did not improve from 0.36115
# 393/393 - 79s - 200ms/step - accuracy: 0.8878 - loss: 0.3691 - top2_accuracy: 0.9502 - val_accuracy: 0.8599 - val_loss: 0.4650 - val_top2_accuracy: 0.9413
# Epoch 88/200
#
# Epoch 88: val_loss did not improve from 0.36115
# 393/393 - 79s - 202ms/step - accuracy: 0.8884 - loss: 0.3663 - top2_accuracy: 0.9503 - val_accuracy: 0.8807 - val_loss: 0.3676 - val_top2_accuracy: 0.9498
# Epoch 89/200
#
# Epoch 89: val_loss did not improve from 0.36115
# 393/393 - 79s - 201ms/step - accuracy: 0.8923 - loss: 0.3643 - top2_accuracy: 0.9506 - val_accuracy: 0.8826 - val_loss: 0.3868 - val_top2_accuracy: 0.9450
# Epoch 90/200
#
# Epoch 90: val_loss did not improve from 0.36115
# 393/393 - 79s - 202ms/step - accuracy: 0.8908 - loss: 0.3578 - top2_accuracy: 0.9529 - val_accuracy: 0.8153 - val_loss: 0.5964 - val_top2_accuracy: 0.9067
# Epoch 91/200
#
# Epoch 91: val_loss did not improve from 0.36115
# 393/393 - 93s - 237ms/step - accuracy: 0.8885 - loss: 0.3662 - top2_accuracy: 0.9524 - val_accuracy: 0.8618 - val_loss: 0.4331 - val_top2_accuracy: 0.9376
# Epoch 92/200
#
# Epoch 92: val_loss did not improve from 0.36115
# 393/393 - 79s - 201ms/step - accuracy: 0.8933 - loss: 0.3531 - top2_accuracy: 0.9537 - val_accuracy: 0.8878 - val_loss: 0.3736 - val_top2_accuracy: 0.9495
# Epoch 93/200
#
# Epoch 93: val_loss did not improve from 0.36115
# 393/393 - 80s - 202ms/step - accuracy: 0.8917 - loss: 0.3633 - top2_accuracy: 0.9514 - val_accuracy: 0.8339 - val_loss: 0.5567 - val_top2_accuracy: 0.9164
# Epoch 94/200
#
# Epoch 94: val_loss did not improve from 0.36115
# 393/393 - 79s - 201ms/step - accuracy: 0.8876 - loss: 0.3604 - top2_accuracy: 0.9525 - val_accuracy: 0.8629 - val_loss: 0.4499 - val_top2_accuracy: 0.9346
# Epoch 95/200
#
# Epoch 95: val_loss did not improve from 0.36115
# 393/393 - 79s - 202ms/step - accuracy: 0.8897 - loss: 0.3613 - top2_accuracy: 0.9530 - val_accuracy: 0.8844 - val_loss: 0.3688 - val_top2_accuracy: 0.9509
# Epoch 96/200
#
# Epoch 96: val_loss did not improve from 0.36115
# 393/393 - 79s - 201ms/step - accuracy: 0.8924 - loss: 0.3574 - top2_accuracy: 0.9537 - val_accuracy: 0.8859 - val_loss: 0.3866 - val_top2_accuracy: 0.9498
# Epoch 97/200
#
# Epoch 97: val_loss improved from 0.36115 to 0.33472, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 97: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 202ms/step - accuracy: 0.8900 - loss: 0.3531 - top2_accuracy: 0.9547 - val_accuracy: 0.8926 - val_loss: 0.3347 - val_top2_accuracy: 0.9580
# Epoch 98/200
#
# Epoch 98: val_loss did not improve from 0.33472
# 393/393 - 80s - 204ms/step - accuracy: 0.8968 - loss: 0.3496 - top2_accuracy: 0.9541 - val_accuracy: 0.8331 - val_loss: 0.5588 - val_top2_accuracy: 0.9116
# Epoch 99/200
#
# Epoch 99: val_loss did not improve from 0.33472
# 393/393 - 81s - 206ms/step - accuracy: 0.8935 - loss: 0.3479 - top2_accuracy: 0.9541 - val_accuracy: 0.8562 - val_loss: 0.4939 - val_top2_accuracy: 0.9316
# Epoch 100/200
#
# Epoch 100: val_loss did not improve from 0.33472
# 393/393 - 81s - 205ms/step - accuracy: 0.8919 - loss: 0.3483 - top2_accuracy: 0.9540 - val_accuracy: 0.8001 - val_loss: 0.6698 - val_top2_accuracy: 0.8997
# Epoch 101/200
#
# Epoch 101: val_loss did not improve from 0.33472
# 393/393 - 81s - 207ms/step - accuracy: 0.8942 - loss: 0.3434 - top2_accuracy: 0.9558 - val_accuracy: 0.8956 - val_loss: 0.3599 - val_top2_accuracy: 0.9495
# Epoch 102/200
#
# Epoch 102: val_loss did not improve from 0.33472
# 393/393 - 88s - 225ms/step - accuracy: 0.8993 - loss: 0.3372 - top2_accuracy: 0.9559 - val_accuracy: 0.8919 - val_loss: 0.3533 - val_top2_accuracy: 0.9554
# Epoch 103/200
#
# Epoch 103: val_loss did not improve from 0.33472
# 393/393 - 100s - 254ms/step - accuracy: 0.8964 - loss: 0.3374 - top2_accuracy: 0.9540 - val_accuracy: 0.8807 - val_loss: 0.4061 - val_top2_accuracy: 0.9528
# Epoch 104/200
#
# Epoch 104: val_loss did not improve from 0.33472
# 393/393 - 95s - 242ms/step - accuracy: 0.8919 - loss: 0.3504 - top2_accuracy: 0.9534 - val_accuracy: 0.8811 - val_loss: 0.3837 - val_top2_accuracy: 0.9469
# Epoch 105/200
#
# Epoch 105: val_loss did not improve from 0.33472
# 393/393 - 80s - 203ms/step - accuracy: 0.8946 - loss: 0.3335 - top2_accuracy: 0.9564 - val_accuracy: 0.7926 - val_loss: 0.7754 - val_top2_accuracy: 0.8967
# Epoch 106/200
#
# Epoch 106: val_loss improved from 0.33472 to 0.33403, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 106: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 81s - 206ms/step - accuracy: 0.8950 - loss: 0.3500 - top2_accuracy: 0.9524 - val_accuracy: 0.8974 - val_loss: 0.3340 - val_top2_accuracy: 0.9595
# Epoch 107/200
#
# Epoch 107: val_loss did not improve from 0.33403
# 393/393 - 80s - 204ms/step - accuracy: 0.8974 - loss: 0.3349 - top2_accuracy: 0.9552 - val_accuracy: 0.8956 - val_loss: 0.3611 - val_top2_accuracy: 0.9547
# Epoch 108/200
#
# Epoch 108: val_loss did not improve from 0.33403
# 393/393 - 80s - 203ms/step - accuracy: 0.8978 - loss: 0.3324 - top2_accuracy: 0.9565 - val_accuracy: 0.8989 - val_loss: 0.3488 - val_top2_accuracy: 0.9543
# Epoch 109/200
#
# Epoch 109: val_loss did not improve from 0.33403
# 393/393 - 79s - 202ms/step - accuracy: 0.8981 - loss: 0.3348 - top2_accuracy: 0.9556 - val_accuracy: 0.7752 - val_loss: 0.7295 - val_top2_accuracy: 0.8878
# Epoch 110/200
#
# Epoch 110: val_loss did not improve from 0.33403
# 393/393 - 79s - 200ms/step - accuracy: 0.8962 - loss: 0.3397 - top2_accuracy: 0.9569 - val_accuracy: 0.8595 - val_loss: 0.4654 - val_top2_accuracy: 0.9342
# Epoch 111/200
#
# Epoch 111: val_loss did not improve from 0.33403
# 393/393 - 79s - 202ms/step - accuracy: 0.9010 - loss: 0.3309 - top2_accuracy: 0.9575 - val_accuracy: 0.8469 - val_loss: 0.5125 - val_top2_accuracy: 0.9279
# Epoch 112/200
#
# Epoch 112: val_loss improved from 0.33403 to 0.32509, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 112: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 87s - 221ms/step - accuracy: 0.9004 - loss: 0.3317 - top2_accuracy: 0.9543 - val_accuracy: 0.9012 - val_loss: 0.3251 - val_top2_accuracy: 0.9610
# Epoch 113/200
#
# Epoch 113: val_loss did not improve from 0.32509
# 393/393 - 85s - 216ms/step - accuracy: 0.9010 - loss: 0.3224 - top2_accuracy: 0.9589 - val_accuracy: 0.8677 - val_loss: 0.4103 - val_top2_accuracy: 0.9550
# Epoch 114/200
#
# Epoch 114: val_loss did not improve from 0.32509
# 393/393 - 79s - 201ms/step - accuracy: 0.9030 - loss: 0.3159 - top2_accuracy: 0.9605 - val_accuracy: 0.8777 - val_loss: 0.4148 - val_top2_accuracy: 0.9417
# Epoch 115/200
#
# Epoch 115: val_loss did not improve from 0.32509
# 393/393 - 80s - 203ms/step - accuracy: 0.9013 - loss: 0.3282 - top2_accuracy: 0.9561 - val_accuracy: 0.8993 - val_loss: 0.3360 - val_top2_accuracy: 0.9547
# Epoch 116/200
#
# Epoch 116: val_loss did not improve from 0.32509
# 393/393 - 79s - 201ms/step - accuracy: 0.8998 - loss: 0.3256 - top2_accuracy: 0.9571 - val_accuracy: 0.8688 - val_loss: 0.4629 - val_top2_accuracy: 0.9398
# Epoch 117/200
#
# Epoch 117: val_loss did not improve from 0.32509
# 393/393 - 79s - 201ms/step - accuracy: 0.9004 - loss: 0.3250 - top2_accuracy: 0.9583 - val_accuracy: 0.8235 - val_loss: 0.6027 - val_top2_accuracy: 0.9104
# Epoch 118/200
#
# Epoch 118: val_loss did not improve from 0.32509
# 393/393 - 81s - 205ms/step - accuracy: 0.9031 - loss: 0.3272 - top2_accuracy: 0.9599 - val_accuracy: 0.8666 - val_loss: 0.4675 - val_top2_accuracy: 0.9275
# Epoch 119/200
#
# Epoch 119: val_loss did not improve from 0.32509
# 393/393 - 79s - 200ms/step - accuracy: 0.8978 - loss: 0.3285 - top2_accuracy: 0.9578 - val_accuracy: 0.8792 - val_loss: 0.3974 - val_top2_accuracy: 0.9517
# Epoch 120/200
#
# Epoch 120: val_loss did not improve from 0.32509
# 393/393 - 78s - 199ms/step - accuracy: 0.8992 - loss: 0.3251 - top2_accuracy: 0.9577 - val_accuracy: 0.8852 - val_loss: 0.3797 - val_top2_accuracy: 0.9584
# Epoch 121/200
#
# Epoch 121: val_loss did not improve from 0.32509
# 393/393 - 80s - 202ms/step - accuracy: 0.9090 - loss: 0.3108 - top2_accuracy: 0.9611 - val_accuracy: 0.8320 - val_loss: 0.5582 - val_top2_accuracy: 0.9294
# Epoch 122/200
#
# Epoch 122: val_loss did not improve from 0.32509
# 393/393 - 79s - 202ms/step - accuracy: 0.9029 - loss: 0.3186 - top2_accuracy: 0.9595 - val_accuracy: 0.8859 - val_loss: 0.3840 - val_top2_accuracy: 0.9498
# Epoch 123/200
#
# Epoch 123: val_loss did not improve from 0.32509
# 393/393 - 79s - 201ms/step - accuracy: 0.9056 - loss: 0.3134 - top2_accuracy: 0.9586 - val_accuracy: 0.8116 - val_loss: 0.6219 - val_top2_accuracy: 0.9060
# Epoch 124/200
#
# Epoch 124: val_loss improved from 0.32509 to 0.31643, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 124: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 80s - 203ms/step - accuracy: 0.9043 - loss: 0.3107 - top2_accuracy: 0.9612 - val_accuracy: 0.9045 - val_loss: 0.3164 - val_top2_accuracy: 0.9602
# Epoch 125/200
#
# Epoch 125: val_loss did not improve from 0.31643
# 393/393 - 79s - 202ms/step - accuracy: 0.9052 - loss: 0.3165 - top2_accuracy: 0.9600 - val_accuracy: 0.8502 - val_loss: 0.4857 - val_top2_accuracy: 0.9379
# Epoch 126/200
#
# Epoch 126: val_loss did not improve from 0.31643
# 393/393 - 80s - 202ms/step - accuracy: 0.9013 - loss: 0.3163 - top2_accuracy: 0.9600 - val_accuracy: 0.8592 - val_loss: 0.4691 - val_top2_accuracy: 0.9320
# Epoch 127/200
#
# Epoch 127: val_loss did not improve from 0.31643
# 393/393 - 79s - 200ms/step - accuracy: 0.9059 - loss: 0.3105 - top2_accuracy: 0.9588 - val_accuracy: 0.8870 - val_loss: 0.3890 - val_top2_accuracy: 0.9465
# Epoch 128/200
#
# Epoch 128: val_loss did not improve from 0.31643
# 393/393 - 79s - 200ms/step - accuracy: 0.9057 - loss: 0.3059 - top2_accuracy: 0.9631 - val_accuracy: 0.8874 - val_loss: 0.3793 - val_top2_accuracy: 0.9558
# Epoch 129/200
#
# Epoch 129: val_loss did not improve from 0.31643
# 393/393 - 78s - 199ms/step - accuracy: 0.9079 - loss: 0.3103 - top2_accuracy: 0.9619 - val_accuracy: 0.8751 - val_loss: 0.4150 - val_top2_accuracy: 0.9454
# Epoch 130/200
#
# Epoch 130: val_loss did not improve from 0.31643
# 393/393 - 77s - 197ms/step - accuracy: 0.9014 - loss: 0.3205 - top2_accuracy: 0.9598 - val_accuracy: 0.9012 - val_loss: 0.3376 - val_top2_accuracy: 0.9584
# Epoch 131/200
#
# Epoch 131: val_loss did not improve from 0.31643
# 393/393 - 79s - 201ms/step - accuracy: 0.9032 - loss: 0.3129 - top2_accuracy: 0.9621 - val_accuracy: 0.8863 - val_loss: 0.3896 - val_top2_accuracy: 0.9446
# Epoch 132/200
#
# Epoch 132: val_loss did not improve from 0.31643
# 393/393 - 80s - 203ms/step - accuracy: 0.9079 - loss: 0.3019 - top2_accuracy: 0.9611 - val_accuracy: 0.8685 - val_loss: 0.4229 - val_top2_accuracy: 0.9528
# Epoch 133/200
#
# Epoch 133: val_loss improved from 0.31643 to 0.31384, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 133: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 201ms/step - accuracy: 0.9072 - loss: 0.3071 - top2_accuracy: 0.9588 - val_accuracy: 0.9023 - val_loss: 0.3138 - val_top2_accuracy: 0.9632
# Epoch 134/200
#
# Epoch 134: val_loss did not improve from 0.31384
# 393/393 - 79s - 200ms/step - accuracy: 0.9053 - loss: 0.3046 - top2_accuracy: 0.9624 - val_accuracy: 0.7763 - val_loss: 0.7474 - val_top2_accuracy: 0.8885
# Epoch 135/200
#
# Epoch 135: val_loss did not improve from 0.31384
# 393/393 - 80s - 204ms/step - accuracy: 0.9064 - loss: 0.3062 - top2_accuracy: 0.9622 - val_accuracy: 0.8410 - val_loss: 0.5388 - val_top2_accuracy: 0.9309
# Epoch 136/200
#
# Epoch 136: val_loss did not improve from 0.31384
# 393/393 - 79s - 202ms/step - accuracy: 0.9082 - loss: 0.3044 - top2_accuracy: 0.9619 - val_accuracy: 0.8930 - val_loss: 0.3516 - val_top2_accuracy: 0.9621
# Epoch 137/200
#
# Epoch 137: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9094 - loss: 0.2931 - top2_accuracy: 0.9626 - val_accuracy: 0.8896 - val_loss: 0.3602 - val_top2_accuracy: 0.9550
# Epoch 138/200
#
# Epoch 138: val_loss did not improve from 0.31384
# 393/393 - 79s - 201ms/step - accuracy: 0.9065 - loss: 0.3031 - top2_accuracy: 0.9619 - val_accuracy: 0.8852 - val_loss: 0.3883 - val_top2_accuracy: 0.9513
# Epoch 139/200
#
# Epoch 139: val_loss did not improve from 0.31384
# 393/393 - 79s - 200ms/step - accuracy: 0.9075 - loss: 0.2964 - top2_accuracy: 0.9612 - val_accuracy: 0.8298 - val_loss: 0.5690 - val_top2_accuracy: 0.9339
# Epoch 140/200
#
# Epoch 140: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9091 - loss: 0.3013 - top2_accuracy: 0.9613 - val_accuracy: 0.8852 - val_loss: 0.3758 - val_top2_accuracy: 0.9528
# Epoch 141/200
#
# Epoch 141: val_loss did not improve from 0.31384
# 393/393 - 78s - 198ms/step - accuracy: 0.9069 - loss: 0.3004 - top2_accuracy: 0.9653 - val_accuracy: 0.8566 - val_loss: 0.4579 - val_top2_accuracy: 0.9409
# Epoch 142/200
#
# Epoch 142: val_loss did not improve from 0.31384
# 393/393 - 79s - 200ms/step - accuracy: 0.9068 - loss: 0.3032 - top2_accuracy: 0.9613 - val_accuracy: 0.8640 - val_loss: 0.4478 - val_top2_accuracy: 0.9409
# Epoch 143/200
#
# Epoch 143: val_loss did not improve from 0.31384
# 393/393 - 80s - 203ms/step - accuracy: 0.9086 - loss: 0.2956 - top2_accuracy: 0.9619 - val_accuracy: 0.8495 - val_loss: 0.5616 - val_top2_accuracy: 0.9119
# Epoch 144/200
#
# Epoch 144: val_loss did not improve from 0.31384
# 393/393 - 82s - 209ms/step - accuracy: 0.9082 - loss: 0.2977 - top2_accuracy: 0.9615 - val_accuracy: 0.8699 - val_loss: 0.4468 - val_top2_accuracy: 0.9424
# Epoch 145/200
#
# Epoch 145: val_loss did not improve from 0.31384
# 393/393 - 79s - 200ms/step - accuracy: 0.9111 - loss: 0.2889 - top2_accuracy: 0.9630 - val_accuracy: 0.8952 - val_loss: 0.3494 - val_top2_accuracy: 0.9576
# Epoch 146/200
#
# Epoch 146: val_loss did not improve from 0.31384
# 393/393 - 80s - 202ms/step - accuracy: 0.9115 - loss: 0.2901 - top2_accuracy: 0.9645 - val_accuracy: 0.9019 - val_loss: 0.3160 - val_top2_accuracy: 0.9636
# Epoch 147/200
#
# Epoch 147: val_loss did not improve from 0.31384
# 393/393 - 79s - 201ms/step - accuracy: 0.9067 - loss: 0.2947 - top2_accuracy: 0.9620 - val_accuracy: 0.8874 - val_loss: 0.3831 - val_top2_accuracy: 0.9550
# Epoch 148/200
#
# Epoch 148: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9119 - loss: 0.2829 - top2_accuracy: 0.9650 - val_accuracy: 0.8885 - val_loss: 0.3759 - val_top2_accuracy: 0.9469
# Epoch 149/200
#
# Epoch 149: val_loss did not improve from 0.31384
# 393/393 - 78s - 198ms/step - accuracy: 0.9108 - loss: 0.2955 - top2_accuracy: 0.9633 - val_accuracy: 0.8744 - val_loss: 0.4014 - val_top2_accuracy: 0.9588
# Epoch 150/200
#
# Epoch 150: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9121 - loss: 0.2874 - top2_accuracy: 0.9652 - val_accuracy: 0.8164 - val_loss: 0.6327 - val_top2_accuracy: 0.9004
# Epoch 151/200
#
# Epoch 151: val_loss did not improve from 0.31384
# 393/393 - 77s - 197ms/step - accuracy: 0.9104 - loss: 0.2866 - top2_accuracy: 0.9647 - val_accuracy: 0.8766 - val_loss: 0.3934 - val_top2_accuracy: 0.9502
# Epoch 152/200
#
# Epoch 152: val_loss did not improve from 0.31384
# 393/393 - 80s - 203ms/step - accuracy: 0.9130 - loss: 0.2818 - top2_accuracy: 0.9652 - val_accuracy: 0.8907 - val_loss: 0.3682 - val_top2_accuracy: 0.9498
# Epoch 153/200
#
# Epoch 153: val_loss did not improve from 0.31384
# 393/393 - 80s - 204ms/step - accuracy: 0.9117 - loss: 0.2838 - top2_accuracy: 0.9640 - val_accuracy: 0.8421 - val_loss: 0.4784 - val_top2_accuracy: 0.9309
# Epoch 154/200
#
# Epoch 154: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9122 - loss: 0.2860 - top2_accuracy: 0.9642 - val_accuracy: 0.9045 - val_loss: 0.3333 - val_top2_accuracy: 0.9565
# Epoch 155/200
#
# Epoch 155: val_loss did not improve from 0.31384
# 393/393 - 78s - 199ms/step - accuracy: 0.9124 - loss: 0.2876 - top2_accuracy: 0.9640 - val_accuracy: 0.8792 - val_loss: 0.4036 - val_top2_accuracy: 0.9435
# Epoch 156/200
#
# Epoch 156: val_loss did not improve from 0.31384
# 393/393 - 77s - 197ms/step - accuracy: 0.9129 - loss: 0.2817 - top2_accuracy: 0.9638 - val_accuracy: 0.8956 - val_loss: 0.3483 - val_top2_accuracy: 0.9580
# Epoch 157/200
#
# Epoch 157: val_loss did not improve from 0.31384
# 393/393 - 78s - 200ms/step - accuracy: 0.9135 - loss: 0.2845 - top2_accuracy: 0.9642 - val_accuracy: 0.8956 - val_loss: 0.3578 - val_top2_accuracy: 0.9614
# Epoch 158/200
#
# Epoch 158: val_loss improved from 0.31384 to 0.28549, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 158: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 78s - 198ms/step - accuracy: 0.9139 - loss: 0.2805 - top2_accuracy: 0.9642 - val_accuracy: 0.9156 - val_loss: 0.2855 - val_top2_accuracy: 0.9640
# Epoch 159/200
#
# Epoch 159: val_loss did not improve from 0.28549
# 393/393 - 79s - 200ms/step - accuracy: 0.9130 - loss: 0.2826 - top2_accuracy: 0.9641 - val_accuracy: 0.9000 - val_loss: 0.3344 - val_top2_accuracy: 0.9565
# Epoch 160/200
#
# Epoch 160: val_loss did not improve from 0.28549
# 393/393 - 78s - 198ms/step - accuracy: 0.9126 - loss: 0.2804 - top2_accuracy: 0.9628 - val_accuracy: 0.8599 - val_loss: 0.4747 - val_top2_accuracy: 0.9335
# Epoch 161/200
#
# Epoch 161: val_loss did not improve from 0.28549
# 393/393 - 77s - 196ms/step - accuracy: 0.9114 - loss: 0.2831 - top2_accuracy: 0.9651 - val_accuracy: 0.8770 - val_loss: 0.3824 - val_top2_accuracy: 0.9539
# Epoch 162/200
#
# Epoch 162: val_loss did not improve from 0.28549
# 393/393 - 77s - 197ms/step - accuracy: 0.9111 - loss: 0.2878 - top2_accuracy: 0.9648 - val_accuracy: 0.8235 - val_loss: 0.5847 - val_top2_accuracy: 0.9272
# Epoch 163/200
#
# Epoch 163: val_loss did not improve from 0.28549
# 393/393 - 77s - 197ms/step - accuracy: 0.9167 - loss: 0.2775 - top2_accuracy: 0.9673 - val_accuracy: 0.8974 - val_loss: 0.3379 - val_top2_accuracy: 0.9565
# Epoch 164/200
#
# Epoch 164: val_loss did not improve from 0.28549
# 393/393 - 82s - 208ms/step - accuracy: 0.9138 - loss: 0.2707 - top2_accuracy: 0.9677 - val_accuracy: 0.9041 - val_loss: 0.3126 - val_top2_accuracy: 0.9647
# Epoch 165/200
#
# Epoch 165: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9159 - loss: 0.2734 - top2_accuracy: 0.9662 - val_accuracy: 0.9004 - val_loss: 0.3418 - val_top2_accuracy: 0.9584
# Epoch 166/200
#
# Epoch 166: val_loss did not improve from 0.28549
# 393/393 - 78s - 199ms/step - accuracy: 0.9165 - loss: 0.2773 - top2_accuracy: 0.9669 - val_accuracy: 0.9075 - val_loss: 0.3027 - val_top2_accuracy: 0.9617
# Epoch 167/200
#
# Epoch 167: val_loss did not improve from 0.28549
# 393/393 - 82s - 209ms/step - accuracy: 0.9171 - loss: 0.2676 - top2_accuracy: 0.9653 - val_accuracy: 0.9075 - val_loss: 0.3066 - val_top2_accuracy: 0.9591
# Epoch 168/200
#
# Epoch 168: val_loss did not improve from 0.28549
# 393/393 - 79s - 202ms/step - accuracy: 0.9135 - loss: 0.2776 - top2_accuracy: 0.9656 - val_accuracy: 0.9000 - val_loss: 0.3293 - val_top2_accuracy: 0.9588
# Epoch 169/200
#
# Epoch 169: val_loss did not improve from 0.28549
# 393/393 - 79s - 200ms/step - accuracy: 0.9116 - loss: 0.2750 - top2_accuracy: 0.9656 - val_accuracy: 0.8740 - val_loss: 0.4154 - val_top2_accuracy: 0.9539
# Epoch 170/200
#
# Epoch 170: val_loss did not improve from 0.28549
# 393/393 - 81s - 206ms/step - accuracy: 0.9145 - loss: 0.2735 - top2_accuracy: 0.9673 - val_accuracy: 0.8302 - val_loss: 0.6018 - val_top2_accuracy: 0.9134
# Epoch 171/200
#
# Epoch 171: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9146 - loss: 0.2734 - top2_accuracy: 0.9685 - val_accuracy: 0.9000 - val_loss: 0.3311 - val_top2_accuracy: 0.9562
# Epoch 172/200
#
# Epoch 172: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9191 - loss: 0.2602 - top2_accuracy: 0.9690 - val_accuracy: 0.8328 - val_loss: 0.5529 - val_top2_accuracy: 0.9175
# Epoch 173/200
#
# Epoch 173: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9148 - loss: 0.2694 - top2_accuracy: 0.9673 - val_accuracy: 0.8818 - val_loss: 0.3964 - val_top2_accuracy: 0.9524
# Epoch 174/200
#
# Epoch 174: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9158 - loss: 0.2652 - top2_accuracy: 0.9677 - val_accuracy: 0.8569 - val_loss: 0.4601 - val_top2_accuracy: 0.9454
# Epoch 175/200
#
# Epoch 175: val_loss did not improve from 0.28549
# 393/393 - 138s - 351ms/step - accuracy: 0.9197 - loss: 0.2653 - top2_accuracy: 0.9675 - val_accuracy: 0.8595 - val_loss: 0.4573 - val_top2_accuracy: 0.9327
# Epoch 176/200
#
# Epoch 176: val_loss did not improve from 0.28549
# 393/393 - 82s - 209ms/step - accuracy: 0.9181 - loss: 0.2657 - top2_accuracy: 0.9686 - val_accuracy: 0.8881 - val_loss: 0.3677 - val_top2_accuracy: 0.9521
# Epoch 177/200
#
# Epoch 177: val_loss did not improve from 0.28549
# 393/393 - 78s - 200ms/step - accuracy: 0.9154 - loss: 0.2717 - top2_accuracy: 0.9670 - val_accuracy: 0.9052 - val_loss: 0.3251 - val_top2_accuracy: 0.9584
# Epoch 178/200
#
# Epoch 178: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9154 - loss: 0.2678 - top2_accuracy: 0.9659 - val_accuracy: 0.8562 - val_loss: 0.4718 - val_top2_accuracy: 0.9316
# Epoch 179/200
#
# Epoch 179: val_loss did not improve from 0.28549
# 393/393 - 79s - 200ms/step - accuracy: 0.9179 - loss: 0.2659 - top2_accuracy: 0.9683 - val_accuracy: 0.8826 - val_loss: 0.3813 - val_top2_accuracy: 0.9491
# Epoch 180/200
#
# Epoch 180: val_loss did not improve from 0.28549
# 393/393 - 78s - 199ms/step - accuracy: 0.9172 - loss: 0.2656 - top2_accuracy: 0.9658 - val_accuracy: 0.8926 - val_loss: 0.3561 - val_top2_accuracy: 0.9550
# Epoch 181/200
#
# Epoch 181: val_loss did not improve from 0.28549
# 393/393 - 79s - 201ms/step - accuracy: 0.9151 - loss: 0.2591 - top2_accuracy: 0.9687 - val_accuracy: 0.8941 - val_loss: 0.3809 - val_top2_accuracy: 0.9532
# Epoch 182/200
#
# Epoch 182: val_loss did not improve from 0.28549
# 393/393 - 78s - 199ms/step - accuracy: 0.9185 - loss: 0.2648 - top2_accuracy: 0.9673 - val_accuracy: 0.8744 - val_loss: 0.4036 - val_top2_accuracy: 0.9495
# Epoch 183/200
#
# Epoch 183: val_loss did not improve from 0.28549
# 393/393 - 78s - 199ms/step - accuracy: 0.9182 - loss: 0.2654 - top2_accuracy: 0.9656 - val_accuracy: 0.8948 - val_loss: 0.3486 - val_top2_accuracy: 0.9573
# Epoch 184/200
#
# Epoch 184: val_loss did not improve from 0.28549
# 393/393 - 80s - 204ms/step - accuracy: 0.9232 - loss: 0.2528 - top2_accuracy: 0.9690 - val_accuracy: 0.9119 - val_loss: 0.3129 - val_top2_accuracy: 0.9654
# Epoch 185/200
#
# Epoch 185: val_loss improved from 0.28549 to 0.28401, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 185: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 79s - 200ms/step - accuracy: 0.9161 - loss: 0.2686 - top2_accuracy: 0.9662 - val_accuracy: 0.9130 - val_loss: 0.2840 - val_top2_accuracy: 0.9673
# Epoch 186/200
#
# Epoch 186: val_loss did not improve from 0.28401
# 393/393 - 77s - 195ms/step - accuracy: 0.9183 - loss: 0.2629 - top2_accuracy: 0.9681 - val_accuracy: 0.8796 - val_loss: 0.4170 - val_top2_accuracy: 0.9480
# Epoch 187/200
#
# Epoch 187: val_loss did not improve from 0.28401
# 393/393 - 79s - 202ms/step - accuracy: 0.9201 - loss: 0.2561 - top2_accuracy: 0.9693 - val_accuracy: 0.8963 - val_loss: 0.3488 - val_top2_accuracy: 0.9547
# Epoch 188/200
#
# Epoch 188: val_loss did not improve from 0.28401
# 393/393 - 79s - 201ms/step - accuracy: 0.9193 - loss: 0.2600 - top2_accuracy: 0.9674 - val_accuracy: 0.8933 - val_loss: 0.3811 - val_top2_accuracy: 0.9509
# Epoch 189/200
#
# Epoch 189: val_loss did not improve from 0.28401
# 393/393 - 78s - 200ms/step - accuracy: 0.9222 - loss: 0.2579 - top2_accuracy: 0.9673 - val_accuracy: 0.8161 - val_loss: 0.6105 - val_top2_accuracy: 0.9104
# Epoch 190/200
#
# Epoch 190: val_loss did not improve from 0.28401
# 393/393 - 85s - 215ms/step - accuracy: 0.9243 - loss: 0.2488 - top2_accuracy: 0.9702 - val_accuracy: 0.9149 - val_loss: 0.2960 - val_top2_accuracy: 0.9666
# Epoch 191/200
#
# Epoch 191: val_loss did not improve from 0.28401
# 393/393 - 82s - 209ms/step - accuracy: 0.9174 - loss: 0.2571 - top2_accuracy: 0.9669 - val_accuracy: 0.8283 - val_loss: 0.5988 - val_top2_accuracy: 0.9182
# Epoch 192/200
#
# Epoch 192: val_loss did not improve from 0.28401
# 393/393 - 81s - 206ms/step - accuracy: 0.9232 - loss: 0.2505 - top2_accuracy: 0.9698 - val_accuracy: 0.8863 - val_loss: 0.3696 - val_top2_accuracy: 0.9558
# Epoch 193/200
#
# Epoch 193: val_loss did not improve from 0.28401
# 393/393 - 81s - 205ms/step - accuracy: 0.9217 - loss: 0.2488 - top2_accuracy: 0.9692 - val_accuracy: 0.8662 - val_loss: 0.4368 - val_top2_accuracy: 0.9502
# Epoch 194/200
#
# Epoch 194: val_loss did not improve from 0.28401
# 393/393 - 95s - 242ms/step - accuracy: 0.9181 - loss: 0.2559 - top2_accuracy: 0.9685 - val_accuracy: 0.9041 - val_loss: 0.3347 - val_top2_accuracy: 0.9595
# Epoch 195/200
#
# Epoch 195: val_loss did not improve from 0.28401
# 393/393 - 87s - 222ms/step - accuracy: 0.9205 - loss: 0.2585 - top2_accuracy: 0.9695 - val_accuracy: 0.8759 - val_loss: 0.4102 - val_top2_accuracy: 0.9483
# Epoch 196/200
#
# Epoch 196: val_loss did not improve from 0.28401
# 393/393 - 88s - 224ms/step - accuracy: 0.9170 - loss: 0.2544 - top2_accuracy: 0.9697 - val_accuracy: 0.8335 - val_loss: 0.6418 - val_top2_accuracy: 0.8997
# Epoch 197/200
#
# Epoch 197: val_loss did not improve from 0.28401
# 393/393 - 86s - 219ms/step - accuracy: 0.9180 - loss: 0.2563 - top2_accuracy: 0.9666 - val_accuracy: 0.8766 - val_loss: 0.4405 - val_top2_accuracy: 0.9398
# Epoch 198/200
#
# Epoch 198: val_loss did not improve from 0.28401
# 393/393 - 83s - 212ms/step - accuracy: 0.9220 - loss: 0.2499 - top2_accuracy: 0.9696 - val_accuracy: 0.8870 - val_loss: 0.3561 - val_top2_accuracy: 0.9580
# Epoch 199/200
#
# Epoch 199: val_loss did not improve from 0.28401
# 393/393 - 79s - 200ms/step - accuracy: 0.9195 - loss: 0.2502 - top2_accuracy: 0.9678 - val_accuracy: 0.8904 - val_loss: 0.3878 - val_top2_accuracy: 0.9528
# Epoch 200/200
#
# Epoch 200: val_loss improved from 0.28401 to 0.28194, saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
#
# Epoch 200: finished saving model to /kaggle/working/custom_cnn_clean_split_lanczos_seed12345/best_custom_cnn.keras
# 393/393 - 78s - 198ms/step - accuracy: 0.9233 - loss: 0.2458 - top2_accuracy: 0.9708 - val_accuracy: 0.9160 - val_loss: 0.2819 - val_top2_accuracy: 0.9658
# Restoring model weights from the end of the best epoch: 200.
#
# Training completed.
# Epochs completed: 200
# Best epoch: 200
# Best validation loss: 0.2819381356239319
# Training hours: 4.49341017862161

# %%
fig, axes = plt.subplots(
    1,
    3,
    figsize=(18, 5),
)


axes[0].plot(
    history_df["epoch"],
    history_df["accuracy"],
    label="Training",
)

axes[0].plot(
    history_df["epoch"],
    history_df["val_accuracy"],
    label="Validation",
)

axes[0].set_title("Accuracy")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].grid(alpha=0.3)
axes[0].legend()


axes[1].plot(
    history_df["epoch"],
    history_df["loss"],
    label="Training",
)

axes[1].plot(
    history_df["epoch"],
    history_df["val_loss"],
    label="Validation",
)

axes[1].axvline(
    best_epoch,
    color="red",
    linestyle="--",
    label=f"Best epoch: {best_epoch}",
)

axes[1].set_title("Loss")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].grid(alpha=0.3)
axes[1].legend()


axes[2].plot(
    history_df["epoch"],
    history_df["top2_accuracy"],
    label="Training",
)

axes[2].plot(
    history_df["epoch"],
    history_df["val_top2_accuracy"],
    label="Validation",
)

axes[2].set_title("Top-2 Accuracy")
axes[2].set_xlabel("Epoch")
axes[2].set_ylabel("Top-2 Accuracy")
axes[2].grid(alpha=0.3)
axes[2].legend()


plt.suptitle(
    "Custom CNN — Lanczos",
    fontsize=15,
)

plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "training_curves.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()
plt.close()

# %%
best_model = tf.keras.models.load_model(
    BEST_MODEL_PATH,
    compile=False,
)


test_generator = eval_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)


test_generator.reset()

y_prob = best_model.predict(
    test_generator,
    verbose=1,
)


y_true = np.asarray(
    test_generator.classes,
    dtype=np.int64,
)

y_pred = np.argmax(
    y_prob,
    axis=1,
)


test_loss = float(
    -np.mean(
        np.log(
            np.clip(
                y_prob[
                    np.arange(len(y_true)),
                    y_true,
                ],
                1e-7,
                1.0,
            )
        )
    )
)

test_accuracy = float(
    accuracy_score(
        y_true,
        y_pred,
    )
)

macro_precision = float(
    precision_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_recall = float(
    recall_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_f1 = float(
    f1_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

top2_predictions = np.argsort(
    y_prob,
    axis=1,
)[:, -2:]

top2_accuracy = float(
    np.mean(
        np.any(
            top2_predictions == y_true[:, None],
            axis=1,
        )
    )
)


metrics = {
    "model": "Custom CNN",
    "split": "test",
    "samples": len(y_true),
    "loss": test_loss,
    "accuracy": test_accuracy,
    "macro_precision": macro_precision,
    "macro_recall": macro_recall,
    "macro_f1": macro_f1,
    "top2_accuracy": top2_accuracy,
    "best_epoch": best_epoch,
    "seed": SEED,
}


with open(
    OUTPUT_DIR / "test_metrics.json",
    "w",
) as file:
    json.dump(
        metrics,
        file,
        indent=2,
    )


print("\nTEST RESULTS")

for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# Found 2691 validated image filenames belonging to 35 classes.
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 19s 216ms/step
#
# TEST RESULTS
# model: Custom CNN
# split: test
# samples: 2691
# loss: 0.24189795553684235
# accuracy: 0.9279078409513192
# macro_precision: 0.793683316099097
# macro_recall: 0.7310438638996472
# macro_f1: 0.7438915410366298
# top2_accuracy: 0.9762170196952805
# best_epoch: 200
# seed: 12345

# %%
classification_results = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=CLASS_NAMES,
    output_dict=True,
    zero_division=0,
)


classification_df = (
    pd.DataFrame(classification_results)
    .transpose()
)

classification_df.to_csv(
    OUTPUT_DIR / "classification_report.csv"
)


predictions_df = pd.DataFrame({
    "image_name": [
        Path(path).name
        for path in test_generator.filepaths
    ],
    "true_class": [
        CLASS_NAMES[index]
        for index in y_true
    ],
    "predicted_class": [
        CLASS_NAMES[index]
        for index in y_pred
    ],
    "confidence": np.max(
        y_prob,
        axis=1,
    ),
    "correct": y_true == y_pred,
})


predictions_df.to_csv(
    OUTPUT_DIR / "test_predictions.csv",
    index=False,
)


np.savez_compressed(
    OUTPUT_DIR / "predictions.npz",
    y_true=y_true,
    y_pred=y_pred,
    y_prob=y_prob.astype(np.float32),
    class_names=np.asarray(CLASS_NAMES),
    image_names=np.asarray(
        [
            Path(path).name
            for path in test_generator.filepaths
        ]
    ),
)


print("Classification report saved.")
print("Test predictions saved.")
print("Prediction arrays saved.")
# Out:
# Classification report saved.
# Test predictions saved.
# Prediction arrays saved.

# %%
cm = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
)


cm_normalized = (
    cm.astype(float)
    / np.maximum(
        cm.sum(axis=1, keepdims=True),
        1,
    )
)


support = cm.sum(axis=1)

sort_order = np.argsort(
    support
)[::-1]


cm_sorted = cm[
    sort_order
][:, sort_order]

cm_normalized_sorted = cm_normalized[
    sort_order
][:, sort_order]


class_names_sorted = [
    CLASS_NAMES[index]
    for index in sort_order
]

support_sorted = support[
    sort_order
]


class_labels_with_support = [
    f"{name} ({int(class_support)})"
    for name, class_support in zip(
        class_names_sorted,
        support_sorted,
    )
]


pd.DataFrame(
    cm_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_counts.csv"
)


pd.DataFrame(
    cm_normalized_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_normalized.csv"
)


figure_size = max(
    12,
    0.38 * NUM_CLASSES,
)

plt.figure(
    figsize=(
        figure_size,
        figure_size,
    )
)


image = plt.imshow(
    cm_normalized_sorted,
    interpolation="nearest",
    cmap="Blues",
    vmin=0,
    vmax=1,
)


plt.colorbar(
    image,
    fraction=0.046,
    pad=0.04,
    label="Normalized count",
)


tick_positions = np.arange(
    NUM_CLASSES
)


plt.xticks(
    tick_positions,
    class_names_sorted,
    rotation=90,
    fontsize=7,
)

plt.yticks(
    tick_positions,
    class_labels_with_support,
    fontsize=7,
)


plt.title(
    "Custom CNN - Normalized Confusion Matrix"
)

plt.xlabel(
    "Predicted class"
)

plt.ylabel(
    "True class"
)


for row in range(NUM_CLASSES):
    for column in range(NUM_CLASSES):

        value = cm_normalized_sorted[
            row,
            column,
        ]

        if row == column or value >= 0.05:

            text_color = (
                "white"
                if value >= 0.50
                else "black"
            )

            plt.text(
                column,
                row,
                f"{value:.2f}",
                ha="center",
                va="center",
                color=text_color,
                fontsize=5,
            )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "confusion_matrix_normalized.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
per_class_df = (
    classification_df
    .loc[CLASS_NAMES]
    .reset_index()
    .rename(
        columns={
            "index": "class",
            "f1-score": "f1_score",
        }
    )
)


per_class_df = per_class_df.sort_values(
    "support",
    ascending=False,
)


per_class_df.to_csv(
    OUTPUT_DIR / "per_class_metrics.csv",
    index=False,
)


per_class_df["class_with_support"] = (
    per_class_df.apply(
        lambda row: (
            f"{row['class']} "
            f"({int(row['support'])})"
        ),
        axis=1,
    )
)


heatmap_data = per_class_df.set_index(
    "class_with_support"
)[
    [
        "precision",
        "recall",
        "f1_score",
    ]
]


figure_height = max(
    8,
    0.35 * len(heatmap_data),
)


plt.figure(
    figsize=(
        8,
        figure_height,
    )
)


image = plt.imshow(
    heatmap_data.values,
    aspect="auto",
    vmin=0,
    vmax=1,
    cmap="RdBu",
)


plt.colorbar(
    image,
    label="Score",
)


plt.xticks(
    np.arange(3),
    [
        "Precision",
        "Recall",
        "F1-score",
    ],
)


plt.yticks(
    np.arange(
        len(heatmap_data)
    ),
    heatmap_data.index,
)


plt.title(
    "Custom CNN - Per-Class Metrics"
)

plt.xlabel(
    "Metric"
)

plt.ylabel(
    "Class"
)


for row in range(
    len(heatmap_data)
):
    for column in range(3):

        value = heatmap_data.values[
            row,
            column,
        ]

        text_color = (
            "white"
            if value >= 0.75
            else "black"
        )

        plt.text(
            column,
            row,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontsize=8,
        )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "per_class_metrics.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
run_config = {
    "run_name": RUN_NAME,
    "model": "Custom CNN",
    "training_type": "from scratch",
    "seed": SEED,
    "image_size": list(IMAGE_SIZE),
    "batch_size": BATCH_SIZE,
    "classes": NUM_CLASSES,
    "train_samples": len(train_df),
    "validation_samples": len(val_df),
    "test_samples": len(test_df),
    "learning_rate": LEARNING_RATE,
    "maximum_epochs": MAX_EPOCHS,
    "early_stopping_patience": EARLY_STOPPING_PATIENCE,
    "checkpoint_monitor": "val_loss",
    "loss": "categorical_crossentropy",
    "sampling": "natural",
    "class_weights": None,
    "augmentation": {
        "rotation_range": 180,
        "horizontal_flip": True,
        "vertical_flip": True,
        "zoom_range": 0.20,
        "shear_range": 10,
    },
}


with open(
    OUTPUT_DIR / "run_config.json",
    "w",
) as file:
    json.dump(
        run_config,
        file,
        indent=2,
    )


pd.DataFrame(
    [metrics]
).to_csv(
    OUTPUT_DIR / "summary_metrics.csv",
    index=False,
)


with open(
    OUTPUT_DIR / "model_summary.txt",
    "w",
) as file:

    best_model.summary(
        print_fn=lambda line: file.write(
            line + "\n"
        )
    )


ARCHIVE_PATH = (
    Path("/kaggle/working")
    / f"{RUN_NAME}_results.zip"
)


with zipfile.ZipFile(
    ARCHIVE_PATH,
    "w",
    compression=zipfile.ZIP_DEFLATED,
) as archive:

    for path in sorted(
        OUTPUT_DIR.rglob("*")
    ):
        if path.is_file():

            archive.write(
                path,
                arcname=path.relative_to(
                    OUTPUT_DIR
                ),
            )


print("Final results archive:")
print(ARCHIVE_PATH)

print("\nFiles included:")

for path in sorted(
    OUTPUT_DIR.rglob("*")
):
    if path.is_file():
        print(" -", path.name)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final results archive:
# /kaggle/working/custom_cnn_clean_split_lanczos_seed12345_results.zip
#
# Files included:
#  - best_custom_cnn.keras
#  - classification_report.csv
#  - confusion_matrix_counts.csv
#  - confusion_matrix_normalized.csv
#  - confusion_matrix_normalized.png
#  - model_summary.txt
#  - per_class_metrics.csv
#  - per_class_metrics.png
#  - predictions.npz
#  - run_config.json
#  - summary_metrics.csv
#  - test_metrics.json
#  - test_predictions.csv
#  - training_curves.png
#  - training_history.csv
#  - training_info.json
