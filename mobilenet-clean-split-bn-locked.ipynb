# %%
from pathlib import Path

import hashlib
import json
import random
import time

import numpy as np
import pandas as pd

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    CSVLogger,
)


SEED = 12345

IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 35

FINETUNE_EPOCHS = 400
FINETUNE_PATIENCE = 200
FINETUNE_LEARNING_RATE = 1e-7

RUN_NAME = "mobilenet_clean_split_bn_locked"
OUTPUT_DIR = Path("/kaggle/working") / RUN_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)


print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))

print("\nRun:", RUN_NAME)
print("Image size:", IMAGE_SIZE)
print("Batch size:", BATCH_SIZE)
print("Classes:", NUM_CLASSES)
print("Fine-tuning epochs:", FINETUNE_EPOCHS)
print("Fine-tuning patience:", FINETUNE_PATIENCE)
print("Fine-tuning learning rate:", FINETUNE_LEARNING_RATE)
print("Output directory:", OUTPUT_DIR)
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Run: mobilenet_clean_split_bn_locked
# Image size: (128, 128)
# Batch size: 32
# Classes: 35
# Fine-tuning epochs: 400
# Fine-tuning patience: 200
# Fine-tuning learning rate: 1e-07
# Output directory: /kaggle/working/mobilenet_clean_split_bn_locked

# %%
KAGGLE_INPUT = Path("/kaggle/input")


MANIFEST_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_clean_split_manifest.csv")
)

CLASS_NAMES_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_class_names.json")
)

DATASET_ROOT = next(
    KAGGLE_INPUT.rglob("zooplankton_0p5x")
)

FROZEN_MODEL_PATH = next(
    path
    for path in KAGGLE_INPUT.rglob("best_frozen_model.keras")
    if "mobilenet" in str(path).lower()
)

FROZEN_HISTORY_PATH = next(
    path
    for path in KAGGLE_INPUT.rglob("frozen_history.csv")
    if "mobilenet" in str(path).lower()
)


manifest_df = pd.read_csv(MANIFEST_PATH)

with open(
    CLASS_NAMES_PATH,
    "r",
    encoding="utf-8",
) as file:
    CLASS_NAMES = json.load(file)


manifest_df["filepath"] = manifest_df[
    "relative_filepath"
].apply(
    lambda path: str(DATASET_ROOT / path)
)


train_df = manifest_df[
    manifest_df["split"] == "train"
].copy()

validation_df = manifest_df[
    manifest_df["split"] == "validation"
].copy()

test_df = manifest_df[
    manifest_df["split"] == "test"
].copy()


print("Training:", len(train_df))
print("Validation:", len(validation_df))
print("Test:", len(test_df))
print("Classes:", len(CLASS_NAMES))

print("\nFrozen model:")
print(FROZEN_MODEL_PATH)

print("\nFrozen history:")
print(FROZEN_HISTORY_PATH)
# Out:
# Training: 12558
# Validation: 2691
# Test: 2691
# Classes: 35
#
# Frozen model:
# /kaggle/input/datasets/alexkaggletest/mobilenet-frozen-paper-clean-split-results/mobilenet_verified_head_frozen/best_frozen_model.keras
#
# Frozen history:
# /kaggle/input/datasets/alexkaggletest/mobilenet-frozen-paper-clean-split-results/mobilenet_verified_head_frozen/frozen_history.csv

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.20,
    shear_range=10,
)

eval_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED,
    interpolation="lanczos",
)

validation_generator = eval_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)

test_generator = eval_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)
# Out:
# Found 12558 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.

# %%
model = tf.keras.models.load_model(
    FROZEN_MODEL_PATH
)


validation_generator.reset()

frozen_validation_results = model.evaluate(
    validation_generator,
    return_dict=True,
    verbose=1,
)


print("\nLoaded frozen model:")
print("Loss:", round(frozen_validation_results["loss"], 4))
print("Accuracy:", round(frozen_validation_results["accuracy"], 4))
print(
    "Top-2 accuracy:",
    round(frozen_validation_results["top2_accuracy"], 4),
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786626804.174922      24 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# I0000 00:00:1786626812.985257      70 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 23s 186ms/step - accuracy: 0.9316 - loss: 0.2342 - top2_accuracy: 0.9747
#
# Loaded frozen model:
# Loss: 0.2342
# Accuracy: 0.9316
# Top-2 accuracy: 0.9747

# %%
for layer in model.layers:
    layer.trainable = True


for layer in model.layers:
    if isinstance(
        layer,
        tf.keras.layers.BatchNormalization,
    ):
        layer.trainable = False


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=FINETUNE_LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


batch_normalization_layers = [
    layer
    for layer in model.layers
    if isinstance(
        layer,
        tf.keras.layers.BatchNormalization,
    )
]


print("Total layers:", len(model.layers))

print(
    "Trainable layers:",
    sum(layer.trainable for layer in model.layers),
)

print(
    "BatchNormalization layers:",
    len(batch_normalization_layers),
)

print(
    "Trainable BatchNormalization layers:",
    sum(
        layer.trainable
        for layer in batch_normalization_layers
    ),
)

print(
    "Learning rate:",
    float(model.optimizer.learning_rate.numpy()),
)
# Out:
# Total layers: 93
# Trainable layers: 64
# BatchNormalization layers: 29
# Trainable BatchNormalization layers: 0
# Learning rate: 1.0000000116860974e-07

# %%
BEST_WEIGHTS_PATH = (
    OUTPUT_DIR / "best_finetuned.weights.h5"
)

BEST_MODEL_PATH = (
    OUTPUT_DIR / "best_finetuned_model.keras"
)

FINETUNE_HISTORY_PATH = (
    OUTPUT_DIR / "finetuned_history.csv"
)

MAX_TRAINING_HOURS = 11


class TimeLimitCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        elapsed_hours = (
            time.time() - self.start_time
        ) / 3600

        if elapsed_hours >= MAX_TRAINING_HOURS:
            print(
                "\nTraining stopped safely "
                "because the time limit was reached."
            )

            self.model.stop_training = True


callbacks = [
    ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),

    EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=FINETUNE_PATIENCE,
        restore_best_weights=False,
        verbose=1,
    ),

    CSVLogger(
        str(FINETUNE_HISTORY_PATH)
    ),
    TimeLimitCallback(),
]


print("Best weights:", BEST_WEIGHTS_PATH)
print("Best model:", BEST_MODEL_PATH)
print("Fine-tuning history:", FINETUNE_HISTORY_PATH)

print("\nCheckpoint monitor: val_loss")
print("Early-stopping patience:", FINETUNE_PATIENCE)
# Out:
# Best weights: /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# Best model: /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned_model.keras
# Fine-tuning history: /kaggle/working/mobilenet_clean_split_bn_locked/finetuned_history.csv
#
# Checkpoint monitor: val_loss
# Early-stopping patience: 200

# %%
finetune_start_time = time.time()


history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=FINETUNE_EPOCHS,
    callbacks=callbacks,
    verbose=2,
)


finetune_seconds = time.time() - finetune_start_time
epochs_completed = len(history.history["loss"])


training_time = {
    "epochs_completed": epochs_completed,
    "total_seconds": finetune_seconds,
    "total_hours": finetune_seconds / 3600,
    "average_seconds_per_epoch": (
        finetune_seconds / epochs_completed
    ),
}


with open(
    OUTPUT_DIR / "training_time.json",
    "w",
    encoding="utf-8",
) as file:
    json.dump(
        training_time,
        file,
        indent=2,
    )


print("\nFine-tuning completed")
print("Epochs completed:", epochs_completed)
print(
    "Total hours:",
    round(finetune_seconds / 3600, 2),
)
print(
    "Average seconds per epoch:",
    round(finetune_seconds / epochs_completed, 2),
)
# Out:
# Epoch 1/400
# 2026-08-13 13:13:59.957097: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-13 13:14:00.156490: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-13 13:15:13.074470: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-13 13:15:13.273029: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from None to 0.23452, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 128s - 325ms/step - accuracy: 0.9533 - loss: 0.1419 - top2_accuracy: 0.9880 - val_accuracy: 0.9335 - val_loss: 0.2345 - val_top2_accuracy: 0.9747
# Epoch 2/400
#
# Epoch 2: val_loss improved from 0.23452 to 0.23376, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 72s - 182ms/step - accuracy: 0.9552 - loss: 0.1402 - top2_accuracy: 0.9871 - val_accuracy: 0.9346 - val_loss: 0.2338 - val_top2_accuracy: 0.9744
# Epoch 3/400
#
# Epoch 3: val_loss did not improve from 0.23376
# 393/393 - 71s - 182ms/step - accuracy: 0.9595 - loss: 0.1191 - top2_accuracy: 0.9900 - val_accuracy: 0.9350 - val_loss: 0.2346 - val_top2_accuracy: 0.9751
# Epoch 4/400
#
# Epoch 4: val_loss did not improve from 0.23376
# 393/393 - 70s - 178ms/step - accuracy: 0.9576 - loss: 0.1276 - top2_accuracy: 0.9904 - val_accuracy: 0.9339 - val_loss: 0.2353 - val_top2_accuracy: 0.9770
# Epoch 5/400
#
# Epoch 5: val_loss did not improve from 0.23376
# 393/393 - 69s - 177ms/step - accuracy: 0.9568 - loss: 0.1291 - top2_accuracy: 0.9875 - val_accuracy: 0.9320 - val_loss: 0.2354 - val_top2_accuracy: 0.9762
# Epoch 6/400
#
# Epoch 6: val_loss improved from 0.23376 to 0.23324, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 69s - 177ms/step - accuracy: 0.9568 - loss: 0.1279 - top2_accuracy: 0.9892 - val_accuracy: 0.9335 - val_loss: 0.2332 - val_top2_accuracy: 0.9762
# Epoch 7/400
#
# Epoch 7: val_loss improved from 0.23324 to 0.23320, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 70s - 178ms/step - accuracy: 0.9588 - loss: 0.1273 - top2_accuracy: 0.9882 - val_accuracy: 0.9316 - val_loss: 0.2332 - val_top2_accuracy: 0.9766
# Epoch 8/400
#
# Epoch 8: val_loss did not improve from 0.23320
# 393/393 - 69s - 176ms/step - accuracy: 0.9564 - loss: 0.1282 - top2_accuracy: 0.9892 - val_accuracy: 0.9327 - val_loss: 0.2344 - val_top2_accuracy: 0.9758
# Epoch 9/400
#
# Epoch 9: val_loss improved from 0.23320 to 0.23274, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 9: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 69s - 177ms/step - accuracy: 0.9578 - loss: 0.1227 - top2_accuracy: 0.9896 - val_accuracy: 0.9327 - val_loss: 0.2327 - val_top2_accuracy: 0.9766
# Epoch 10/400
#
# Epoch 10: val_loss improved from 0.23274 to 0.23269, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 10: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 180ms/step - accuracy: 0.9586 - loss: 0.1220 - top2_accuracy: 0.9889 - val_accuracy: 0.9339 - val_loss: 0.2327 - val_top2_accuracy: 0.9770
# Epoch 11/400
#
# Epoch 11: val_loss did not improve from 0.23269
# 393/393 - 69s - 177ms/step - accuracy: 0.9623 - loss: 0.1170 - top2_accuracy: 0.9898 - val_accuracy: 0.9327 - val_loss: 0.2332 - val_top2_accuracy: 0.9770
# Epoch 12/400
#
# Epoch 12: val_loss improved from 0.23269 to 0.23140, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 12: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 70s - 179ms/step - accuracy: 0.9580 - loss: 0.1238 - top2_accuracy: 0.9892 - val_accuracy: 0.9335 - val_loss: 0.2314 - val_top2_accuracy: 0.9770
# Epoch 13/400
#
# Epoch 13: val_loss did not improve from 0.23140
# 393/393 - 69s - 176ms/step - accuracy: 0.9538 - loss: 0.1270 - top2_accuracy: 0.9887 - val_accuracy: 0.9324 - val_loss: 0.2325 - val_top2_accuracy: 0.9770
# Epoch 14/400
#
# Epoch 14: val_loss did not improve from 0.23140
# 393/393 - 70s - 179ms/step - accuracy: 0.9603 - loss: 0.1185 - top2_accuracy: 0.9896 - val_accuracy: 0.9320 - val_loss: 0.2316 - val_top2_accuracy: 0.9770
# Epoch 15/400
#
# Epoch 15: val_loss improved from 0.23140 to 0.23080, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 73s - 185ms/step - accuracy: 0.9597 - loss: 0.1211 - top2_accuracy: 0.9886 - val_accuracy: 0.9316 - val_loss: 0.2308 - val_top2_accuracy: 0.9766
# Epoch 16/400
#
# Epoch 16: val_loss improved from 0.23080 to 0.23073, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 16: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 69s - 176ms/step - accuracy: 0.9613 - loss: 0.1121 - top2_accuracy: 0.9915 - val_accuracy: 0.9339 - val_loss: 0.2307 - val_top2_accuracy: 0.9777
# Epoch 17/400
#
# Epoch 17: val_loss did not improve from 0.23073
# 393/393 - 70s - 179ms/step - accuracy: 0.9600 - loss: 0.1184 - top2_accuracy: 0.9903 - val_accuracy: 0.9335 - val_loss: 0.2320 - val_top2_accuracy: 0.9770
# Epoch 18/400
#
# Epoch 18: val_loss improved from 0.23073 to 0.23050, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 69s - 176ms/step - accuracy: 0.9600 - loss: 0.1209 - top2_accuracy: 0.9893 - val_accuracy: 0.9346 - val_loss: 0.2305 - val_top2_accuracy: 0.9773
# Epoch 19/400
#
# Epoch 19: val_loss improved from 0.23050 to 0.23033, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 19: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 69s - 175ms/step - accuracy: 0.9591 - loss: 0.1199 - top2_accuracy: 0.9908 - val_accuracy: 0.9335 - val_loss: 0.2303 - val_top2_accuracy: 0.9770
# Epoch 20/400
#
# Epoch 20: val_loss did not improve from 0.23033
# 393/393 - 75s - 192ms/step - accuracy: 0.9617 - loss: 0.1169 - top2_accuracy: 0.9910 - val_accuracy: 0.9335 - val_loss: 0.2306 - val_top2_accuracy: 0.9770
# Epoch 21/400
#
# Epoch 21: val_loss did not improve from 0.23033
# 393/393 - 69s - 176ms/step - accuracy: 0.9603 - loss: 0.1217 - top2_accuracy: 0.9889 - val_accuracy: 0.9327 - val_loss: 0.2304 - val_top2_accuracy: 0.9773
# Epoch 22/400
#
# Epoch 22: val_loss did not improve from 0.23033
# 393/393 - 70s - 178ms/step - accuracy: 0.9565 - loss: 0.1215 - top2_accuracy: 0.9892 - val_accuracy: 0.9339 - val_loss: 0.2307 - val_top2_accuracy: 0.9777
# Epoch 23/400
#
# Epoch 23: val_loss did not improve from 0.23033
# 393/393 - 69s - 176ms/step - accuracy: 0.9603 - loss: 0.1126 - top2_accuracy: 0.9901 - val_accuracy: 0.9331 - val_loss: 0.2316 - val_top2_accuracy: 0.9770
# Epoch 24/400
#
# Epoch 24: val_loss did not improve from 0.23033
# 393/393 - 74s - 189ms/step - accuracy: 0.9627 - loss: 0.1134 - top2_accuracy: 0.9907 - val_accuracy: 0.9335 - val_loss: 0.2309 - val_top2_accuracy: 0.9770
# Epoch 25/400
#
# Epoch 25: val_loss did not improve from 0.23033
# 393/393 - 73s - 186ms/step - accuracy: 0.9654 - loss: 0.1080 - top2_accuracy: 0.9902 - val_accuracy: 0.9339 - val_loss: 0.2313 - val_top2_accuracy: 0.9762
# Epoch 26/400
#
# Epoch 26: val_loss improved from 0.23033 to 0.22973, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 26: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 182ms/step - accuracy: 0.9602 - loss: 0.1137 - top2_accuracy: 0.9906 - val_accuracy: 0.9339 - val_loss: 0.2297 - val_top2_accuracy: 0.9766
# Epoch 27/400
#
# Epoch 27: val_loss did not improve from 0.22973
# 393/393 - 70s - 179ms/step - accuracy: 0.9607 - loss: 0.1129 - top2_accuracy: 0.9906 - val_accuracy: 0.9346 - val_loss: 0.2306 - val_top2_accuracy: 0.9762
# Epoch 28/400
#
# Epoch 28: val_loss did not improve from 0.22973
# 393/393 - 70s - 179ms/step - accuracy: 0.9628 - loss: 0.1101 - top2_accuracy: 0.9900 - val_accuracy: 0.9339 - val_loss: 0.2307 - val_top2_accuracy: 0.9758
# Epoch 29/400
#
# Epoch 29: val_loss did not improve from 0.22973
# 393/393 - 70s - 179ms/step - accuracy: 0.9616 - loss: 0.1158 - top2_accuracy: 0.9901 - val_accuracy: 0.9342 - val_loss: 0.2299 - val_top2_accuracy: 0.9777
# Epoch 30/400
#
# Epoch 30: val_loss did not improve from 0.22973
# 393/393 - 74s - 187ms/step - accuracy: 0.9613 - loss: 0.1153 - top2_accuracy: 0.9900 - val_accuracy: 0.9339 - val_loss: 0.2317 - val_top2_accuracy: 0.9766
# Epoch 31/400
#
# Epoch 31: val_loss did not improve from 0.22973
# 393/393 - 72s - 183ms/step - accuracy: 0.9607 - loss: 0.1159 - top2_accuracy: 0.9906 - val_accuracy: 0.9335 - val_loss: 0.2302 - val_top2_accuracy: 0.9766
# Epoch 32/400
#
# Epoch 32: val_loss did not improve from 0.22973
# 393/393 - 71s - 179ms/step - accuracy: 0.9622 - loss: 0.1098 - top2_accuracy: 0.9908 - val_accuracy: 0.9342 - val_loss: 0.2306 - val_top2_accuracy: 0.9766
# Epoch 33/400
#
# Epoch 33: val_loss did not improve from 0.22973
# 393/393 - 70s - 177ms/step - accuracy: 0.9619 - loss: 0.1098 - top2_accuracy: 0.9904 - val_accuracy: 0.9346 - val_loss: 0.2298 - val_top2_accuracy: 0.9770
# Epoch 34/400
#
# Epoch 34: val_loss improved from 0.22973 to 0.22945, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 34: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 181ms/step - accuracy: 0.9623 - loss: 0.1101 - top2_accuracy: 0.9900 - val_accuracy: 0.9353 - val_loss: 0.2295 - val_top2_accuracy: 0.9766
# Epoch 35/400
#
# Epoch 35: val_loss did not improve from 0.22945
# 393/393 - 71s - 182ms/step - accuracy: 0.9615 - loss: 0.1130 - top2_accuracy: 0.9901 - val_accuracy: 0.9361 - val_loss: 0.2299 - val_top2_accuracy: 0.9770
# Epoch 36/400
#
# Epoch 36: val_loss did not improve from 0.22945
# 393/393 - 71s - 182ms/step - accuracy: 0.9638 - loss: 0.1075 - top2_accuracy: 0.9912 - val_accuracy: 0.9346 - val_loss: 0.2297 - val_top2_accuracy: 0.9770
# Epoch 37/400
#
# Epoch 37: val_loss improved from 0.22945 to 0.22920, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 37: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 182ms/step - accuracy: 0.9630 - loss: 0.1100 - top2_accuracy: 0.9907 - val_accuracy: 0.9353 - val_loss: 0.2292 - val_top2_accuracy: 0.9762
# Epoch 38/400
#
# Epoch 38: val_loss did not improve from 0.22920
# 393/393 - 69s - 176ms/step - accuracy: 0.9637 - loss: 0.1111 - top2_accuracy: 0.9916 - val_accuracy: 0.9357 - val_loss: 0.2299 - val_top2_accuracy: 0.9773
# Epoch 39/400
#
# Epoch 39: val_loss did not improve from 0.22920
# 393/393 - 71s - 180ms/step - accuracy: 0.9610 - loss: 0.1098 - top2_accuracy: 0.9904 - val_accuracy: 0.9350 - val_loss: 0.2296 - val_top2_accuracy: 0.9762
# Epoch 40/400
#
# Epoch 40: val_loss improved from 0.22920 to 0.22877, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 40: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 70s - 178ms/step - accuracy: 0.9638 - loss: 0.1107 - top2_accuracy: 0.9916 - val_accuracy: 0.9350 - val_loss: 0.2288 - val_top2_accuracy: 0.9758
# Epoch 41/400
#
# Epoch 41: val_loss improved from 0.22877 to 0.22826, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 41: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 70s - 179ms/step - accuracy: 0.9641 - loss: 0.1079 - top2_accuracy: 0.9908 - val_accuracy: 0.9346 - val_loss: 0.2283 - val_top2_accuracy: 0.9762
# Epoch 42/400
#
# Epoch 42: val_loss did not improve from 0.22826
# 393/393 - 71s - 181ms/step - accuracy: 0.9631 - loss: 0.1102 - top2_accuracy: 0.9907 - val_accuracy: 0.9353 - val_loss: 0.2289 - val_top2_accuracy: 0.9773
# Epoch 43/400
#
# Epoch 43: val_loss improved from 0.22826 to 0.22767, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 43: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 188ms/step - accuracy: 0.9607 - loss: 0.1096 - top2_accuracy: 0.9920 - val_accuracy: 0.9357 - val_loss: 0.2277 - val_top2_accuracy: 0.9770
# Epoch 44/400
#
# Epoch 44: val_loss did not improve from 0.22767
# 393/393 - 72s - 182ms/step - accuracy: 0.9657 - loss: 0.1073 - top2_accuracy: 0.9912 - val_accuracy: 0.9372 - val_loss: 0.2279 - val_top2_accuracy: 0.9770
# Epoch 45/400
#
# Epoch 45: val_loss improved from 0.22767 to 0.22715, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 45: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 180ms/step - accuracy: 0.9635 - loss: 0.1073 - top2_accuracy: 0.9908 - val_accuracy: 0.9379 - val_loss: 0.2271 - val_top2_accuracy: 0.9758
# Epoch 46/400
#
# Epoch 46: val_loss improved from 0.22715 to 0.22642, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 46: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 70s - 178ms/step - accuracy: 0.9615 - loss: 0.1131 - top2_accuracy: 0.9904 - val_accuracy: 0.9357 - val_loss: 0.2264 - val_top2_accuracy: 0.9773
# Epoch 47/400
#
# Epoch 47: val_loss did not improve from 0.22642
# 393/393 - 71s - 181ms/step - accuracy: 0.9628 - loss: 0.1109 - top2_accuracy: 0.9899 - val_accuracy: 0.9361 - val_loss: 0.2272 - val_top2_accuracy: 0.9770
# Epoch 48/400
#
# Epoch 48: val_loss improved from 0.22642 to 0.22584, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 48: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 72s - 184ms/step - accuracy: 0.9619 - loss: 0.1116 - top2_accuracy: 0.9896 - val_accuracy: 0.9368 - val_loss: 0.2258 - val_top2_accuracy: 0.9758
# Epoch 49/400
#
# Epoch 49: val_loss did not improve from 0.22584
# 393/393 - 71s - 181ms/step - accuracy: 0.9659 - loss: 0.1054 - top2_accuracy: 0.9916 - val_accuracy: 0.9368 - val_loss: 0.2272 - val_top2_accuracy: 0.9766
# Epoch 50/400
#
# Epoch 50: val_loss did not improve from 0.22584
# 393/393 - 74s - 189ms/step - accuracy: 0.9635 - loss: 0.1048 - top2_accuracy: 0.9911 - val_accuracy: 0.9368 - val_loss: 0.2275 - val_top2_accuracy: 0.9766
# Epoch 51/400
#
# Epoch 51: val_loss did not improve from 0.22584
# 393/393 - 73s - 187ms/step - accuracy: 0.9650 - loss: 0.1053 - top2_accuracy: 0.9914 - val_accuracy: 0.9376 - val_loss: 0.2273 - val_top2_accuracy: 0.9758
# Epoch 52/400
#
# Epoch 52: val_loss did not improve from 0.22584
# 393/393 - 72s - 184ms/step - accuracy: 0.9666 - loss: 0.1034 - top2_accuracy: 0.9914 - val_accuracy: 0.9368 - val_loss: 0.2261 - val_top2_accuracy: 0.9777
# Epoch 53/400
#
# Epoch 53: val_loss did not improve from 0.22584
# 393/393 - 72s - 182ms/step - accuracy: 0.9658 - loss: 0.1028 - top2_accuracy: 0.9920 - val_accuracy: 0.9353 - val_loss: 0.2261 - val_top2_accuracy: 0.9770
# Epoch 54/400
#
# Epoch 54: val_loss did not improve from 0.22584
# 393/393 - 72s - 184ms/step - accuracy: 0.9637 - loss: 0.1017 - top2_accuracy: 0.9915 - val_accuracy: 0.9357 - val_loss: 0.2265 - val_top2_accuracy: 0.9770
# Epoch 55/400
#
# Epoch 55: val_loss did not improve from 0.22584
# 393/393 - 73s - 186ms/step - accuracy: 0.9665 - loss: 0.1028 - top2_accuracy: 0.9923 - val_accuracy: 0.9368 - val_loss: 0.2270 - val_top2_accuracy: 0.9777
# Epoch 56/400
#
# Epoch 56: val_loss did not improve from 0.22584
# 393/393 - 75s - 191ms/step - accuracy: 0.9642 - loss: 0.1033 - top2_accuracy: 0.9904 - val_accuracy: 0.9368 - val_loss: 0.2270 - val_top2_accuracy: 0.9773
# Epoch 57/400
#
# Epoch 57: val_loss did not improve from 0.22584
# 393/393 - 79s - 200ms/step - accuracy: 0.9638 - loss: 0.1041 - top2_accuracy: 0.9917 - val_accuracy: 0.9365 - val_loss: 0.2259 - val_top2_accuracy: 0.9762
# Epoch 58/400
#
# Epoch 58: val_loss did not improve from 0.22584
# 393/393 - 72s - 182ms/step - accuracy: 0.9650 - loss: 0.1020 - top2_accuracy: 0.9920 - val_accuracy: 0.9372 - val_loss: 0.2259 - val_top2_accuracy: 0.9773
# Epoch 59/400
#
# Epoch 59: val_loss did not improve from 0.22584
# 393/393 - 70s - 179ms/step - accuracy: 0.9646 - loss: 0.1041 - top2_accuracy: 0.9910 - val_accuracy: 0.9372 - val_loss: 0.2261 - val_top2_accuracy: 0.9777
# Epoch 60/400
#
# Epoch 60: val_loss did not improve from 0.22584
# 393/393 - 70s - 177ms/step - accuracy: 0.9664 - loss: 0.1000 - top2_accuracy: 0.9909 - val_accuracy: 0.9372 - val_loss: 0.2260 - val_top2_accuracy: 0.9777
# Epoch 61/400
#
# Epoch 61: val_loss did not improve from 0.22584
# 393/393 - 71s - 180ms/step - accuracy: 0.9690 - loss: 0.0963 - top2_accuracy: 0.9924 - val_accuracy: 0.9357 - val_loss: 0.2270 - val_top2_accuracy: 0.9784
# Epoch 62/400
#
# Epoch 62: val_loss improved from 0.22584 to 0.22560, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 62: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 180ms/step - accuracy: 0.9663 - loss: 0.0993 - top2_accuracy: 0.9932 - val_accuracy: 0.9376 - val_loss: 0.2256 - val_top2_accuracy: 0.9773
# Epoch 63/400
#
# Epoch 63: val_loss improved from 0.22560 to 0.22555, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 63: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 71s - 182ms/step - accuracy: 0.9649 - loss: 0.1036 - top2_accuracy: 0.9916 - val_accuracy: 0.9368 - val_loss: 0.2256 - val_top2_accuracy: 0.9781
# Epoch 64/400
#
# Epoch 64: val_loss did not improve from 0.22555
# 393/393 - 72s - 183ms/step - accuracy: 0.9653 - loss: 0.0995 - top2_accuracy: 0.9910 - val_accuracy: 0.9368 - val_loss: 0.2259 - val_top2_accuracy: 0.9777
# Epoch 65/400
#
# Epoch 65: val_loss did not improve from 0.22555
# 393/393 - 72s - 184ms/step - accuracy: 0.9672 - loss: 0.0986 - top2_accuracy: 0.9908 - val_accuracy: 0.9353 - val_loss: 0.2263 - val_top2_accuracy: 0.9784
# Epoch 66/400
#
# Epoch 66: val_loss did not improve from 0.22555
# 393/393 - 72s - 184ms/step - accuracy: 0.9671 - loss: 0.0998 - top2_accuracy: 0.9923 - val_accuracy: 0.9350 - val_loss: 0.2263 - val_top2_accuracy: 0.9770
# Epoch 67/400
#
# Epoch 67: val_loss did not improve from 0.22555
# 393/393 - 73s - 187ms/step - accuracy: 0.9654 - loss: 0.1043 - top2_accuracy: 0.9924 - val_accuracy: 0.9365 - val_loss: 0.2257 - val_top2_accuracy: 0.9777
# Epoch 68/400
#
# Epoch 68: val_loss did not improve from 0.22555
# 393/393 - 72s - 183ms/step - accuracy: 0.9654 - loss: 0.1012 - top2_accuracy: 0.9915 - val_accuracy: 0.9353 - val_loss: 0.2267 - val_top2_accuracy: 0.9784
# Epoch 69/400
#
# Epoch 69: val_loss did not improve from 0.22555
# 393/393 - 72s - 184ms/step - accuracy: 0.9677 - loss: 0.0996 - top2_accuracy: 0.9929 - val_accuracy: 0.9368 - val_loss: 0.2267 - val_top2_accuracy: 0.9777
# Epoch 70/400
#
# Epoch 70: val_loss did not improve from 0.22555
# 393/393 - 72s - 184ms/step - accuracy: 0.9642 - loss: 0.1034 - top2_accuracy: 0.9916 - val_accuracy: 0.9361 - val_loss: 0.2266 - val_top2_accuracy: 0.9781
# Epoch 71/400
#
# Epoch 71: val_loss did not improve from 0.22555
# 393/393 - 72s - 182ms/step - accuracy: 0.9654 - loss: 0.1028 - top2_accuracy: 0.9914 - val_accuracy: 0.9357 - val_loss: 0.2261 - val_top2_accuracy: 0.9784
# Epoch 72/400
#
# Epoch 72: val_loss did not improve from 0.22555
# 393/393 - 74s - 187ms/step - accuracy: 0.9670 - loss: 0.0989 - top2_accuracy: 0.9925 - val_accuracy: 0.9346 - val_loss: 0.2270 - val_top2_accuracy: 0.9781
# Epoch 73/400
#
# Epoch 73: val_loss did not improve from 0.22555
# 393/393 - 77s - 196ms/step - accuracy: 0.9674 - loss: 0.0949 - top2_accuracy: 0.9923 - val_accuracy: 0.9357 - val_loss: 0.2282 - val_top2_accuracy: 0.9773
# Epoch 74/400
#
# Epoch 74: val_loss did not improve from 0.22555
# 393/393 - 74s - 189ms/step - accuracy: 0.9641 - loss: 0.0997 - top2_accuracy: 0.9917 - val_accuracy: 0.9372 - val_loss: 0.2276 - val_top2_accuracy: 0.9770
# Epoch 75/400
#
# Epoch 75: val_loss did not improve from 0.22555
# 393/393 - 75s - 191ms/step - accuracy: 0.9681 - loss: 0.0960 - top2_accuracy: 0.9919 - val_accuracy: 0.9365 - val_loss: 0.2264 - val_top2_accuracy: 0.9770
# Epoch 76/400
#
# Epoch 76: val_loss did not improve from 0.22555
# 393/393 - 74s - 188ms/step - accuracy: 0.9678 - loss: 0.0997 - top2_accuracy: 0.9916 - val_accuracy: 0.9361 - val_loss: 0.2268 - val_top2_accuracy: 0.9777
# Epoch 77/400
#
# Epoch 77: val_loss did not improve from 0.22555
# 393/393 - 73s - 186ms/step - accuracy: 0.9655 - loss: 0.0995 - top2_accuracy: 0.9931 - val_accuracy: 0.9368 - val_loss: 0.2260 - val_top2_accuracy: 0.9781
# Epoch 78/400
#
# Epoch 78: val_loss did not improve from 0.22555
# 393/393 - 75s - 191ms/step - accuracy: 0.9675 - loss: 0.0977 - top2_accuracy: 0.9928 - val_accuracy: 0.9376 - val_loss: 0.2258 - val_top2_accuracy: 0.9777
# Epoch 79/400
#
# Epoch 79: val_loss improved from 0.22555 to 0.22493, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 79: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 75s - 191ms/step - accuracy: 0.9679 - loss: 0.0991 - top2_accuracy: 0.9922 - val_accuracy: 0.9368 - val_loss: 0.2249 - val_top2_accuracy: 0.9777
# Epoch 80/400
#
# Epoch 80: val_loss did not improve from 0.22493
# 393/393 - 74s - 188ms/step - accuracy: 0.9649 - loss: 0.0993 - top2_accuracy: 0.9924 - val_accuracy: 0.9376 - val_loss: 0.2255 - val_top2_accuracy: 0.9781
# Epoch 81/400
#
# Epoch 81: val_loss did not improve from 0.22493
# 393/393 - 74s - 188ms/step - accuracy: 0.9695 - loss: 0.0918 - top2_accuracy: 0.9935 - val_accuracy: 0.9368 - val_loss: 0.2263 - val_top2_accuracy: 0.9781
# Epoch 82/400
#
# Epoch 82: val_loss did not improve from 0.22493
# 393/393 - 74s - 189ms/step - accuracy: 0.9663 - loss: 0.1015 - top2_accuracy: 0.9908 - val_accuracy: 0.9376 - val_loss: 0.2255 - val_top2_accuracy: 0.9777
# Epoch 83/400
#
# Epoch 83: val_loss did not improve from 0.22493
# 393/393 - 74s - 189ms/step - accuracy: 0.9660 - loss: 0.0961 - top2_accuracy: 0.9922 - val_accuracy: 0.9368 - val_loss: 0.2263 - val_top2_accuracy: 0.9781
# Epoch 84/400
#
# Epoch 84: val_loss did not improve from 0.22493
# 393/393 - 73s - 186ms/step - accuracy: 0.9667 - loss: 0.0978 - top2_accuracy: 0.9923 - val_accuracy: 0.9372 - val_loss: 0.2250 - val_top2_accuracy: 0.9773
# Epoch 85/400
#
# Epoch 85: val_loss did not improve from 0.22493
# 393/393 - 73s - 185ms/step - accuracy: 0.9679 - loss: 0.0938 - top2_accuracy: 0.9925 - val_accuracy: 0.9368 - val_loss: 0.2260 - val_top2_accuracy: 0.9777
# Epoch 86/400
#
# Epoch 86: val_loss did not improve from 0.22493
# 393/393 - 73s - 185ms/step - accuracy: 0.9661 - loss: 0.0978 - top2_accuracy: 0.9920 - val_accuracy: 0.9376 - val_loss: 0.2264 - val_top2_accuracy: 0.9777
# Epoch 87/400
#
# Epoch 87: val_loss did not improve from 0.22493
# 393/393 - 74s - 187ms/step - accuracy: 0.9685 - loss: 0.0924 - top2_accuracy: 0.9932 - val_accuracy: 0.9376 - val_loss: 0.2251 - val_top2_accuracy: 0.9781
# Epoch 88/400
#
# Epoch 88: val_loss improved from 0.22493 to 0.22483, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 88: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 75s - 190ms/step - accuracy: 0.9696 - loss: 0.0953 - top2_accuracy: 0.9927 - val_accuracy: 0.9368 - val_loss: 0.2248 - val_top2_accuracy: 0.9781
# Epoch 89/400
#
# Epoch 89: val_loss did not improve from 0.22483
# 393/393 - 73s - 186ms/step - accuracy: 0.9685 - loss: 0.0903 - top2_accuracy: 0.9933 - val_accuracy: 0.9379 - val_loss: 0.2264 - val_top2_accuracy: 0.9777
# Epoch 90/400
#
# Epoch 90: val_loss did not improve from 0.22483
# 393/393 - 73s - 186ms/step - accuracy: 0.9650 - loss: 0.0993 - top2_accuracy: 0.9917 - val_accuracy: 0.9372 - val_loss: 0.2254 - val_top2_accuracy: 0.9781
# Epoch 91/400
#
# Epoch 91: val_loss did not improve from 0.22483
# 393/393 - 73s - 187ms/step - accuracy: 0.9670 - loss: 0.0981 - top2_accuracy: 0.9917 - val_accuracy: 0.9368 - val_loss: 0.2250 - val_top2_accuracy: 0.9784
# Epoch 92/400
#
# Epoch 92: val_loss did not improve from 0.22483
# 393/393 - 75s - 190ms/step - accuracy: 0.9684 - loss: 0.0956 - top2_accuracy: 0.9931 - val_accuracy: 0.9372 - val_loss: 0.2250 - val_top2_accuracy: 0.9792
# Epoch 93/400
#
# Epoch 93: val_loss did not improve from 0.22483
# 393/393 - 74s - 188ms/step - accuracy: 0.9683 - loss: 0.0942 - top2_accuracy: 0.9935 - val_accuracy: 0.9376 - val_loss: 0.2260 - val_top2_accuracy: 0.9773
# Epoch 94/400
#
# Epoch 94: val_loss did not improve from 0.22483
# 393/393 - 73s - 185ms/step - accuracy: 0.9680 - loss: 0.0980 - top2_accuracy: 0.9919 - val_accuracy: 0.9376 - val_loss: 0.2263 - val_top2_accuracy: 0.9773
# Epoch 95/400
#
# Epoch 95: val_loss did not improve from 0.22483
# 393/393 - 74s - 188ms/step - accuracy: 0.9704 - loss: 0.0897 - top2_accuracy: 0.9939 - val_accuracy: 0.9376 - val_loss: 0.2254 - val_top2_accuracy: 0.9770
# Epoch 96/400
#
# Epoch 96: val_loss did not improve from 0.22483
# 393/393 - 74s - 187ms/step - accuracy: 0.9667 - loss: 0.0944 - top2_accuracy: 0.9930 - val_accuracy: 0.9368 - val_loss: 0.2261 - val_top2_accuracy: 0.9770
# Epoch 97/400
#
# Epoch 97: val_loss did not improve from 0.22483
# 393/393 - 73s - 186ms/step - accuracy: 0.9708 - loss: 0.0915 - top2_accuracy: 0.9922 - val_accuracy: 0.9368 - val_loss: 0.2251 - val_top2_accuracy: 0.9762
# Epoch 98/400
#
# Epoch 98: val_loss did not improve from 0.22483
# 393/393 - 72s - 184ms/step - accuracy: 0.9692 - loss: 0.0928 - top2_accuracy: 0.9933 - val_accuracy: 0.9376 - val_loss: 0.2258 - val_top2_accuracy: 0.9766
# Epoch 99/400
#
# Epoch 99: val_loss did not improve from 0.22483
# 393/393 - 74s - 189ms/step - accuracy: 0.9713 - loss: 0.0889 - top2_accuracy: 0.9936 - val_accuracy: 0.9383 - val_loss: 0.2253 - val_top2_accuracy: 0.9773
# Epoch 100/400
#
# Epoch 100: val_loss did not improve from 0.22483
# 393/393 - 72s - 184ms/step - accuracy: 0.9691 - loss: 0.0912 - top2_accuracy: 0.9939 - val_accuracy: 0.9379 - val_loss: 0.2253 - val_top2_accuracy: 0.9777
# Epoch 101/400
#
# Epoch 101: val_loss did not improve from 0.22483
# 393/393 - 71s - 181ms/step - accuracy: 0.9692 - loss: 0.0925 - top2_accuracy: 0.9940 - val_accuracy: 0.9376 - val_loss: 0.2258 - val_top2_accuracy: 0.9770
# Epoch 102/400
#
# Epoch 102: val_loss improved from 0.22483 to 0.22466, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 102: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 187ms/step - accuracy: 0.9677 - loss: 0.0942 - top2_accuracy: 0.9930 - val_accuracy: 0.9379 - val_loss: 0.2247 - val_top2_accuracy: 0.9773
# Epoch 103/400
#
# Epoch 103: val_loss did not improve from 0.22466
# 393/393 - 72s - 183ms/step - accuracy: 0.9674 - loss: 0.0971 - top2_accuracy: 0.9920 - val_accuracy: 0.9387 - val_loss: 0.2259 - val_top2_accuracy: 0.9773
# Epoch 104/400
#
# Epoch 104: val_loss did not improve from 0.22466
# 393/393 - 71s - 182ms/step - accuracy: 0.9709 - loss: 0.0856 - top2_accuracy: 0.9934 - val_accuracy: 0.9372 - val_loss: 0.2257 - val_top2_accuracy: 0.9781
# Epoch 105/400
#
# Epoch 105: val_loss did not improve from 0.22466
# 393/393 - 72s - 183ms/step - accuracy: 0.9675 - loss: 0.0968 - top2_accuracy: 0.9932 - val_accuracy: 0.9361 - val_loss: 0.2254 - val_top2_accuracy: 0.9781
# Epoch 106/400
#
# Epoch 106: val_loss did not improve from 0.22466
# 393/393 - 72s - 182ms/step - accuracy: 0.9700 - loss: 0.0891 - top2_accuracy: 0.9930 - val_accuracy: 0.9372 - val_loss: 0.2256 - val_top2_accuracy: 0.9777
# Epoch 107/400
#
# Epoch 107: val_loss did not improve from 0.22466
# 393/393 - 74s - 187ms/step - accuracy: 0.9688 - loss: 0.0892 - top2_accuracy: 0.9935 - val_accuracy: 0.9368 - val_loss: 0.2259 - val_top2_accuracy: 0.9773
# Epoch 108/400
#
# Epoch 108: val_loss did not improve from 0.22466
# 393/393 - 73s - 186ms/step - accuracy: 0.9689 - loss: 0.0907 - top2_accuracy: 0.9931 - val_accuracy: 0.9379 - val_loss: 0.2251 - val_top2_accuracy: 0.9777
# Epoch 109/400
#
# Epoch 109: val_loss improved from 0.22466 to 0.22431, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 109: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 188ms/step - accuracy: 0.9702 - loss: 0.0887 - top2_accuracy: 0.9916 - val_accuracy: 0.9379 - val_loss: 0.2243 - val_top2_accuracy: 0.9777
# Epoch 110/400
#
# Epoch 110: val_loss did not improve from 0.22431
# 393/393 - 73s - 186ms/step - accuracy: 0.9713 - loss: 0.0892 - top2_accuracy: 0.9936 - val_accuracy: 0.9387 - val_loss: 0.2246 - val_top2_accuracy: 0.9781
# Epoch 111/400
#
# Epoch 111: val_loss did not improve from 0.22431
# 393/393 - 72s - 184ms/step - accuracy: 0.9685 - loss: 0.0891 - top2_accuracy: 0.9928 - val_accuracy: 0.9376 - val_loss: 0.2257 - val_top2_accuracy: 0.9773
# Epoch 112/400
#
# Epoch 112: val_loss did not improve from 0.22431
# 393/393 - 79s - 200ms/step - accuracy: 0.9698 - loss: 0.0901 - top2_accuracy: 0.9932 - val_accuracy: 0.9383 - val_loss: 0.2253 - val_top2_accuracy: 0.9781
# Epoch 113/400
#
# Epoch 113: val_loss did not improve from 0.22431
# 393/393 - 73s - 185ms/step - accuracy: 0.9714 - loss: 0.0859 - top2_accuracy: 0.9947 - val_accuracy: 0.9387 - val_loss: 0.2250 - val_top2_accuracy: 0.9773
# Epoch 114/400
#
# Epoch 114: val_loss did not improve from 0.22431
# 393/393 - 72s - 184ms/step - accuracy: 0.9696 - loss: 0.0871 - top2_accuracy: 0.9939 - val_accuracy: 0.9391 - val_loss: 0.2252 - val_top2_accuracy: 0.9784
# Epoch 115/400
#
# Epoch 115: val_loss did not improve from 0.22431
# 393/393 - 73s - 185ms/step - accuracy: 0.9687 - loss: 0.0894 - top2_accuracy: 0.9925 - val_accuracy: 0.9387 - val_loss: 0.2251 - val_top2_accuracy: 0.9781
# Epoch 116/400
#
# Epoch 116: val_loss did not improve from 0.22431
# 393/393 - 74s - 188ms/step - accuracy: 0.9708 - loss: 0.0895 - top2_accuracy: 0.9932 - val_accuracy: 0.9372 - val_loss: 0.2257 - val_top2_accuracy: 0.9770
# Epoch 117/400
#
# Epoch 117: val_loss did not improve from 0.22431
# 393/393 - 72s - 184ms/step - accuracy: 0.9700 - loss: 0.0901 - top2_accuracy: 0.9924 - val_accuracy: 0.9379 - val_loss: 0.2250 - val_top2_accuracy: 0.9777
# Epoch 118/400
#
# Epoch 118: val_loss did not improve from 0.22431
# 393/393 - 71s - 182ms/step - accuracy: 0.9728 - loss: 0.0851 - top2_accuracy: 0.9932 - val_accuracy: 0.9368 - val_loss: 0.2253 - val_top2_accuracy: 0.9766
# Epoch 119/400
#
# Epoch 119: val_loss did not improve from 0.22431
# 393/393 - 72s - 183ms/step - accuracy: 0.9700 - loss: 0.0898 - top2_accuracy: 0.9933 - val_accuracy: 0.9391 - val_loss: 0.2261 - val_top2_accuracy: 0.9777
# Epoch 120/400
#
# Epoch 120: val_loss did not improve from 0.22431
# 393/393 - 72s - 182ms/step - accuracy: 0.9695 - loss: 0.0900 - top2_accuracy: 0.9940 - val_accuracy: 0.9372 - val_loss: 0.2271 - val_top2_accuracy: 0.9773
# Epoch 121/400
#
# Epoch 121: val_loss did not improve from 0.22431
# 393/393 - 72s - 184ms/step - accuracy: 0.9687 - loss: 0.0881 - top2_accuracy: 0.9942 - val_accuracy: 0.9372 - val_loss: 0.2263 - val_top2_accuracy: 0.9773
# Epoch 122/400
#
# Epoch 122: val_loss did not improve from 0.22431
# 393/393 - 73s - 186ms/step - accuracy: 0.9710 - loss: 0.0877 - top2_accuracy: 0.9937 - val_accuracy: 0.9383 - val_loss: 0.2252 - val_top2_accuracy: 0.9781
# Epoch 123/400
#
# Epoch 123: val_loss did not improve from 0.22431
# 393/393 - 73s - 184ms/step - accuracy: 0.9717 - loss: 0.0848 - top2_accuracy: 0.9935 - val_accuracy: 0.9361 - val_loss: 0.2254 - val_top2_accuracy: 0.9781
# Epoch 124/400
#
# Epoch 124: val_loss did not improve from 0.22431
# 393/393 - 73s - 185ms/step - accuracy: 0.9709 - loss: 0.0866 - top2_accuracy: 0.9930 - val_accuracy: 0.9372 - val_loss: 0.2253 - val_top2_accuracy: 0.9773
# Epoch 125/400
#
# Epoch 125: val_loss did not improve from 0.22431
# 393/393 - 72s - 183ms/step - accuracy: 0.9707 - loss: 0.0873 - top2_accuracy: 0.9921 - val_accuracy: 0.9372 - val_loss: 0.2251 - val_top2_accuracy: 0.9777
# Epoch 126/400
#
# Epoch 126: val_loss improved from 0.22431 to 0.22421, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 126: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 73s - 185ms/step - accuracy: 0.9689 - loss: 0.0925 - top2_accuracy: 0.9930 - val_accuracy: 0.9387 - val_loss: 0.2242 - val_top2_accuracy: 0.9773
# Epoch 127/400
#
# Epoch 127: val_loss did not improve from 0.22421
# 393/393 - 72s - 184ms/step - accuracy: 0.9724 - loss: 0.0881 - top2_accuracy: 0.9929 - val_accuracy: 0.9398 - val_loss: 0.2256 - val_top2_accuracy: 0.9770
# Epoch 128/400
#
# Epoch 128: val_loss did not improve from 0.22421
# 393/393 - 72s - 183ms/step - accuracy: 0.9729 - loss: 0.0804 - top2_accuracy: 0.9935 - val_accuracy: 0.9379 - val_loss: 0.2260 - val_top2_accuracy: 0.9766
# Epoch 129/400
#
# Epoch 129: val_loss did not improve from 0.22421
# 393/393 - 71s - 182ms/step - accuracy: 0.9708 - loss: 0.0869 - top2_accuracy: 0.9934 - val_accuracy: 0.9383 - val_loss: 0.2257 - val_top2_accuracy: 0.9773
# Epoch 130/400
#
# Epoch 130: val_loss did not improve from 0.22421
# 393/393 - 71s - 180ms/step - accuracy: 0.9736 - loss: 0.0822 - top2_accuracy: 0.9940 - val_accuracy: 0.9383 - val_loss: 0.2251 - val_top2_accuracy: 0.9777
# Epoch 131/400
#
# Epoch 131: val_loss did not improve from 0.22421
# 393/393 - 71s - 182ms/step - accuracy: 0.9717 - loss: 0.0857 - top2_accuracy: 0.9937 - val_accuracy: 0.9379 - val_loss: 0.2255 - val_top2_accuracy: 0.9777
# Epoch 132/400
#
# Epoch 132: val_loss did not improve from 0.22421
# 393/393 - 72s - 184ms/step - accuracy: 0.9698 - loss: 0.0902 - top2_accuracy: 0.9931 - val_accuracy: 0.9379 - val_loss: 0.2254 - val_top2_accuracy: 0.9777
# Epoch 133/400
#
# Epoch 133: val_loss did not improve from 0.22421
# 393/393 - 72s - 183ms/step - accuracy: 0.9728 - loss: 0.0834 - top2_accuracy: 0.9934 - val_accuracy: 0.9368 - val_loss: 0.2249 - val_top2_accuracy: 0.9781
# Epoch 134/400
#
# Epoch 134: val_loss did not improve from 0.22421
# 393/393 - 73s - 186ms/step - accuracy: 0.9716 - loss: 0.0836 - top2_accuracy: 0.9934 - val_accuracy: 0.9372 - val_loss: 0.2258 - val_top2_accuracy: 0.9781
# Epoch 135/400
#
# Epoch 135: val_loss did not improve from 0.22421
# 393/393 - 73s - 186ms/step - accuracy: 0.9691 - loss: 0.0863 - top2_accuracy: 0.9935 - val_accuracy: 0.9376 - val_loss: 0.2260 - val_top2_accuracy: 0.9784
# Epoch 136/400
#
# Epoch 136: val_loss did not improve from 0.22421
# 393/393 - 74s - 189ms/step - accuracy: 0.9717 - loss: 0.0837 - top2_accuracy: 0.9947 - val_accuracy: 0.9379 - val_loss: 0.2251 - val_top2_accuracy: 0.9792
# Epoch 137/400
#
# Epoch 137: val_loss did not improve from 0.22421
# 393/393 - 74s - 188ms/step - accuracy: 0.9722 - loss: 0.0855 - top2_accuracy: 0.9944 - val_accuracy: 0.9379 - val_loss: 0.2245 - val_top2_accuracy: 0.9784
# Epoch 138/400
#
# Epoch 138: val_loss did not improve from 0.22421
# 393/393 - 73s - 186ms/step - accuracy: 0.9713 - loss: 0.0820 - top2_accuracy: 0.9942 - val_accuracy: 0.9368 - val_loss: 0.2256 - val_top2_accuracy: 0.9781
# Epoch 139/400
#
# Epoch 139: val_loss did not improve from 0.22421
# 393/393 - 73s - 187ms/step - accuracy: 0.9709 - loss: 0.0864 - top2_accuracy: 0.9938 - val_accuracy: 0.9372 - val_loss: 0.2248 - val_top2_accuracy: 0.9781
# Epoch 140/400
#
# Epoch 140: val_loss did not improve from 0.22421
# 393/393 - 73s - 185ms/step - accuracy: 0.9740 - loss: 0.0770 - top2_accuracy: 0.9947 - val_accuracy: 0.9365 - val_loss: 0.2246 - val_top2_accuracy: 0.9784
# Epoch 141/400
#
# Epoch 141: val_loss did not improve from 0.22421
# 393/393 - 74s - 188ms/step - accuracy: 0.9736 - loss: 0.0820 - top2_accuracy: 0.9934 - val_accuracy: 0.9383 - val_loss: 0.2249 - val_top2_accuracy: 0.9788
# Epoch 142/400
#
# Epoch 142: val_loss did not improve from 0.22421
# 393/393 - 75s - 192ms/step - accuracy: 0.9724 - loss: 0.0832 - top2_accuracy: 0.9933 - val_accuracy: 0.9387 - val_loss: 0.2242 - val_top2_accuracy: 0.9788
# Epoch 143/400
#
# Epoch 143: val_loss did not improve from 0.22421
# 393/393 - 73s - 187ms/step - accuracy: 0.9713 - loss: 0.0835 - top2_accuracy: 0.9936 - val_accuracy: 0.9391 - val_loss: 0.2243 - val_top2_accuracy: 0.9781
# Epoch 144/400
#
# Epoch 144: val_loss did not improve from 0.22421
# 393/393 - 73s - 187ms/step - accuracy: 0.9724 - loss: 0.0815 - top2_accuracy: 0.9943 - val_accuracy: 0.9394 - val_loss: 0.2248 - val_top2_accuracy: 0.9788
# Epoch 145/400
#
# Epoch 145: val_loss did not improve from 0.22421
# 393/393 - 73s - 185ms/step - accuracy: 0.9723 - loss: 0.0814 - top2_accuracy: 0.9937 - val_accuracy: 0.9387 - val_loss: 0.2249 - val_top2_accuracy: 0.9784
# Epoch 146/400
#
# Epoch 146: val_loss did not improve from 0.22421
# 393/393 - 74s - 187ms/step - accuracy: 0.9716 - loss: 0.0818 - top2_accuracy: 0.9932 - val_accuracy: 0.9398 - val_loss: 0.2244 - val_top2_accuracy: 0.9781
# Epoch 147/400
#
# Epoch 147: val_loss did not improve from 0.22421
# 393/393 - 73s - 187ms/step - accuracy: 0.9735 - loss: 0.0774 - top2_accuracy: 0.9947 - val_accuracy: 0.9391 - val_loss: 0.2253 - val_top2_accuracy: 0.9770
# Epoch 148/400
#
# Epoch 148: val_loss did not improve from 0.22421
# 393/393 - 73s - 186ms/step - accuracy: 0.9746 - loss: 0.0796 - top2_accuracy: 0.9940 - val_accuracy: 0.9387 - val_loss: 0.2255 - val_top2_accuracy: 0.9781
# Epoch 149/400
#
# Epoch 149: val_loss did not improve from 0.22421
# 393/393 - 74s - 188ms/step - accuracy: 0.9723 - loss: 0.0836 - top2_accuracy: 0.9939 - val_accuracy: 0.9383 - val_loss: 0.2262 - val_top2_accuracy: 0.9781
# Epoch 150/400
#
# Epoch 150: val_loss did not improve from 0.22421
# 393/393 - 81s - 207ms/step - accuracy: 0.9738 - loss: 0.0783 - top2_accuracy: 0.9944 - val_accuracy: 0.9379 - val_loss: 0.2263 - val_top2_accuracy: 0.9777
# Epoch 151/400
#
# Epoch 151: val_loss did not improve from 0.22421
# 393/393 - 77s - 196ms/step - accuracy: 0.9734 - loss: 0.0805 - top2_accuracy: 0.9943 - val_accuracy: 0.9387 - val_loss: 0.2266 - val_top2_accuracy: 0.9770
# Epoch 152/400
#
# Epoch 152: val_loss did not improve from 0.22421
# 393/393 - 97s - 247ms/step - accuracy: 0.9708 - loss: 0.0848 - top2_accuracy: 0.9932 - val_accuracy: 0.9387 - val_loss: 0.2265 - val_top2_accuracy: 0.9770
# Epoch 153/400
#
# Epoch 153: val_loss did not improve from 0.22421
# 393/393 - 76s - 194ms/step - accuracy: 0.9711 - loss: 0.0833 - top2_accuracy: 0.9935 - val_accuracy: 0.9391 - val_loss: 0.2253 - val_top2_accuracy: 0.9781
# Epoch 154/400
#
# Epoch 154: val_loss did not improve from 0.22421
# 393/393 - 75s - 191ms/step - accuracy: 0.9731 - loss: 0.0808 - top2_accuracy: 0.9940 - val_accuracy: 0.9394 - val_loss: 0.2244 - val_top2_accuracy: 0.9773
# Epoch 155/400
#
# Epoch 155: val_loss improved from 0.22421 to 0.22389, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 155: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 187ms/step - accuracy: 0.9752 - loss: 0.0758 - top2_accuracy: 0.9943 - val_accuracy: 0.9391 - val_loss: 0.2239 - val_top2_accuracy: 0.9770
# Epoch 156/400
#
# Epoch 156: val_loss improved from 0.22389 to 0.22376, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 156: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 189ms/step - accuracy: 0.9735 - loss: 0.0799 - top2_accuracy: 0.9943 - val_accuracy: 0.9391 - val_loss: 0.2238 - val_top2_accuracy: 0.9773
# Epoch 157/400
#
# Epoch 157: val_loss did not improve from 0.22376
# 393/393 - 74s - 188ms/step - accuracy: 0.9752 - loss: 0.0771 - top2_accuracy: 0.9933 - val_accuracy: 0.9383 - val_loss: 0.2241 - val_top2_accuracy: 0.9781
# Epoch 158/400
#
# Epoch 158: val_loss did not improve from 0.22376
# 393/393 - 73s - 186ms/step - accuracy: 0.9733 - loss: 0.0756 - top2_accuracy: 0.9941 - val_accuracy: 0.9387 - val_loss: 0.2248 - val_top2_accuracy: 0.9777
# Epoch 159/400
#
# Epoch 159: val_loss did not improve from 0.22376
# 393/393 - 73s - 187ms/step - accuracy: 0.9731 - loss: 0.0763 - top2_accuracy: 0.9949 - val_accuracy: 0.9402 - val_loss: 0.2246 - val_top2_accuracy: 0.9773
# Epoch 160/400
#
# Epoch 160: val_loss did not improve from 0.22376
# 393/393 - 73s - 187ms/step - accuracy: 0.9764 - loss: 0.0750 - top2_accuracy: 0.9951 - val_accuracy: 0.9394 - val_loss: 0.2261 - val_top2_accuracy: 0.9777
# Epoch 161/400
#
# Epoch 161: val_loss did not improve from 0.22376
# 393/393 - 73s - 186ms/step - accuracy: 0.9754 - loss: 0.0775 - top2_accuracy: 0.9939 - val_accuracy: 0.9394 - val_loss: 0.2259 - val_top2_accuracy: 0.9781
# Epoch 162/400
#
# Epoch 162: val_loss did not improve from 0.22376
# 393/393 - 74s - 189ms/step - accuracy: 0.9748 - loss: 0.0758 - top2_accuracy: 0.9953 - val_accuracy: 0.9398 - val_loss: 0.2240 - val_top2_accuracy: 0.9770
# Epoch 163/400
#
# Epoch 163: val_loss did not improve from 0.22376
# 393/393 - 75s - 191ms/step - accuracy: 0.9750 - loss: 0.0773 - top2_accuracy: 0.9937 - val_accuracy: 0.9391 - val_loss: 0.2244 - val_top2_accuracy: 0.9773
# Epoch 164/400
#
# Epoch 164: val_loss did not improve from 0.22376
# 393/393 - 74s - 187ms/step - accuracy: 0.9745 - loss: 0.0772 - top2_accuracy: 0.9945 - val_accuracy: 0.9387 - val_loss: 0.2252 - val_top2_accuracy: 0.9784
# Epoch 165/400
#
# Epoch 165: val_loss did not improve from 0.22376
# 393/393 - 74s - 188ms/step - accuracy: 0.9746 - loss: 0.0750 - top2_accuracy: 0.9942 - val_accuracy: 0.9398 - val_loss: 0.2246 - val_top2_accuracy: 0.9788
# Epoch 166/400
#
# Epoch 166: val_loss did not improve from 0.22376
# 393/393 - 74s - 190ms/step - accuracy: 0.9782 - loss: 0.0679 - top2_accuracy: 0.9959 - val_accuracy: 0.9394 - val_loss: 0.2262 - val_top2_accuracy: 0.9784
# Epoch 167/400
#
# Epoch 167: val_loss did not improve from 0.22376
# 393/393 - 74s - 188ms/step - accuracy: 0.9760 - loss: 0.0723 - top2_accuracy: 0.9953 - val_accuracy: 0.9394 - val_loss: 0.2259 - val_top2_accuracy: 0.9784
# Epoch 168/400
#
# Epoch 168: val_loss did not improve from 0.22376
# 393/393 - 74s - 189ms/step - accuracy: 0.9770 - loss: 0.0710 - top2_accuracy: 0.9951 - val_accuracy: 0.9405 - val_loss: 0.2257 - val_top2_accuracy: 0.9781
# Epoch 169/400
#
# Epoch 169: val_loss did not improve from 0.22376
# 393/393 - 74s - 188ms/step - accuracy: 0.9759 - loss: 0.0717 - top2_accuracy: 0.9952 - val_accuracy: 0.9387 - val_loss: 0.2262 - val_top2_accuracy: 0.9781
# Epoch 170/400
#
# Epoch 170: val_loss did not improve from 0.22376
# 393/393 - 74s - 189ms/step - accuracy: 0.9754 - loss: 0.0718 - top2_accuracy: 0.9947 - val_accuracy: 0.9383 - val_loss: 0.2252 - val_top2_accuracy: 0.9784
# Epoch 171/400
#
# Epoch 171: val_loss did not improve from 0.22376
# 393/393 - 76s - 193ms/step - accuracy: 0.9767 - loss: 0.0710 - top2_accuracy: 0.9951 - val_accuracy: 0.9387 - val_loss: 0.2254 - val_top2_accuracy: 0.9784
# Epoch 172/400
#
# Epoch 172: val_loss did not improve from 0.22376
# 393/393 - 75s - 191ms/step - accuracy: 0.9770 - loss: 0.0701 - top2_accuracy: 0.9955 - val_accuracy: 0.9391 - val_loss: 0.2261 - val_top2_accuracy: 0.9788
# Epoch 173/400
#
# Epoch 173: val_loss did not improve from 0.22376
# 393/393 - 73s - 186ms/step - accuracy: 0.9753 - loss: 0.0747 - top2_accuracy: 0.9938 - val_accuracy: 0.9391 - val_loss: 0.2248 - val_top2_accuracy: 0.9784
# Epoch 174/400
#
# Epoch 174: val_loss did not improve from 0.22376
# 393/393 - 73s - 186ms/step - accuracy: 0.9769 - loss: 0.0719 - top2_accuracy: 0.9946 - val_accuracy: 0.9383 - val_loss: 0.2253 - val_top2_accuracy: 0.9781
# Epoch 175/400
#
# Epoch 175: val_loss did not improve from 0.22376
# 393/393 - 75s - 191ms/step - accuracy: 0.9770 - loss: 0.0716 - top2_accuracy: 0.9956 - val_accuracy: 0.9383 - val_loss: 0.2248 - val_top2_accuracy: 0.9784
# Epoch 176/400
#
# Epoch 176: val_loss did not improve from 0.22376
# 393/393 - 74s - 187ms/step - accuracy: 0.9777 - loss: 0.0702 - top2_accuracy: 0.9952 - val_accuracy: 0.9391 - val_loss: 0.2253 - val_top2_accuracy: 0.9792
# Epoch 177/400
#
# Epoch 177: val_loss did not improve from 0.22376
# 393/393 - 75s - 190ms/step - accuracy: 0.9789 - loss: 0.0664 - top2_accuracy: 0.9954 - val_accuracy: 0.9383 - val_loss: 0.2249 - val_top2_accuracy: 0.9788
# Epoch 178/400
#
# Epoch 178: val_loss did not improve from 0.22376
# 393/393 - 73s - 185ms/step - accuracy: 0.9795 - loss: 0.0654 - top2_accuracy: 0.9953 - val_accuracy: 0.9391 - val_loss: 0.2255 - val_top2_accuracy: 0.9788
# Epoch 179/400
#
# Epoch 179: val_loss did not improve from 0.22376
# 393/393 - 73s - 185ms/step - accuracy: 0.9778 - loss: 0.0665 - top2_accuracy: 0.9956 - val_accuracy: 0.9383 - val_loss: 0.2255 - val_top2_accuracy: 0.9777
# Epoch 180/400
#
# Epoch 180: val_loss did not improve from 0.22376
# 393/393 - 73s - 186ms/step - accuracy: 0.9778 - loss: 0.0698 - top2_accuracy: 0.9951 - val_accuracy: 0.9376 - val_loss: 0.2258 - val_top2_accuracy: 0.9781
# Epoch 181/400
#
# Epoch 181: val_loss did not improve from 0.22376
# 393/393 - 74s - 189ms/step - accuracy: 0.9795 - loss: 0.0632 - top2_accuracy: 0.9955 - val_accuracy: 0.9402 - val_loss: 0.2260 - val_top2_accuracy: 0.9777
# Epoch 182/400
#
# Epoch 182: val_loss did not improve from 0.22376
# 393/393 - 74s - 187ms/step - accuracy: 0.9795 - loss: 0.0637 - top2_accuracy: 0.9955 - val_accuracy: 0.9383 - val_loss: 0.2265 - val_top2_accuracy: 0.9773
# Epoch 183/400
#
# Epoch 183: val_loss did not improve from 0.22376
# 393/393 - 72s - 183ms/step - accuracy: 0.9793 - loss: 0.0621 - top2_accuracy: 0.9955 - val_accuracy: 0.9394 - val_loss: 0.2272 - val_top2_accuracy: 0.9777
# Epoch 184/400
#
# Epoch 184: val_loss did not improve from 0.22376
# 393/393 - 72s - 183ms/step - accuracy: 0.9787 - loss: 0.0617 - top2_accuracy: 0.9956 - val_accuracy: 0.9387 - val_loss: 0.2268 - val_top2_accuracy: 0.9781
# Epoch 185/400
#
# Epoch 185: val_loss did not improve from 0.22376
# 393/393 - 73s - 185ms/step - accuracy: 0.9650 - loss: 0.1020 - top2_accuracy: 0.9913 - val_accuracy: 0.9391 - val_loss: 0.2250 - val_top2_accuracy: 0.9784
# Epoch 186/400
#
# Epoch 186: val_loss did not improve from 0.22376
# 393/393 - 73s - 185ms/step - accuracy: 0.9658 - loss: 0.0996 - top2_accuracy: 0.9928 - val_accuracy: 0.9402 - val_loss: 0.2242 - val_top2_accuracy: 0.9777
# Epoch 187/400
#
# Epoch 187: val_loss improved from 0.22376 to 0.22314, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Epoch 187: finished saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
# 393/393 - 74s - 188ms/step - accuracy: 0.9677 - loss: 0.0992 - top2_accuracy: 0.9914 - val_accuracy: 0.9409 - val_loss: 0.2231 - val_top2_accuracy: 0.9784
# Epoch 188/400
#
# Epoch 188: val_loss improved from 0.22314 to 0.22291, saving model to /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# ...
# Epoch 329/400
#
# Epoch 329: val_loss did not improve from 0.21357
# 393/393 - 77s - 196ms/step - accuracy: 0.9664 - loss: 0.0950 - top2_accuracy: 0.9920 - val_accuracy: 0.9417 - val_loss: 0.2139 - val_top2_accuracy: 0.9792
# Epoch 330/400
#
# Epoch 330: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9693 - loss: 0.0898 - top2_accuracy: 0.9936 - val_accuracy: 0.9417 - val_loss: 0.2145 - val_top2_accuracy: 0.9788
# Epoch 331/400
#
# Epoch 331: val_loss did not improve from 0.21357
# 393/393 - 74s - 187ms/step - accuracy: 0.9680 - loss: 0.0885 - top2_accuracy: 0.9930 - val_accuracy: 0.9413 - val_loss: 0.2145 - val_top2_accuracy: 0.9792
# Epoch 332/400
#
# Epoch 332: val_loss did not improve from 0.21357
# 393/393 - 73s - 187ms/step - accuracy: 0.9679 - loss: 0.0920 - top2_accuracy: 0.9924 - val_accuracy: 0.9420 - val_loss: 0.2150 - val_top2_accuracy: 0.9784
# Epoch 333/400
#
# Epoch 333: val_loss did not improve from 0.21357
# 393/393 - 74s - 188ms/step - accuracy: 0.9693 - loss: 0.0901 - top2_accuracy: 0.9932 - val_accuracy: 0.9424 - val_loss: 0.2158 - val_top2_accuracy: 0.9784
# Epoch 334/400
#
# Epoch 334: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9689 - loss: 0.0905 - top2_accuracy: 0.9932 - val_accuracy: 0.9428 - val_loss: 0.2159 - val_top2_accuracy: 0.9781
# Epoch 335/400
#
# Epoch 335: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9695 - loss: 0.0878 - top2_accuracy: 0.9934 - val_accuracy: 0.9424 - val_loss: 0.2160 - val_top2_accuracy: 0.9788
# Epoch 336/400
#
# Epoch 336: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9699 - loss: 0.0893 - top2_accuracy: 0.9924 - val_accuracy: 0.9428 - val_loss: 0.2155 - val_top2_accuracy: 0.9788
# Epoch 337/400
#
# Epoch 337: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9687 - loss: 0.0895 - top2_accuracy: 0.9926 - val_accuracy: 0.9424 - val_loss: 0.2152 - val_top2_accuracy: 0.9796
# Epoch 338/400
#
# Epoch 338: val_loss did not improve from 0.21357
# 393/393 - 74s - 190ms/step - accuracy: 0.9699 - loss: 0.0909 - top2_accuracy: 0.9924 - val_accuracy: 0.9424 - val_loss: 0.2162 - val_top2_accuracy: 0.9792
# Epoch 339/400
#
# Epoch 339: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9677 - loss: 0.0930 - top2_accuracy: 0.9934 - val_accuracy: 0.9417 - val_loss: 0.2174 - val_top2_accuracy: 0.9784
# Epoch 340/400
#
# Epoch 340: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9680 - loss: 0.0901 - top2_accuracy: 0.9937 - val_accuracy: 0.9424 - val_loss: 0.2157 - val_top2_accuracy: 0.9796
# Epoch 341/400
#
# Epoch 341: val_loss did not improve from 0.21357
# 393/393 - 76s - 192ms/step - accuracy: 0.9676 - loss: 0.0938 - top2_accuracy: 0.9925 - val_accuracy: 0.9417 - val_loss: 0.2159 - val_top2_accuracy: 0.9796
# Epoch 342/400
#
# Epoch 342: val_loss did not improve from 0.21357
# 393/393 - 76s - 195ms/step - accuracy: 0.9698 - loss: 0.0887 - top2_accuracy: 0.9928 - val_accuracy: 0.9420 - val_loss: 0.2167 - val_top2_accuracy: 0.9799
# Epoch 343/400
#
# Epoch 343: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9684 - loss: 0.0922 - top2_accuracy: 0.9922 - val_accuracy: 0.9417 - val_loss: 0.2162 - val_top2_accuracy: 0.9803
# Epoch 344/400
#
# Epoch 344: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9683 - loss: 0.0909 - top2_accuracy: 0.9932 - val_accuracy: 0.9431 - val_loss: 0.2157 - val_top2_accuracy: 0.9796
# Epoch 345/400
#
# Epoch 345: val_loss did not improve from 0.21357
# 393/393 - 76s - 192ms/step - accuracy: 0.9705 - loss: 0.0902 - top2_accuracy: 0.9923 - val_accuracy: 0.9420 - val_loss: 0.2155 - val_top2_accuracy: 0.9796
# Epoch 346/400
#
# Epoch 346: val_loss did not improve from 0.21357
# 393/393 - 76s - 194ms/step - accuracy: 0.9701 - loss: 0.0907 - top2_accuracy: 0.9930 - val_accuracy: 0.9428 - val_loss: 0.2147 - val_top2_accuracy: 0.9788
# Epoch 347/400
#
# Epoch 347: val_loss did not improve from 0.21357
# 393/393 - 77s - 195ms/step - accuracy: 0.9684 - loss: 0.0904 - top2_accuracy: 0.9930 - val_accuracy: 0.9420 - val_loss: 0.2140 - val_top2_accuracy: 0.9792
# Epoch 348/400
#
# Epoch 348: val_loss did not improve from 0.21357
# 393/393 - 77s - 195ms/step - accuracy: 0.9681 - loss: 0.0904 - top2_accuracy: 0.9920 - val_accuracy: 0.9428 - val_loss: 0.2166 - val_top2_accuracy: 0.9792
# Epoch 349/400
#
# Epoch 349: val_loss did not improve from 0.21357
# 393/393 - 77s - 197ms/step - accuracy: 0.9704 - loss: 0.0869 - top2_accuracy: 0.9932 - val_accuracy: 0.9428 - val_loss: 0.2173 - val_top2_accuracy: 0.9781
# Epoch 350/400
#
# Epoch 350: val_loss did not improve from 0.21357
# 393/393 - 77s - 196ms/step - accuracy: 0.9689 - loss: 0.0882 - top2_accuracy: 0.9933 - val_accuracy: 0.9417 - val_loss: 0.2163 - val_top2_accuracy: 0.9784
# Epoch 351/400
#
# Epoch 351: val_loss did not improve from 0.21357
# 393/393 - 77s - 196ms/step - accuracy: 0.9685 - loss: 0.0905 - top2_accuracy: 0.9925 - val_accuracy: 0.9417 - val_loss: 0.2160 - val_top2_accuracy: 0.9788
# Epoch 352/400
#
# Epoch 352: val_loss did not improve from 0.21357
# 393/393 - 78s - 197ms/step - accuracy: 0.9697 - loss: 0.0878 - top2_accuracy: 0.9935 - val_accuracy: 0.9420 - val_loss: 0.2170 - val_top2_accuracy: 0.9784
# Epoch 353/400
#
# Epoch 353: val_loss did not improve from 0.21357
# 393/393 - 78s - 198ms/step - accuracy: 0.9707 - loss: 0.0871 - top2_accuracy: 0.9933 - val_accuracy: 0.9431 - val_loss: 0.2163 - val_top2_accuracy: 0.9781
# Epoch 354/400
#
# Epoch 354: val_loss did not improve from 0.21357
# 393/393 - 76s - 194ms/step - accuracy: 0.9709 - loss: 0.0858 - top2_accuracy: 0.9922 - val_accuracy: 0.9431 - val_loss: 0.2162 - val_top2_accuracy: 0.9788
# Epoch 355/400
#
# Epoch 355: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9678 - loss: 0.0918 - top2_accuracy: 0.9927 - val_accuracy: 0.9435 - val_loss: 0.2167 - val_top2_accuracy: 0.9784
# Epoch 356/400
#
# Epoch 356: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9691 - loss: 0.0897 - top2_accuracy: 0.9928 - val_accuracy: 0.9424 - val_loss: 0.2160 - val_top2_accuracy: 0.9788
# Epoch 357/400
#
# Epoch 357: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9716 - loss: 0.0822 - top2_accuracy: 0.9941 - val_accuracy: 0.9431 - val_loss: 0.2165 - val_top2_accuracy: 0.9788
# Epoch 358/400
#
# Epoch 358: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9677 - loss: 0.0927 - top2_accuracy: 0.9924 - val_accuracy: 0.9439 - val_loss: 0.2147 - val_top2_accuracy: 0.9784
# Epoch 359/400
#
# Epoch 359: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9696 - loss: 0.0901 - top2_accuracy: 0.9939 - val_accuracy: 0.9439 - val_loss: 0.2142 - val_top2_accuracy: 0.9784
# Epoch 360/400
#
# Epoch 360: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9715 - loss: 0.0828 - top2_accuracy: 0.9925 - val_accuracy: 0.9435 - val_loss: 0.2144 - val_top2_accuracy: 0.9788
# Epoch 361/400
#
# Epoch 361: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9720 - loss: 0.0829 - top2_accuracy: 0.9938 - val_accuracy: 0.9439 - val_loss: 0.2151 - val_top2_accuracy: 0.9792
# Epoch 362/400
#
# Epoch 362: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9701 - loss: 0.0832 - top2_accuracy: 0.9939 - val_accuracy: 0.9446 - val_loss: 0.2162 - val_top2_accuracy: 0.9788
# Epoch 363/400
#
# Epoch 363: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9692 - loss: 0.0904 - top2_accuracy: 0.9939 - val_accuracy: 0.9428 - val_loss: 0.2165 - val_top2_accuracy: 0.9796
# Epoch 364/400
#
# Epoch 364: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9688 - loss: 0.0898 - top2_accuracy: 0.9915 - val_accuracy: 0.9428 - val_loss: 0.2157 - val_top2_accuracy: 0.9796
# Epoch 365/400
#
# Epoch 365: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9675 - loss: 0.0929 - top2_accuracy: 0.9916 - val_accuracy: 0.9431 - val_loss: 0.2150 - val_top2_accuracy: 0.9796
# Epoch 366/400
#
# Epoch 366: val_loss did not improve from 0.21357
# 393/393 - 76s - 192ms/step - accuracy: 0.9698 - loss: 0.0883 - top2_accuracy: 0.9933 - val_accuracy: 0.9424 - val_loss: 0.2152 - val_top2_accuracy: 0.9788
# Epoch 367/400
#
# Epoch 367: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9693 - loss: 0.0921 - top2_accuracy: 0.9923 - val_accuracy: 0.9428 - val_loss: 0.2152 - val_top2_accuracy: 0.9796
# Epoch 368/400
#
# Epoch 368: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9682 - loss: 0.0924 - top2_accuracy: 0.9918 - val_accuracy: 0.9428 - val_loss: 0.2147 - val_top2_accuracy: 0.9784
# Epoch 369/400
#
# Epoch 369: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9668 - loss: 0.0912 - top2_accuracy: 0.9929 - val_accuracy: 0.9424 - val_loss: 0.2136 - val_top2_accuracy: 0.9784
# Epoch 370/400
#
# Epoch 370: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9682 - loss: 0.0923 - top2_accuracy: 0.9929 - val_accuracy: 0.9439 - val_loss: 0.2148 - val_top2_accuracy: 0.9799
# Epoch 371/400
#
# Epoch 371: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9708 - loss: 0.0862 - top2_accuracy: 0.9939 - val_accuracy: 0.9431 - val_loss: 0.2150 - val_top2_accuracy: 0.9803
# Epoch 372/400
#
# Epoch 372: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9677 - loss: 0.0908 - top2_accuracy: 0.9928 - val_accuracy: 0.9424 - val_loss: 0.2153 - val_top2_accuracy: 0.9792
# Epoch 373/400
#
# Epoch 373: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9691 - loss: 0.0917 - top2_accuracy: 0.9940 - val_accuracy: 0.9428 - val_loss: 0.2156 - val_top2_accuracy: 0.9788
# Epoch 374/400
#
# Epoch 374: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9716 - loss: 0.0847 - top2_accuracy: 0.9937 - val_accuracy: 0.9420 - val_loss: 0.2157 - val_top2_accuracy: 0.9788
# Epoch 375/400
#
# Epoch 375: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9700 - loss: 0.0857 - top2_accuracy: 0.9938 - val_accuracy: 0.9428 - val_loss: 0.2173 - val_top2_accuracy: 0.9788
# Epoch 376/400
#
# Epoch 376: val_loss did not improve from 0.21357
# 393/393 - 73s - 187ms/step - accuracy: 0.9683 - loss: 0.0886 - top2_accuracy: 0.9942 - val_accuracy: 0.9420 - val_loss: 0.2159 - val_top2_accuracy: 0.9792
# Epoch 377/400
#
# Epoch 377: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9690 - loss: 0.0872 - top2_accuracy: 0.9935 - val_accuracy: 0.9417 - val_loss: 0.2162 - val_top2_accuracy: 0.9784
# Epoch 378/400
#
# Epoch 378: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9696 - loss: 0.0859 - top2_accuracy: 0.9942 - val_accuracy: 0.9424 - val_loss: 0.2164 - val_top2_accuracy: 0.9784
# Epoch 379/400
#
# Epoch 379: val_loss did not improve from 0.21357
# 393/393 - 74s - 188ms/step - accuracy: 0.9697 - loss: 0.0865 - top2_accuracy: 0.9935 - val_accuracy: 0.9428 - val_loss: 0.2175 - val_top2_accuracy: 0.9788
# Epoch 380/400
#
# Epoch 380: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9696 - loss: 0.0890 - top2_accuracy: 0.9933 - val_accuracy: 0.9435 - val_loss: 0.2168 - val_top2_accuracy: 0.9796
# Epoch 381/400
#
# Epoch 381: val_loss did not improve from 0.21357
# 393/393 - 73s - 185ms/step - accuracy: 0.9709 - loss: 0.0857 - top2_accuracy: 0.9920 - val_accuracy: 0.9431 - val_loss: 0.2160 - val_top2_accuracy: 0.9796
# Epoch 382/400
#
# Epoch 382: val_loss did not improve from 0.21357
# 393/393 - 74s - 188ms/step - accuracy: 0.9700 - loss: 0.0863 - top2_accuracy: 0.9934 - val_accuracy: 0.9420 - val_loss: 0.2165 - val_top2_accuracy: 0.9796
# Epoch 383/400
#
# Epoch 383: val_loss did not improve from 0.21357
# 393/393 - 74s - 187ms/step - accuracy: 0.9687 - loss: 0.0908 - top2_accuracy: 0.9917 - val_accuracy: 0.9428 - val_loss: 0.2160 - val_top2_accuracy: 0.9796
# Epoch 384/400
#
# Epoch 384: val_loss did not improve from 0.21357
# 393/393 - 74s - 188ms/step - accuracy: 0.9698 - loss: 0.0874 - top2_accuracy: 0.9934 - val_accuracy: 0.9424 - val_loss: 0.2152 - val_top2_accuracy: 0.9796
# Epoch 385/400
#
# Epoch 385: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9686 - loss: 0.0885 - top2_accuracy: 0.9930 - val_accuracy: 0.9428 - val_loss: 0.2158 - val_top2_accuracy: 0.9796
# Epoch 386/400
#
# Epoch 386: val_loss did not improve from 0.21357
# 393/393 - 77s - 196ms/step - accuracy: 0.9691 - loss: 0.0881 - top2_accuracy: 0.9926 - val_accuracy: 0.9428 - val_loss: 0.2162 - val_top2_accuracy: 0.9788
# Epoch 387/400
#
# Epoch 387: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9706 - loss: 0.0881 - top2_accuracy: 0.9925 - val_accuracy: 0.9424 - val_loss: 0.2167 - val_top2_accuracy: 0.9788
# Epoch 388/400
#
# Epoch 388: val_loss did not improve from 0.21357
# 393/393 - 77s - 195ms/step - accuracy: 0.9690 - loss: 0.0848 - top2_accuracy: 0.9934 - val_accuracy: 0.9420 - val_loss: 0.2161 - val_top2_accuracy: 0.9799
# Epoch 389/400
#
# Epoch 389: val_loss did not improve from 0.21357
# 393/393 - 75s - 191ms/step - accuracy: 0.9679 - loss: 0.0893 - top2_accuracy: 0.9928 - val_accuracy: 0.9428 - val_loss: 0.2167 - val_top2_accuracy: 0.9788
# Epoch 390/400
#
# Epoch 390: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9728 - loss: 0.0814 - top2_accuracy: 0.9938 - val_accuracy: 0.9435 - val_loss: 0.2166 - val_top2_accuracy: 0.9796
# Epoch 391/400
#
# Epoch 391: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9692 - loss: 0.0881 - top2_accuracy: 0.9926 - val_accuracy: 0.9420 - val_loss: 0.2167 - val_top2_accuracy: 0.9788
# Epoch 392/400
#
# Epoch 392: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9695 - loss: 0.0915 - top2_accuracy: 0.9928 - val_accuracy: 0.9446 - val_loss: 0.2146 - val_top2_accuracy: 0.9788
# Epoch 393/400
#
# Epoch 393: val_loss did not improve from 0.21357
# 393/393 - 74s - 189ms/step - accuracy: 0.9693 - loss: 0.0878 - top2_accuracy: 0.9941 - val_accuracy: 0.9435 - val_loss: 0.2151 - val_top2_accuracy: 0.9788
# Epoch 394/400
#
# Epoch 394: val_loss did not improve from 0.21357
# 393/393 - 76s - 193ms/step - accuracy: 0.9694 - loss: 0.0881 - top2_accuracy: 0.9933 - val_accuracy: 0.9428 - val_loss: 0.2151 - val_top2_accuracy: 0.9784
# Epoch 395/400
#
# Epoch 395: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9689 - loss: 0.0873 - top2_accuracy: 0.9932 - val_accuracy: 0.9428 - val_loss: 0.2153 - val_top2_accuracy: 0.9788
# Epoch 396/400
#
# Epoch 396: val_loss did not improve from 0.21357
# 393/393 - 77s - 196ms/step - accuracy: 0.9701 - loss: 0.0878 - top2_accuracy: 0.9945 - val_accuracy: 0.9424 - val_loss: 0.2156 - val_top2_accuracy: 0.9788
# Epoch 397/400
#
# Epoch 397: val_loss did not improve from 0.21357
# 393/393 - 76s - 192ms/step - accuracy: 0.9696 - loss: 0.0872 - top2_accuracy: 0.9934 - val_accuracy: 0.9431 - val_loss: 0.2144 - val_top2_accuracy: 0.9788
# Epoch 398/400
#
# Epoch 398: val_loss did not improve from 0.21357
# 393/393 - 75s - 190ms/step - accuracy: 0.9711 - loss: 0.0843 - top2_accuracy: 0.9932 - val_accuracy: 0.9435 - val_loss: 0.2150 - val_top2_accuracy: 0.9784
# Epoch 399/400
#
# Epoch 399: val_loss did not improve from 0.21357
# 393/393 - 74s - 188ms/step - accuracy: 0.9709 - loss: 0.0903 - top2_accuracy: 0.9924 - val_accuracy: 0.9431 - val_loss: 0.2147 - val_top2_accuracy: 0.9788
# Epoch 400/400
#
# Epoch 400: val_loss did not improve from 0.21357
# 393/393 - 75s - 192ms/step - accuracy: 0.9703 - loss: 0.0851 - top2_accuracy: 0.9936 - val_accuracy: 0.9428 - val_loss: 0.2159 - val_top2_accuracy: 0.9781
#
# Fine-tuning completed
# Epochs completed: 400
# Total hours: 8.15
# Average seconds per epoch: 73.33

# %%
LAST_MODEL_PATH = (
    OUTPUT_DIR / "last_finetuned_model.keras"
)

model.save(LAST_MODEL_PATH)

print("Last training state saved:")
print(LAST_MODEL_PATH)


model.load_weights(BEST_WEIGHTS_PATH)

model.save(BEST_MODEL_PATH)


frozen_history_df = pd.read_csv(
    FROZEN_HISTORY_PATH
)

finetuned_history_df = pd.read_csv(
    FINETUNE_HISTORY_PATH
)


best_row_index = finetuned_history_df[
    "val_loss"
].idxmin()

best_finetune_epoch = (
    int(
        finetuned_history_df.loc[
            best_row_index,
            "epoch",
        ]
    )
    + 1
)

best_global_epoch = (
    len(frozen_history_df)
    + best_finetune_epoch
)

best_val_loss = float(
    finetuned_history_df.loc[
        best_row_index,
        "val_loss",
    ]
)


best_epoch_info = {
    "best_finetune_epoch": best_finetune_epoch,
    "best_global_epoch": best_global_epoch,
    "best_validation_loss": best_val_loss,
}


with open(
    OUTPUT_DIR / "best_epoch.json",
    "w",
    encoding="utf-8",
) as file:
    json.dump(
        best_epoch_info,
        file,
        indent=2,
    )


print("Best weights loaded:")
print(BEST_WEIGHTS_PATH)

print("\nComplete best model saved:")
print(BEST_MODEL_PATH)

print("\nBest fine-tuning epoch:", best_finetune_epoch)
print("Best global epoch:", best_global_epoch)
print("Best validation loss:", round(best_val_loss, 4))
# Out:
# Last training state saved:
# /kaggle/working/mobilenet_clean_split_bn_locked/last_finetuned_model.keras
# Best weights loaded:
# /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned.weights.h5
#
# Complete best model saved:
# /kaggle/working/mobilenet_clean_split_bn_locked/best_finetuned_model.keras
#
# Best fine-tuning epoch: 309
# Best global epoch: 509
# Best validation loss: 0.2136

# %%
frozen_history_df["phase"] = "frozen"
frozen_history_df["global_epoch"] = np.arange(
    1,
    len(frozen_history_df) + 1,
)


finetuned_history_df["phase"] = "fine_tuning"
finetuned_history_df["global_epoch"] = (
    len(frozen_history_df)
    + np.arange(
        1,
        len(finetuned_history_df) + 1,
    )
)


combined_history_df = pd.concat(
    [
        frozen_history_df,
        finetuned_history_df,
    ],
    ignore_index=True,
)


COMBINED_HISTORY_PATH = (
    OUTPUT_DIR / "combined_history.csv"
)

combined_history_df.to_csv(
    COMBINED_HISTORY_PATH,
    index=False,
)


print("Combined history saved:")
print(COMBINED_HISTORY_PATH)

print("\nFrozen epochs:", len(frozen_history_df))
print(
    "Fine-tuning epochs:",
    len(finetuned_history_df),
)
print(
    "Total epochs:",
    len(combined_history_df),
)
# Out:
# Combined history saved:
# /kaggle/working/mobilenet_clean_split_bn_locked/combined_history.csv
#
# Frozen epochs: 200
# Fine-tuning epochs: 400
# Total epochs: 600

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
)


test_generator.reset()

test_results = model.evaluate(
    test_generator,
    return_dict=True,
    verbose=1,
)


test_generator.reset()

y_prob = model.predict(
    test_generator,
    verbose=1,
)

y_true = test_generator.classes
y_pred = np.argmax(y_prob, axis=1)


metrics = {
    "accuracy": float(
        test_results["accuracy"]
    ),
    "macro_precision": float(
        precision_score(
            y_true,
            y_pred,
            average="macro",
            zero_division=0,
        )
    ),
    "macro_recall": float(
        recall_score(
            y_true,
            y_pred,
            average="macro",
            zero_division=0,
        )
    ),
    "macro_f1": float(
        f1_score(
            y_true,
            y_pred,
            average="macro",
            zero_division=0,
        )
    ),
    "top2_accuracy": float(
        test_results["top2_accuracy"]
    ),
    "test_loss": float(
        test_results["loss"]
    ),
    "best_finetune_epoch": (
        best_finetune_epoch
    ),
    "training_hours": float(
        training_time["total_hours"]
    ),
    "total_parameters": int(
        model.count_params()
    ),
}


METRICS_PATH = OUTPUT_DIR / "metrics.json"

with open(
    METRICS_PATH,
    "w",
    encoding="utf-8",
) as file:
    json.dump(
        metrics,
        file,
        indent=2,
    )


PREDICTIONS_PATH = (
    OUTPUT_DIR / "predictions.npz"
)

np.savez_compressed(
    PREDICTIONS_PATH,
    y_true=y_true,
    y_pred=y_pred,
    y_prob=y_prob,
    class_names=np.array(CLASS_NAMES),
    image_names=test_df["image_name"].to_numpy(),
)


predictions_df = pd.DataFrame({
    "image_name": test_df[
        "image_name"
    ].to_numpy(),

    "true_label": [
        CLASS_NAMES[index]
        for index in y_true
    ],

    "predicted_label": [
        CLASS_NAMES[index]
        for index in y_pred
    ],

    "confidence": np.max(
        y_prob,
        axis=1,
    ),
})


PREDICTIONS_CSV_PATH = (
    OUTPUT_DIR / "test_predictions.csv"
)

predictions_df.to_csv(
    PREDICTIONS_CSV_PATH,
    index=False,
)


print("\nTest results:")

for name, value in metrics.items():
    print(name, ":", value)

print("\nSaved:", METRICS_PATH)
print("Saved:", PREDICTIONS_PATH)
print("Saved:", PREDICTIONS_CSV_PATH)
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 20s 239ms/step - accuracy: 0.9483 - loss: 0.1992 - top2_accuracy: 0.9799
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step
#
# Test results:
# accuracy : 0.9483463168144226
# macro_precision : 0.8414399541348986
# macro_recall : 0.8424092280327884
# macro_f1 : 0.8338657392990053
# top2_accuracy : 0.9799330830574036
# test_loss : 0.1992378681898117
# best_finetune_epoch : 309
# training_hours : 8.147885230051147
# total_parameters : 4243795
#
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/metrics.json
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/predictions.npz
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/test_predictions.csv

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
)


report = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=CLASS_NAMES,
    output_dict=True,
    zero_division=0,
)


report_df = pd.DataFrame(
    report
).transpose()

report_df.index.name = "class"


REPORT_PATH = (
    OUTPUT_DIR / "classification_report.csv"
)

report_df.to_csv(
    REPORT_PATH
)


confusion_counts = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
)


confusion_normalized = (
    confusion_counts.astype(float)
    / confusion_counts.sum(
        axis=1,
        keepdims=True,
    )
)

confusion_normalized = np.nan_to_num(
    confusion_normalized
)


CONFUSION_COUNTS_PATH = (
    OUTPUT_DIR / "confusion_matrix_counts.csv"
)

CONFUSION_NORMALIZED_PATH = (
    OUTPUT_DIR / "confusion_matrix_normalized.csv"
)


pd.DataFrame(
    confusion_counts,
    index=CLASS_NAMES,
    columns=CLASS_NAMES,
).to_csv(
    CONFUSION_COUNTS_PATH
)

pd.DataFrame(
    confusion_normalized,
    index=CLASS_NAMES,
    columns=CLASS_NAMES,
).to_csv(
    CONFUSION_NORMALIZED_PATH
)


print("Saved:", REPORT_PATH)
print("Saved:", CONFUSION_COUNTS_PATH)
print("Saved:", CONFUSION_NORMALIZED_PATH)
# Out:
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/classification_report.csv
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/confusion_matrix_counts.csv
# Saved: /kaggle/working/mobilenet_clean_split_bn_locked/confusion_matrix_normalized.csv

# %%
import shutil


ZIP_PATH = shutil.make_archive(
    str(
        Path("/kaggle/working")
        / f"{RUN_NAME}_results"
    ),
    "zip",
    root_dir=OUTPUT_DIR,
)


print("Results folder:")
print(OUTPUT_DIR)

print("\nResults ZIP:")
print(ZIP_PATH)
# Out:
# Results folder:
# /kaggle/working/mobilenet_clean_split_bn_locked
#
# Results ZIP:
# /kaggle/working/mobilenet_clean_split_bn_locked_results.zip
