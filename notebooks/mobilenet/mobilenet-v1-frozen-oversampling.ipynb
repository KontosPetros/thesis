# %% [markdown]
# # MobileNetV1 με Oversampling — Παγωμένος κορμός
#
# Εφαρμόζεται random oversampling μόνο στο σύνολο εκπαίδευσης.
# Στη συνέχεια εκπαιδεύεται το classification head του MobileNetV1,
# ενώ η προεκπαιδευμένη συνελικτική βάση παραμένει παγωμένη.

# %%
from pathlib import Path
import json
import shutil

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

from tensorflow.keras import Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import (
    GlobalAveragePooling2D,
    Dropout,
    BatchNormalization,
    Dense,
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    CSVLogger,
)


SEED = 12345
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 35

EPOCHS = 200
PATIENCE = 50
LEARNING_RATE = 1e-4

RUN_NAME = "mobilenet_frozen_oversampling_seed12345"

OUTPUT_DIR = Path("/kaggle/working") / RUN_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

tf.keras.utils.set_random_seed(SEED)


print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
print("Output:", OUTPUT_DIR)
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Output: /kaggle/working/mobilenet_frozen_oversampling_seed12345

# %%
KAGGLE_INPUT = Path("/kaggle/input")


MANIFEST_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_clean_split_manifest.csv")
)

CLASS_NAMES_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_class_names.json")
)

DATASET_ROOT = next(
    KAGGLE_INPUT.rglob("zooplankton_0p5x")
)


manifest = pd.read_csv(MANIFEST_PATH)

with open(
    CLASS_NAMES_PATH,
    "r",
    encoding="utf-8",
) as file:
    class_names = json.load(file)


manifest["filepath"] = manifest[
    "relative_filepath"
].apply(
    lambda path: str(DATASET_ROOT / path)
)


train_df = manifest[
    manifest["split"] == "train"
].copy()

validation_df = manifest[
    manifest["split"] == "validation"
].copy()

test_df = manifest[
    manifest["split"] == "test"
].copy()


print("Training:", len(train_df))
print("Validation:", len(validation_df))
print("Test:", len(test_df))
print("Κλάσεις:", len(class_names))
# Out:
# Training: 12558
# Validation: 2691
# Test: 2691
# Κλάσεις: 35

# %%
rare_classes = [
    "chaoborus",
    "copepod_skins",
    "daphnia_skins",
    "diatom_chain",
    "hydra",
]

target_count = 100

parts = [train_df]


for class_name in rare_classes:

    class_rows = train_df[
        train_df["label"] == class_name
    ]

    extra_rows = class_rows.sample(
        n=target_count - len(class_rows),
        replace=True,
        random_state=SEED,
    )

    parts.append(extra_rows)


oversampled_train_df = pd.concat(
    parts,
    ignore_index=True,
)

oversampled_train_df = oversampled_train_df.sample(
    frac=1,
    random_state=SEED,
).reset_index(drop=True)


print("Πριν:", len(train_df))
print("Μετά:", len(oversampled_train_df))

print("\nΣπάνιες κλάσεις:")
print(
    oversampled_train_df[
        oversampled_train_df["label"].isin(rare_classes)
    ]["label"].value_counts()
)
# Out:
# Πριν: 12558
# Μετά: 12961
#
# Σπάνιες κλάσεις:
# label
# hydra            100
# daphnia_skins    100
# diatom_chain     100
# copepod_skins    100
# chaoborus        100
# Name: count, dtype: int64

# %%
before_counts = (
    train_df["label"]
    .value_counts()
    .reindex(class_names, fill_value=0)
)

after_counts = (
    oversampled_train_df["label"]
    .value_counts()
    .reindex(class_names, fill_value=0)
)


oversampling_counts = pd.DataFrame({
    "class": class_names,
    "before": before_counts.values,
    "after": after_counts.values,
})


oversampling_counts.to_csv(
    OUTPUT_DIR / "oversampling_counts.csv",
    index=False,
)


oversampling_counts[
    oversampling_counts["class"].isin(rare_classes)
]
# Out:
#             class  before  after
# 6       chaoborus       7    100
# 8   copepod_skins      24    100
# 11  daphnia_skins      39    100
# 13   diatom_chain      12    100
# 20          hydra      15    100

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.20,
    shear_range=10,
)

evaluation_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=oversampled_train_df,
    x_col="filepath",
    y_col="label",
    classes=class_names,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED,
    interpolation="lanczos",
)


validation_generator = evaluation_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col="filepath",
    y_col="label",
    classes=class_names,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)


test_generator = evaluation_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    classes=class_names,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="lanczos",
)
# Out:
# Found 12961 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.

# %%
backbone = MobileNet(
    weights="imagenet",
    include_top=False,
    input_shape=(128, 128, 3),
)

# Στο πρώτο στάδιο η συνελικτική βάση είναι παγωμένη.
backbone.trainable = False


x = GlobalAveragePooling2D()(backbone.output)

x = Dropout(0.2)(x)
x = BatchNormalization()(x)

x = Dense(
    950,
    activation="relu",
    bias_initializer="zeros",
)(x)

x = Dropout(0.1)(x)
x = BatchNormalization()(x)

output = Dense(
    NUM_CLASSES,
    activation="softmax",
    kernel_initializer="random_uniform",
    bias_initializer="zeros",
)(x)


model = Model(
    inputs=backbone.input,
    outputs=output,
)


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


print("Trainable backbone:", backbone.trainable)
print("Παράμετροι:", model.count_params())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789637567.801779      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1789637567.804662      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_128_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Trainable backbone: False
# Παράμετροι: 4243795

# %%
BEST_WEIGHTS_PATH = (
    OUTPUT_DIR / "best_frozen.weights.h5"
)

BEST_MODEL_PATH = (
    OUTPUT_DIR / "best_frozen_model.keras"
)

HISTORY_PATH = (
    OUTPUT_DIR / "frozen_history.csv"
)


callbacks = [
    ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),

    EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=PATIENCE,
        verbose=1,
    ),

    CSVLogger(
        str(HISTORY_PATH)
    ),
]


history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Epoch 1/200
# 2026-09-17 09:33:04.793869: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:33:04.938568: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1789637587.403786      69 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-09-17 09:34:34.670739: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:34:34.823385: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:34:34.958670: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:34:35.093151: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:34:35.228370: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:35:42.065107: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:35:42.204211: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:35:42.344571: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-17 09:35:42.482277: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from None to 0.65155, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 173s - 427ms/step - accuracy: 0.6467 - loss: 1.3442 - top2_accuracy: 0.7619 - val_accuracy: 0.8183 - val_loss: 0.6515 - val_top2_accuracy: 0.9045
# Epoch 2/200
#
# Epoch 2: val_loss improved from 0.65155 to 0.49658, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 85s - 209ms/step - accuracy: 0.7999 - loss: 0.7157 - top2_accuracy: 0.8924 - val_accuracy: 0.8599 - val_loss: 0.4966 - val_top2_accuracy: 0.9331
# Epoch 3/200
#
# Epoch 3: val_loss improved from 0.49658 to 0.42901, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 3: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 83s - 204ms/step - accuracy: 0.8189 - loss: 0.6190 - top2_accuracy: 0.9071 - val_accuracy: 0.8766 - val_loss: 0.4290 - val_top2_accuracy: 0.9446
# Epoch 4/200
#
# Epoch 4: val_loss improved from 0.42901 to 0.40003, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 4: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 84s - 206ms/step - accuracy: 0.8394 - loss: 0.5451 - top2_accuracy: 0.9228 - val_accuracy: 0.8841 - val_loss: 0.4000 - val_top2_accuracy: 0.9472
# Epoch 5/200
#
# Epoch 5: val_loss improved from 0.40003 to 0.37087, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 5: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 85s - 209ms/step - accuracy: 0.8528 - loss: 0.4991 - top2_accuracy: 0.9302 - val_accuracy: 0.8915 - val_loss: 0.3709 - val_top2_accuracy: 0.9532
# Epoch 6/200
#
# Epoch 6: val_loss improved from 0.37087 to 0.35416, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 87s - 214ms/step - accuracy: 0.8607 - loss: 0.4788 - top2_accuracy: 0.9349 - val_accuracy: 0.8956 - val_loss: 0.3542 - val_top2_accuracy: 0.9573
# Epoch 7/200
#
# Epoch 7: val_loss improved from 0.35416 to 0.34435, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 87s - 215ms/step - accuracy: 0.8644 - loss: 0.4551 - top2_accuracy: 0.9396 - val_accuracy: 0.8982 - val_loss: 0.3444 - val_top2_accuracy: 0.9584
# Epoch 8/200
#
# Epoch 8: val_loss improved from 0.34435 to 0.33513, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 8: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 86s - 212ms/step - accuracy: 0.8678 - loss: 0.4329 - top2_accuracy: 0.9417 - val_accuracy: 0.9004 - val_loss: 0.3351 - val_top2_accuracy: 0.9602
# Epoch 9/200
#
# Epoch 9: val_loss improved from 0.33513 to 0.32624, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 9: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 90s - 221ms/step - accuracy: 0.8708 - loss: 0.4196 - top2_accuracy: 0.9448 - val_accuracy: 0.9056 - val_loss: 0.3262 - val_top2_accuracy: 0.9606
# Epoch 10/200
#
# Epoch 10: val_loss did not improve from 0.32624
# 406/406 - 86s - 212ms/step - accuracy: 0.8796 - loss: 0.3979 - top2_accuracy: 0.9478 - val_accuracy: 0.8997 - val_loss: 0.3380 - val_top2_accuracy: 0.9595
# Epoch 11/200
#
# Epoch 11: val_loss improved from 0.32624 to 0.31496, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 11: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 87s - 215ms/step - accuracy: 0.8762 - loss: 0.3966 - top2_accuracy: 0.9469 - val_accuracy: 0.9041 - val_loss: 0.3150 - val_top2_accuracy: 0.9628
# Epoch 12/200
#
# Epoch 12: val_loss improved from 0.31496 to 0.30510, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 12: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 86s - 213ms/step - accuracy: 0.8776 - loss: 0.3925 - top2_accuracy: 0.9492 - val_accuracy: 0.9101 - val_loss: 0.3051 - val_top2_accuracy: 0.9643
# Epoch 13/200
#
# Epoch 13: val_loss did not improve from 0.30510
# 406/406 - 86s - 211ms/step - accuracy: 0.8823 - loss: 0.3841 - top2_accuracy: 0.9488 - val_accuracy: 0.9086 - val_loss: 0.3097 - val_top2_accuracy: 0.9658
# Epoch 14/200
#
# Epoch 14: val_loss improved from 0.30510 to 0.30494, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 14: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 85s - 209ms/step - accuracy: 0.8805 - loss: 0.3764 - top2_accuracy: 0.9492 - val_accuracy: 0.9093 - val_loss: 0.3049 - val_top2_accuracy: 0.9643
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.30494 to 0.30375, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 85s - 209ms/step - accuracy: 0.8849 - loss: 0.3665 - top2_accuracy: 0.9529 - val_accuracy: 0.9101 - val_loss: 0.3038 - val_top2_accuracy: 0.9636
# Epoch 16/200
#
# Epoch 16: val_loss did not improve from 0.30375
# 406/406 - 86s - 212ms/step - accuracy: 0.8836 - loss: 0.3622 - top2_accuracy: 0.9525 - val_accuracy: 0.9116 - val_loss: 0.3098 - val_top2_accuracy: 0.9640
# Epoch 17/200
#
# Epoch 17: val_loss improved from 0.30375 to 0.29945, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 17: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# 406/406 - 87s - 214ms/step - accuracy: 0.8854 - loss: 0.3614 - top2_accuracy: 0.9533 - val_accuracy: 0.9104 - val_loss: 0.2995 - val_top2_accuracy: 0.9658
# Epoch 18/200
#
# Epoch 18: val_loss improved from 0.29945 to 0.29313, saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# Epoch 165/200
#
# Epoch 165: val_loss did not improve from 0.23380
# 406/406 - 86s - 213ms/step - accuracy: 0.9350 - loss: 0.1938 - top2_accuracy: 0.9808 - val_accuracy: 0.9290 - val_loss: 0.2464 - val_top2_accuracy: 0.9714
# Epoch 166/200
#
# Epoch 166: val_loss did not improve from 0.23380
# 406/406 - 89s - 220ms/step - accuracy: 0.9369 - loss: 0.1827 - top2_accuracy: 0.9808 - val_accuracy: 0.9260 - val_loss: 0.2569 - val_top2_accuracy: 0.9718
# Epoch 167/200
#
# Epoch 167: val_loss did not improve from 0.23380
# 406/406 - 88s - 216ms/step - accuracy: 0.9351 - loss: 0.1973 - top2_accuracy: 0.9789 - val_accuracy: 0.9272 - val_loss: 0.2516 - val_top2_accuracy: 0.9710
# Epoch 168/200
#
# Epoch 168: val_loss did not improve from 0.23380
# 406/406 - 89s - 218ms/step - accuracy: 0.9375 - loss: 0.1899 - top2_accuracy: 0.9806 - val_accuracy: 0.9279 - val_loss: 0.2543 - val_top2_accuracy: 0.9718
# Epoch 169/200
#
# Epoch 169: val_loss did not improve from 0.23380
# 406/406 - 90s - 223ms/step - accuracy: 0.9330 - loss: 0.1962 - top2_accuracy: 0.9796 - val_accuracy: 0.9298 - val_loss: 0.2493 - val_top2_accuracy: 0.9725
# Epoch 170/200
#
# Epoch 170: val_loss did not improve from 0.23380
# 406/406 - 100s - 247ms/step - accuracy: 0.9360 - loss: 0.1837 - top2_accuracy: 0.9802 - val_accuracy: 0.9275 - val_loss: 0.2506 - val_top2_accuracy: 0.9718
# Epoch 171/200
#
# Epoch 171: val_loss did not improve from 0.23380
# 406/406 - 100s - 247ms/step - accuracy: 0.9350 - loss: 0.1945 - top2_accuracy: 0.9793 - val_accuracy: 0.9283 - val_loss: 0.2519 - val_top2_accuracy: 0.9718
# Epoch 171: early stopping

# %%
# Φορτώνουμε τα βάρη της καλύτερης εποχής.
model.load_weights(BEST_WEIGHTS_PATH)

# Αποθηκεύουμε ολόκληρο το μοντέλο.
model.save(BEST_MODEL_PATH)


history_df = pd.read_csv(HISTORY_PATH)

best_epoch = int(
    history_df["val_loss"].idxmin() + 1
)


print("Καλύτερη εποχή:", best_epoch)
print("Βάρη:", BEST_WEIGHTS_PATH)
print("Μοντέλο:", BEST_MODEL_PATH)
print("History:", HISTORY_PATH)
# Out:
# Καλύτερη εποχή: 121
# Βάρη: /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen.weights.h5
# Μοντέλο: /kaggle/working/mobilenet_frozen_oversampling_seed12345/best_frozen_model.keras
# History: /kaggle/working/mobilenet_frozen_oversampling_seed12345/frozen_history.csv

# %%
test_generator.reset()

test_results = model.evaluate(
    test_generator,
    return_dict=True,
    verbose=1,
)


test_generator.reset()

probabilities = model.predict(
    test_generator,
    verbose=1,
)


true_labels = np.asarray(
    test_generator.classes
)

predicted_labels = np.argmax(
    probabilities,
    axis=1,
)


test_metrics = {
    "model": "MobileNetV1 frozen with oversampling",
    "split": "test",
    "samples": len(true_labels),
    "loss": float(test_results["loss"]),
    "accuracy": float(
        accuracy_score(
            true_labels,
            predicted_labels,
        )
    ),
    "macro_precision": float(
        precision_score(
            true_labels,
            predicted_labels,
            average="macro",
            zero_division=0,
        )
    ),
    "macro_recall": float(
        recall_score(
            true_labels,
            predicted_labels,
            average="macro",
            zero_division=0,
        )
    ),
    "macro_f1": float(
        f1_score(
            true_labels,
            predicted_labels,
            average="macro",
            zero_division=0,
        )
    ),
    "top2_accuracy": float(
        test_results["top2_accuracy"]
    ),
    "best_epoch": best_epoch,
    "seed": SEED,
}


with open(
    OUTPUT_DIR / "test_metrics.json",
    "w",
) as file:
    json.dump(
        test_metrics,
        file,
        indent=2,
    )


print("TEST RESULTS")

for name, value in test_metrics.items():
    print(name, ":", value)
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 29s 340ms/step - accuracy: 0.9394 - loss: 0.2299 - top2_accuracy: 0.9781
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step
# TEST RESULTS
# model : MobileNetV1 frozen with oversampling
# split : test
# samples : 2691
# loss : 0.22985395789146423
# accuracy : 0.9394277220364177
# macro_precision : 0.8634346547415374
# macro_recall : 0.8633517858464343
# macro_f1 : 0.8530335488325967
# top2_accuracy : 0.9780750870704651
# best_epoch : 121
# seed : 12345

# %%
report = classification_report(
    true_labels,
    predicted_labels,
    labels=np.arange(NUM_CLASSES),
    target_names=class_names,
    output_dict=True,
    zero_division=0,
)


report_df = pd.DataFrame(
    report
).transpose()


report_df.to_csv(
    OUTPUT_DIR / "classification_report.csv"
)


top2_indices = np.argsort(
    probabilities,
    axis=1,
)[:, -2:][:, ::-1]


predictions_df = pd.DataFrame({
    "filepath": test_generator.filepaths,
    "true_index": true_labels,
    "true_label": [
        class_names[index]
        for index in true_labels
    ],
    "predicted_index": predicted_labels,
    "predicted_label": [
        class_names[index]
        for index in predicted_labels
    ],
    "confidence": np.max(
        probabilities,
        axis=1,
    ),
    "top2_label_1": [
        class_names[index]
        for index in top2_indices[:, 0]
    ],
    "top2_label_2": [
        class_names[index]
        for index in top2_indices[:, 1]
    ],
})


predictions_df.to_csv(
    OUTPUT_DIR / "test_predictions.csv",
    index=False,
)


np.savez_compressed(
    OUTPUT_DIR / "predictions.npz",
    y_true=true_labels,
    y_pred=predicted_labels,
    y_prob=probabilities,
    class_names=np.asarray(class_names),
)


print("Αποθηκεύτηκε το classification report.")
print("Αποθηκεύτηκαν τα predictions.")
# Out:
# Αποθηκεύτηκε το classification report.
# Αποθηκεύτηκαν τα predictions.

# %%
matrix_counts = confusion_matrix(
    true_labels,
    predicted_labels,
    labels=np.arange(NUM_CLASSES),
)


matrix_normalized = confusion_matrix(
    true_labels,
    predicted_labels,
    labels=np.arange(NUM_CLASSES),
    normalize="true",
)


pd.DataFrame(
    matrix_counts,
    index=class_names,
    columns=class_names,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_counts.csv"
)


pd.DataFrame(
    matrix_normalized,
    index=class_names,
    columns=class_names,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_normalized.csv"
)


plt.figure(figsize=(18, 16))

sns.heatmap(
    matrix_normalized,
    cmap="Blues",
    vmin=0,
    vmax=1,
    xticklabels=class_names,
    yticklabels=class_names,
)

plt.title(
    "MobileNetV1 Frozen with Oversampling\n"
    "Normalized Confusion Matrix"
)

plt.xlabel("Predicted class")
plt.ylabel("True class")

plt.xticks(
    rotation=90,
    fontsize=7,
)

plt.yticks(
    rotation=0,
    fontsize=7,
)

plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "confusion_matrix_normalized.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()
plt.close()

# %%
epochs = range(
    1,
    len(history_df) + 1,
)


plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 1)

plt.plot(
    epochs,
    history_df["loss"],
    label="Training",
)

plt.plot(
    epochs,
    history_df["val_loss"],
    label="Validation",
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss")
plt.legend()


plt.subplot(1, 2, 2)

plt.plot(
    epochs,
    history_df["accuracy"],
    label="Training",
)

plt.plot(
    epochs,
    history_df["val_accuracy"],
    label="Validation",
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy")
plt.legend()


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "training_curves.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()
plt.close()

# %%
run_config = {
    "run_name": RUN_NAME,
    "model": "MobileNetV1",
    "training_stage": "frozen backbone",
    "oversampling": True,
    "rare_classes": rare_classes,
    "oversampling_target": target_count,
    "original_training_images": len(train_df),
    "oversampled_training_images": len(
        oversampled_train_df
    ),
    "validation_images": len(validation_df),
    "test_images": len(test_df),
    "seed": SEED,
    "image_size": list(IMAGE_SIZE),
    "batch_size": BATCH_SIZE,
    "learning_rate": LEARNING_RATE,
    "maximum_epochs": EPOCHS,
    "patience": PATIENCE,
}


with open(
    OUTPUT_DIR / "run_config.json",
    "w",
) as file:
    json.dump(
        run_config,
        file,
        indent=2,
    )


pd.DataFrame(
    [test_metrics]
).to_csv(
    OUTPUT_DIR / "summary_metrics.csv",
    index=False,
)


with open(
    OUTPUT_DIR / "model_summary.txt",
    "w",
) as file:

    model.summary(
        print_fn=lambda line: file.write(
            line + "\n"
        )
    )


print("Αποθηκεύτηκαν οι ρυθμίσεις και τα αποτελέσματα.")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Αποθηκεύτηκαν οι ρυθμίσεις και τα αποτελέσματα.

# %%
ZIP_PATH = shutil.make_archive(
    str(
        Path("/kaggle/working")
        / f"{RUN_NAME}_results"
    ),
    "zip",
    root_dir=OUTPUT_DIR,
)


print("ZIP:")
print(ZIP_PATH)

print("\nΑρχεία:")

for path in sorted(OUTPUT_DIR.iterdir()):
    print("-", path.name)
# Out:
# ZIP:
# /kaggle/working/mobilenet_frozen_oversampling_seed12345_results.zip
#
# Αρχεία:
# - best_frozen.weights.h5
# - best_frozen_model.keras
# - classification_report.csv
# - confusion_matrix_counts.csv
# - confusion_matrix_normalized.csv
# - confusion_matrix_normalized.png
# - frozen_history.csv
# - model_summary.txt
# - oversampling_counts.csv
# - predictions.npz
# - run_config.json
# - summary_metrics.csv
# - test_metrics.json
# - test_predictions.csv
# - training_curves.png
