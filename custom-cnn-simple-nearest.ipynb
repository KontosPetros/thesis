# %%
from pathlib import Path

import json
import random
import time
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

from tensorflow.keras.preprocessing.image import ImageDataGenerator


SEED = 12345
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 35

RUN_NAME = "custom_cnn_clean_split_nearest_seed12345"

OUTPUT_DIR = Path("/kaggle/working") / RUN_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)


print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))

print("\nRun:", RUN_NAME)
print("Image size:", IMAGE_SIZE)
print("Batch size:", BATCH_SIZE)
print("Classes:", NUM_CLASSES)
print("Output directory:", OUTPUT_DIR)
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Run: custom_cnn_clean_split_nearest_seed12345
# Image size: (128, 128)
# Batch size: 32
# Classes: 35
# Output directory: /kaggle/working/custom_cnn_clean_split_nearest_seed12345

# %%
KAGGLE_INPUT = Path("/kaggle/input")


MANIFEST_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_clean_split_manifest.csv")
)

CLASS_NAMES_PATH = next(
    KAGGLE_INPUT.rglob("zoolake_class_names.json")
)

DATASET_ROOT = next(
    path
    for path in KAGGLE_INPUT.rglob("zooplankton_0p5x")
    if path.is_dir()
)


manifest = pd.read_csv(MANIFEST_PATH)

with open(CLASS_NAMES_PATH, "r") as file:
    CLASS_NAMES = json.load(file)


manifest["filepath"] = manifest["relative_filepath"].apply(
    lambda path: str(DATASET_ROOT / path)
)


train_df = (
    manifest[manifest["split"] == "train"]
    .copy()
    .reset_index(drop=True)
)

val_df = (
    manifest[manifest["split"] == "validation"]
    .copy()
    .reset_index(drop=True)
)

test_df = (
    manifest[manifest["split"] == "test"]
    .copy()
    .reset_index(drop=True)
)


print("Manifest:", MANIFEST_PATH)
print("Class names:", CLASS_NAMES_PATH)
print("Dataset root:", DATASET_ROOT)

print("\nTraining:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
print("Classes:", len(CLASS_NAMES))
# Out:
# Manifest: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_clean_split_manifest.csv
# Class names: /kaggle/input/datasets/petroskontos/zoolake-clean-split/zoolake_class_names.json
# Dataset root: /kaggle/input/datasets/petroskontos/zoolake-full/zooplankton_0p5x
#
# Training: 12558
# Validation: 2691
# Test: 2691
# Classes: 35

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.20,
    shear_range=10,
)

eval_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED,
    interpolation="nearest",
)

val_generator = eval_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="nearest",
)


print("\nTraining batches:", len(train_generator))
print("Validation batches:", len(val_generator))
# Out:
# Found 12558 validated image filenames belonging to 35 classes.
# Found 2691 validated image filenames belonging to 35 classes.
#
# Training batches: 393
# Validation batches: 85

# %%
tf.keras.backend.clear_session()


model = tf.keras.Sequential([
    tf.keras.layers.Input(
        shape=(*IMAGE_SIZE, 3)
    ),

    tf.keras.layers.Conv2D(
        32,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        64,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(
        128,
        kernel_size=3,
        padding="same",
    ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(
        128,
        activation="relu",
    ),

    tf.keras.layers.Dropout(
        0.5
    ),

    tf.keras.layers.Dense(
        NUM_CLASSES,
        activation="softmax",
    ),
])


model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787048801.839934      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 35)             │         4,515 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 263,267 (1.00 MB)
#  Trainable params: 262,563 (1.00 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
LEARNING_RATE = 1e-4
MAX_EPOCHS = 200
EARLY_STOPPING_PATIENCE = 30


BEST_MODEL_PATH = OUTPUT_DIR / "best_custom_cnn.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.csv"


model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.TopKCategoricalAccuracy(
            k=2,
            name="top2_accuracy",
        ),
    ],
)


callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_MODEL_PATH),
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        verbose=1,
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.CSVLogger(
        str(HISTORY_PATH)
    ),
]


print("Learning rate:", LEARNING_RATE)
print("Maximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", EARLY_STOPPING_PATIENCE)
print("Total parameters:", model.count_params())
print("Best model:", BEST_MODEL_PATH)
print("History:", HISTORY_PATH)
# Out:
# Learning rate: 0.0001
# Maximum epochs: 200
# Early-stopping patience: 30
# Total parameters: 263267
# Best model: /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# History: /kaggle/working/custom_cnn_clean_split_nearest_seed12345/training_history.csv

# %%
train_generator.reset()
val_generator.reset()


training_started = time.time()


history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=MAX_EPOCHS,
    callbacks=callbacks,
    verbose=2,
)


training_seconds = time.time() - training_started
training_hours = training_seconds / 3600


history_df = pd.DataFrame(history.history)

history_df.insert(
    0,
    "epoch",
    np.arange(1, len(history_df) + 1),
)

history_df.to_csv(
    HISTORY_PATH,
    index=False,
)


best_epoch = int(
    history_df.loc[
        history_df["val_loss"].idxmin(),
        "epoch",
    ]
)

best_val_loss = float(
    history_df["val_loss"].min()
)


training_info = {
    "epochs_completed": len(history_df),
    "best_epoch": best_epoch,
    "best_validation_loss": best_val_loss,
    "training_seconds": training_seconds,
    "training_hours": training_hours,
}

with open(
    OUTPUT_DIR / "training_info.json",
    "w",
) as file:
    json.dump(
        training_info,
        file,
        indent=2,
    )


print("\nTraining completed.")
print("Epochs completed:", len(history_df))
print("Best epoch:", best_epoch)
print("Best validation loss:", best_val_loss)
print("Training hours:", training_hours)
# Out:
# Epoch 1/200
# I0000 00:00:1787048812.726608      68 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from None to 3.96697, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 1: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 110s - 279ms/step - accuracy: 0.3150 - loss: 2.6906 - top2_accuracy: 0.4275 - val_accuracy: 0.0613 - val_loss: 3.9670 - val_top2_accuracy: 0.2430
# Epoch 2/200
#
# Epoch 2: val_loss improved from 3.96697 to 1.72385, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 2: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 66s - 169ms/step - accuracy: 0.4658 - loss: 2.0084 - top2_accuracy: 0.6118 - val_accuracy: 0.5437 - val_loss: 1.7238 - val_top2_accuracy: 0.6860
# Epoch 3/200
#
# Epoch 3: val_loss improved from 1.72385 to 1.43737, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 3: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 66s - 168ms/step - accuracy: 0.5387 - loss: 1.7019 - top2_accuracy: 0.6886 - val_accuracy: 0.5671 - val_loss: 1.4374 - val_top2_accuracy: 0.7384
# Epoch 4/200
#
# Epoch 4: val_loss improved from 1.43737 to 1.32855, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 4: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 65s - 166ms/step - accuracy: 0.5871 - loss: 1.5113 - top2_accuracy: 0.7285 - val_accuracy: 0.6388 - val_loss: 1.3285 - val_top2_accuracy: 0.7819
# Epoch 5/200
#
# Epoch 5: val_loss improved from 1.32855 to 1.27369, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 5: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 63s - 161ms/step - accuracy: 0.6335 - loss: 1.3706 - top2_accuracy: 0.7667 - val_accuracy: 0.6269 - val_loss: 1.2737 - val_top2_accuracy: 0.7975
# Epoch 6/200
#
# Epoch 6: val_loss did not improve from 1.27369
# 393/393 - 61s - 156ms/step - accuracy: 0.6602 - loss: 1.2610 - top2_accuracy: 0.7855 - val_accuracy: 0.5923 - val_loss: 1.3594 - val_top2_accuracy: 0.7834
# Epoch 7/200
#
# Epoch 7: val_loss improved from 1.27369 to 1.11557, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 7: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 61s - 156ms/step - accuracy: 0.6797 - loss: 1.1803 - top2_accuracy: 0.8055 - val_accuracy: 0.6774 - val_loss: 1.1156 - val_top2_accuracy: 0.8291
# Epoch 8/200
#
# Epoch 8: val_loss did not improve from 1.11557
# 393/393 - 62s - 159ms/step - accuracy: 0.6972 - loss: 1.1184 - top2_accuracy: 0.8141 - val_accuracy: 0.6551 - val_loss: 1.1638 - val_top2_accuracy: 0.8004
# Epoch 9/200
#
# Epoch 9: val_loss improved from 1.11557 to 0.88547, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 9: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 61s - 155ms/step - accuracy: 0.7105 - loss: 1.0525 - top2_accuracy: 0.8323 - val_accuracy: 0.7443 - val_loss: 0.8855 - val_top2_accuracy: 0.8651
# Epoch 10/200
#
# Epoch 10: val_loss did not improve from 0.88547
# 393/393 - 62s - 157ms/step - accuracy: 0.7241 - loss: 1.0046 - top2_accuracy: 0.8364 - val_accuracy: 0.6849 - val_loss: 1.0786 - val_top2_accuracy: 0.8320
# Epoch 11/200
#
# Epoch 11: val_loss did not improve from 0.88547
# 393/393 - 62s - 159ms/step - accuracy: 0.7344 - loss: 0.9612 - top2_accuracy: 0.8456 - val_accuracy: 0.6975 - val_loss: 1.0241 - val_top2_accuracy: 0.8335
# Epoch 12/200
#
# Epoch 12: val_loss did not improve from 0.88547
# 393/393 - 62s - 159ms/step - accuracy: 0.7424 - loss: 0.9311 - top2_accuracy: 0.8508 - val_accuracy: 0.6336 - val_loss: 1.2413 - val_top2_accuracy: 0.7629
# Epoch 13/200
#
# Epoch 13: val_loss did not improve from 0.88547
# 393/393 - 62s - 157ms/step - accuracy: 0.7524 - loss: 0.8896 - top2_accuracy: 0.8599 - val_accuracy: 0.7343 - val_loss: 0.9157 - val_top2_accuracy: 0.8592
# Epoch 14/200
#
# Epoch 14: val_loss did not improve from 0.88547
# 393/393 - 63s - 160ms/step - accuracy: 0.7646 - loss: 0.8543 - top2_accuracy: 0.8623 - val_accuracy: 0.6611 - val_loss: 1.1713 - val_top2_accuracy: 0.8153
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.88547 to 0.73384, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 15: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 64s - 163ms/step - accuracy: 0.7623 - loss: 0.8424 - top2_accuracy: 0.8645 - val_accuracy: 0.7808 - val_loss: 0.7338 - val_top2_accuracy: 0.8874
# Epoch 16/200
#
# Epoch 16: val_loss did not improve from 0.73384
# 393/393 - 63s - 160ms/step - accuracy: 0.7729 - loss: 0.8144 - top2_accuracy: 0.8705 - val_accuracy: 0.6990 - val_loss: 0.9639 - val_top2_accuracy: 0.8410
# Epoch 17/200
#
# Epoch 17: val_loss did not improve from 0.73384
# 393/393 - 62s - 157ms/step - accuracy: 0.7820 - loss: 0.7867 - top2_accuracy: 0.8810 - val_accuracy: 0.6823 - val_loss: 1.1103 - val_top2_accuracy: 0.8142
# Epoch 18/200
#
# Epoch 18: val_loss did not improve from 0.73384
# 393/393 - 64s - 162ms/step - accuracy: 0.7867 - loss: 0.7639 - top2_accuracy: 0.8849 - val_accuracy: 0.7235 - val_loss: 0.8853 - val_top2_accuracy: 0.8491
# Epoch 19/200
#
# Epoch 19: val_loss did not improve from 0.73384
# 393/393 - 63s - 159ms/step - accuracy: 0.7866 - loss: 0.7597 - top2_accuracy: 0.8829 - val_accuracy: 0.7592 - val_loss: 0.7785 - val_top2_accuracy: 0.8766
# Epoch 20/200
#
# Epoch 20: val_loss did not improve from 0.73384
# 393/393 - 62s - 159ms/step - accuracy: 0.7958 - loss: 0.7295 - top2_accuracy: 0.8902 - val_accuracy: 0.7655 - val_loss: 0.8130 - val_top2_accuracy: 0.8755
# Epoch 21/200
#
# Epoch 21: val_loss improved from 0.73384 to 0.63291, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 21: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 61s - 156ms/step - accuracy: 0.7965 - loss: 0.7146 - top2_accuracy: 0.8914 - val_accuracy: 0.8109 - val_loss: 0.6329 - val_top2_accuracy: 0.9097
# Epoch 22/200
#
# Epoch 22: val_loss did not improve from 0.63291
# 393/393 - 63s - 160ms/step - accuracy: 0.8020 - loss: 0.6999 - top2_accuracy: 0.8923 - val_accuracy: 0.5325 - val_loss: 1.8932 - val_top2_accuracy: 0.6574
# Epoch 23/200
#
# Epoch 23: val_loss did not improve from 0.63291
# 393/393 - 66s - 167ms/step - accuracy: 0.8058 - loss: 0.6846 - top2_accuracy: 0.8965 - val_accuracy: 0.7793 - val_loss: 0.7592 - val_top2_accuracy: 0.8915
# Epoch 24/200
#
# Epoch 24: val_loss did not improve from 0.63291
# 393/393 - 64s - 163ms/step - accuracy: 0.8142 - loss: 0.6643 - top2_accuracy: 0.9024 - val_accuracy: 0.7700 - val_loss: 0.7403 - val_top2_accuracy: 0.8893
# Epoch 25/200
#
# Epoch 25: val_loss did not improve from 0.63291
# 393/393 - 64s - 162ms/step - accuracy: 0.8127 - loss: 0.6668 - top2_accuracy: 0.8997 - val_accuracy: 0.7384 - val_loss: 0.8947 - val_top2_accuracy: 0.8521
# Epoch 26/200
#
# Epoch 26: val_loss did not improve from 0.63291
# 393/393 - 63s - 160ms/step - accuracy: 0.8161 - loss: 0.6483 - top2_accuracy: 0.9044 - val_accuracy: 0.7098 - val_loss: 0.9501 - val_top2_accuracy: 0.8313
# Epoch 27/200
#
# Epoch 27: val_loss did not improve from 0.63291
# 393/393 - 62s - 159ms/step - accuracy: 0.8207 - loss: 0.6354 - top2_accuracy: 0.9048 - val_accuracy: 0.6923 - val_loss: 0.9906 - val_top2_accuracy: 0.8105
# Epoch 28/200
#
# Epoch 28: val_loss did not improve from 0.63291
# 393/393 - 63s - 160ms/step - accuracy: 0.8180 - loss: 0.6378 - top2_accuracy: 0.9028 - val_accuracy: 0.6986 - val_loss: 0.9932 - val_top2_accuracy: 0.8116
# Epoch 29/200
#
# Epoch 29: val_loss did not improve from 0.63291
# 393/393 - 63s - 160ms/step - accuracy: 0.8223 - loss: 0.6211 - top2_accuracy: 0.9099 - val_accuracy: 0.7785 - val_loss: 0.7245 - val_top2_accuracy: 0.8974
# Epoch 30/200
#
# Epoch 30: val_loss did not improve from 0.63291
# 393/393 - 62s - 158ms/step - accuracy: 0.8271 - loss: 0.6039 - top2_accuracy: 0.9100 - val_accuracy: 0.7860 - val_loss: 0.7086 - val_top2_accuracy: 0.8963
# Epoch 31/200
#
# Epoch 31: val_loss did not improve from 0.63291
# 393/393 - 63s - 161ms/step - accuracy: 0.8324 - loss: 0.5923 - top2_accuracy: 0.9132 - val_accuracy: 0.7191 - val_loss: 0.8985 - val_top2_accuracy: 0.8562
# Epoch 32/200
#
# Epoch 32: val_loss improved from 0.63291 to 0.60067, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 32: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 63s - 162ms/step - accuracy: 0.8311 - loss: 0.5863 - top2_accuracy: 0.9164 - val_accuracy: 0.8168 - val_loss: 0.6007 - val_top2_accuracy: 0.9190
# Epoch 33/200
#
# Epoch 33: val_loss did not improve from 0.60067
# 393/393 - 62s - 157ms/step - accuracy: 0.8366 - loss: 0.5826 - top2_accuracy: 0.9173 - val_accuracy: 0.7518 - val_loss: 0.8190 - val_top2_accuracy: 0.8915
# Epoch 34/200
#
# Epoch 34: val_loss did not improve from 0.60067
# 393/393 - 63s - 159ms/step - accuracy: 0.8356 - loss: 0.5712 - top2_accuracy: 0.9177 - val_accuracy: 0.8135 - val_loss: 0.6179 - val_top2_accuracy: 0.9104
# Epoch 35/200
#
# Epoch 35: val_loss did not improve from 0.60067
# 393/393 - 62s - 159ms/step - accuracy: 0.8370 - loss: 0.5605 - top2_accuracy: 0.9202 - val_accuracy: 0.7837 - val_loss: 0.6676 - val_top2_accuracy: 0.8926
# Epoch 36/200
#
# Epoch 36: val_loss improved from 0.60067 to 0.58313, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 36: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 62s - 158ms/step - accuracy: 0.8421 - loss: 0.5549 - top2_accuracy: 0.9218 - val_accuracy: 0.8209 - val_loss: 0.5831 - val_top2_accuracy: 0.9160
# Epoch 37/200
#
# Epoch 37: val_loss did not improve from 0.58313
# 393/393 - 63s - 161ms/step - accuracy: 0.8471 - loss: 0.5404 - top2_accuracy: 0.9213 - val_accuracy: 0.8075 - val_loss: 0.6548 - val_top2_accuracy: 0.8937
# Epoch 38/200
#
# Epoch 38: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8429 - loss: 0.5458 - top2_accuracy: 0.9194 - val_accuracy: 0.7562 - val_loss: 0.8223 - val_top2_accuracy: 0.8826
# Epoch 39/200
#
# Epoch 39: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8503 - loss: 0.5366 - top2_accuracy: 0.9238 - val_accuracy: 0.7938 - val_loss: 0.6767 - val_top2_accuracy: 0.9097
# Epoch 40/200
#
# Epoch 40: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8504 - loss: 0.5236 - top2_accuracy: 0.9291 - val_accuracy: 0.7904 - val_loss: 0.6781 - val_top2_accuracy: 0.8952
# Epoch 41/200
#
# Epoch 41: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8470 - loss: 0.5183 - top2_accuracy: 0.9290 - val_accuracy: 0.7685 - val_loss: 0.7425 - val_top2_accuracy: 0.8844
# Epoch 42/200
#
# Epoch 42: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8494 - loss: 0.5198 - top2_accuracy: 0.9246 - val_accuracy: 0.7417 - val_loss: 0.8891 - val_top2_accuracy: 0.8510
# Epoch 43/200
#
# Epoch 43: val_loss did not improve from 0.58313
# 393/393 - 62s - 157ms/step - accuracy: 0.8508 - loss: 0.5163 - top2_accuracy: 0.9271 - val_accuracy: 0.8016 - val_loss: 0.6667 - val_top2_accuracy: 0.9078
# Epoch 44/200
#
# Epoch 44: val_loss did not improve from 0.58313
# 393/393 - 62s - 158ms/step - accuracy: 0.8583 - loss: 0.4908 - top2_accuracy: 0.9284 - val_accuracy: 0.7157 - val_loss: 0.9547 - val_top2_accuracy: 0.8324
# Epoch 45/200
#
# Epoch 45: val_loss did not improve from 0.58313
# 393/393 - 63s - 159ms/step - accuracy: 0.8548 - loss: 0.4942 - top2_accuracy: 0.9309 - val_accuracy: 0.7893 - val_loss: 0.6960 - val_top2_accuracy: 0.8893
# Epoch 46/200
#
# Epoch 46: val_loss improved from 0.58313 to 0.46370, saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
#
# Epoch 46: finished saving model to /kaggle/working/custom_cnn_clean_split_nearest_seed12345/best_custom_cnn.keras
# 393/393 - 62s - 158ms/step - accuracy: 0.8560 - loss: 0.4963 - top2_accuracy: 0.9311 - val_accuracy: 0.8599 - val_loss: 0.4637 - val_top2_accuracy: 0.9365
# Epoch 47/200
#
# Epoch 47: val_loss did not improve from 0.46370
# 393/393 - 62s - 157ms/step - accuracy: 0.8587 - loss: 0.4870 - top2_accuracy: 0.9314 - val_accuracy: 0.8116 - val_loss: 0.6145 - val_top2_accuracy: 0.9086
# Epoch 48/200
#
# Epoch 48: val_loss did not improve from 0.46370
# 393/393 - 62s - 157ms/step - accuracy: 0.8588 - loss: 0.4824 - top2_accuracy: 0.9326 - val_accuracy: 0.7703 - val_loss: 0.7525 - val_top2_accuracy: 0.8833
# Epoch 49/200
#
# Epoch 49: val_loss did not improve from 0.46370
# 393/393 - 63s - 159ms/step - accuracy: 0.8615 - loss: 0.4774 - top2_accuracy: 0.9327 - val_accuracy: 0.7744 - val_loss: 0.7477 - val_top2_accuracy: 0.8811
# Epoch 50/200
#
# Epoch 50: val_loss did not improve from 0.46370
# 393/393 - 67s - 171ms/step - accuracy: 0.8615 - loss: 0.4757 - top2_accuracy: 0.9330 - val_accuracy: 0.6544 - val_loss: 1.1742 - val_top2_accuracy: 0.7886
# Epoch 51/200
#
# Epoch 51: val_loss did not improve from 0.46370
# 393/393 - 64s - 163ms/step - accuracy: 0.8653 - loss: 0.4604 - top2_accuracy: 0.9359 - val_accuracy: 0.7715 - val_loss: 0.7334 - val_top2_accuracy: 0.8759
# Epoch 52/200
#
# Epoch 52: val_loss did not improve from 0.46370
# 393/393 - 63s - 161ms/step - accuracy: 0.8663 - loss: 0.4585 - top2_accuracy: 0.9374 - val_accuracy: 0.7867 - val_loss: 0.6879 - val_top2_accuracy: 0.8885
# Epoch 53/200
#
# Epoch 53: val_loss did not improve from 0.46370
# 393/393 - 65s - 165ms/step - accuracy: 0.8644 - loss: 0.4578 - top2_accuracy: 0.9376 - val_accuracy: 0.8086 - val_loss: 0.6124 - val_top2_accuracy: 0.9026
# Epoch 54/200
#
# Epoch 54: val_loss did not improve from 0.46370
# 393/393 - 65s - 165ms/step - accuracy: 0.8653 - loss: 0.4646 - top2_accuracy: 0.9356 - val_accuracy: 0.8071 - val_loss: 0.6129 - val_top2_accuracy: 0.9127
# Epoch 55/200
#
# Epoch 55: val_loss did not improve from 0.46370
# 393/393 - 66s - 167ms/step - accuracy: 0.8666 - loss: 0.4531 - top2_accuracy: 0.9349 - val_accuracy: 0.7540 - val_loss: 0.8403 - val_top2_accuracy: 0.8789
# Epoch 56/200
#
# Epoch 56: val_loss did not improve from 0.46370
# 393/393 - 65s - 166ms/step - accuracy: 0.8705 - loss: 0.4415 - top2_accuracy: 0.9408 - val_accuracy: 0.8239 - val_loss: 0.5509 - val_top2_accuracy: 0.9194
# Epoch 57/200
#
# Epoch 57: val_loss did not improve from 0.46370
# 393/393 - 64s - 163ms/step - accuracy: 0.8673 - loss: 0.4447 - top2_accuracy: 0.9383 - val_accuracy: 0.7785 - val_loss: 0.7241 - val_top2_accuracy: 0.8952
# Epoch 58/200
#
# Epoch 58: val_loss did not improve from 0.46370
# 393/393 - 64s - 163ms/step - accuracy: 0.8675 - loss: 0.4437 - top2_accuracy: 0.9384 - val_accuracy: 0.7926 - val_loss: 0.7388 - val_top2_accuracy: 0.8859
# Epoch 59/200
#
# Epoch 59: val_loss did not improve from 0.46370
# 393/393 - 63s - 160ms/step - accuracy: 0.8693 - loss: 0.4364 - top2_accuracy: 0.9390 - val_accuracy: 0.8569 - val_loss: 0.4841 - val_top2_accuracy: 0.9372
# Epoch 60/200
#
# Epoch 60: val_loss did not improve from 0.46370
# 393/393 - 64s - 162ms/step - accuracy: 0.8677 - loss: 0.4375 - top2_accuracy: 0.9402 - val_accuracy: 0.7596 - val_loss: 0.8443 - val_top2_accuracy: 0.8692
# Epoch 61/200
#
# Epoch 61: val_loss did not improve from 0.46370
# 393/393 - 64s - 164ms/step - accuracy: 0.8723 - loss: 0.4307 - top2_accuracy: 0.9425 - val_accuracy: 0.7570 - val_loss: 0.8152 - val_top2_accuracy: 0.8606
# Epoch 62/200
#
# Epoch 62: val_loss did not improve from 0.46370
# 393/393 - 65s - 165ms/step - accuracy: 0.8713 - loss: 0.4279 - top2_accuracy: 0.9433 - val_accuracy: 0.8309 - val_loss: 0.5471 - val_top2_accuracy: 0.9179
# Epoch 63/200
#
# Epoch 63: val_loss did not improve from 0.46370
# 393/393 - 64s - 164ms/step - accuracy: 0.8752 - loss: 0.4301 - top2_accuracy: 0.9406 - val_accuracy: 0.8205 - val_loss: 0.5879 - val_top2_accuracy: 0.9242
# Epoch 64/200
#
# Epoch 64: val_loss did not improve from 0.46370
# 393/393 - 65s - 164ms/step - accuracy: 0.8706 - loss: 0.4245 - top2_accuracy: 0.9392 - val_accuracy: 0.7228 - val_loss: 0.9160 - val_top2_accuracy: 0.8484
# Epoch 65/200
#
# Epoch 65: val_loss did not improve from 0.46370
# 393/393 - 64s - 163ms/step - accuracy: 0.8762 - loss: 0.4186 - top2_accuracy: 0.9422 - val_accuracy: 0.8201 - val_loss: 0.5922 - val_top2_accuracy: 0.9179
# Epoch 66/200
#
# Epoch 66: val_loss did not improve from 0.46370
# 393/393 - 64s - 163ms/step - accuracy: 0.8764 - loss: 0.4166 - top2_accuracy: 0.9415 - val_accuracy: 0.7599 - val_loss: 0.8334 - val_top2_accuracy: 0.8785
# Epoch 67/200
#
# Epoch 67: val_loss did not improve from 0.46370
# 393/393 - 62s - 159ms/step - accuracy: 0.8797 - loss: 0.4063 - top2_accuracy: 0.9459 - val_accuracy: 0.7882 - val_loss: 0.7047 - val_top2_accuracy: 0.8930
# Epoch 68/200
#
# Epoch 68: val_loss did not improve from 0.46370
# 393/393 - 62s - 158ms/step - accuracy: 0.8779 - loss: 0.4077 - top2_accuracy: 0.9458 - val_accuracy: 0.8209 - val_loss: 0.5591 - val_top2_accuracy: 0.9142
# Epoch 69/200
#
# Epoch 69: val_loss did not improve from 0.46370
# 393/393 - 63s - 160ms/step - accuracy: 0.8806 - loss: 0.4029 - top2_accuracy: 0.9446 - val_accuracy: 0.8357 - val_loss: 0.5409 - val_top2_accuracy: 0.9231
# Epoch 70/200
#
# Epoch 70: val_loss did not improve from 0.46370
# 393/393 - 64s - 162ms/step - accuracy: 0.8806 - loss: 0.3972 - top2_accuracy: 0.9474 - val_accuracy: 0.8075 - val_loss: 0.6118 - val_top2_accuracy: 0.9123
# Epoch 71/200
#
# Epoch 71: val_loss did not improve from 0.46370
# 393/393 - 62s - 159ms/step - accuracy: 0.8829 - loss: 0.3983 - top2_accuracy: 0.9431 - val_accuracy: 0.8580 - val_loss: 0.4673 - val_top2_accuracy: 0.9316
# Epoch 72/200
#
# Epoch 72: val_loss did not improve from 0.46370
# 393/393 - 62s - 158ms/step - accuracy: 0.8798 - loss: 0.4007 - top2_accuracy: 0.9472 - val_accuracy: 0.8525 - val_loss: 0.4722 - val_top2_accuracy: 0.9387
# Epoch 73/200
#
# Epoch 73: val_loss did not improve from 0.46370
# 393/393 - 62s - 158ms/step - accuracy: 0.8825 - loss: 0.3958 - top2_accuracy: 0.9474 - val_accuracy: 0.8272 - val_loss: 0.5857 - val_top2_accuracy: 0.9186
# Epoch 74/200
#
# Epoch 74: val_loss did not improve from 0.46370
# 393/393 - 63s - 159ms/step - accuracy: 0.8799 - loss: 0.3982 - top2_accuracy: 0.9494 - val_accuracy: 0.8250 - val_loss: 0.6081 - val_top2_accuracy: 0.9034
# Epoch 75/200
#
# Epoch 75: val_loss did not improve from 0.46370
# 393/393 - 62s - 159ms/step - accuracy: 0.8825 - loss: 0.3921 - top2_accuracy: 0.9470 - val_accuracy: 0.8458 - val_loss: 0.5099 - val_top2_accuracy: 0.9201
# Epoch 76/200
#
# Epoch 76: val_loss did not improve from 0.46370
# 393/393 - 62s - 159ms/step - accuracy: 0.8839 - loss: 0.3914 - top2_accuracy: 0.9480 - val_accuracy: 0.8580 - val_loss: 0.4726 - val_top2_accuracy: 0.9331
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 46.
#
# Training completed.
# Epochs completed: 76
# Best epoch: 46
# Best validation loss: 0.46369630098342896
# Training hours: 1.3448372244172626

# %%
fig, axes = plt.subplots(
    1,
    3,
    figsize=(18, 5),
)


axes[0].plot(
    history_df["epoch"],
    history_df["accuracy"],
    label="Training",
)

axes[0].plot(
    history_df["epoch"],
    history_df["val_accuracy"],
    label="Validation",
)

axes[0].set_title("Accuracy")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].grid(alpha=0.3)
axes[0].legend()


axes[1].plot(
    history_df["epoch"],
    history_df["loss"],
    label="Training",
)

axes[1].plot(
    history_df["epoch"],
    history_df["val_loss"],
    label="Validation",
)

axes[1].axvline(
    best_epoch,
    color="red",
    linestyle="--",
    label=f"Best epoch: {best_epoch}",
)

axes[1].set_title("Loss")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].grid(alpha=0.3)
axes[1].legend()


axes[2].plot(
    history_df["epoch"],
    history_df["top2_accuracy"],
    label="Training",
)

axes[2].plot(
    history_df["epoch"],
    history_df["val_top2_accuracy"],
    label="Validation",
)

axes[2].set_title("Top-2 Accuracy")
axes[2].set_xlabel("Epoch")
axes[2].set_ylabel("Top-2 Accuracy")
axes[2].grid(alpha=0.3)
axes[2].legend()


plt.suptitle(
    "Custom CNN — Lanczos",
    fontsize=15,
)

plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "training_curves.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()
plt.close()

# %%
best_model = tf.keras.models.load_model(
    BEST_MODEL_PATH,
    compile=False,
)


test_generator = eval_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    classes=CLASS_NAMES,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    interpolation="nearest",
)


test_generator.reset()

y_prob = best_model.predict(
    test_generator,
    verbose=1,
)


y_true = np.asarray(
    test_generator.classes,
    dtype=np.int64,
)

y_pred = np.argmax(
    y_prob,
    axis=1,
)


test_loss = float(
    -np.mean(
        np.log(
            np.clip(
                y_prob[
                    np.arange(len(y_true)),
                    y_true,
                ],
                1e-7,
                1.0,
            )
        )
    )
)

test_accuracy = float(
    accuracy_score(
        y_true,
        y_pred,
    )
)

macro_precision = float(
    precision_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_recall = float(
    recall_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

macro_f1 = float(
    f1_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0,
    )
)

top2_predictions = np.argsort(
    y_prob,
    axis=1,
)[:, -2:]

top2_accuracy = float(
    np.mean(
        np.any(
            top2_predictions == y_true[:, None],
            axis=1,
        )
    )
)


metrics = {
    "model": "Custom CNN",
    "split": "test",
    "samples": len(y_true),
    "loss": test_loss,
    "accuracy": test_accuracy,
    "macro_precision": macro_precision,
    "macro_recall": macro_recall,
    "macro_f1": macro_f1,
    "top2_accuracy": top2_accuracy,
    "best_epoch": best_epoch,
    "seed": SEED,
}


with open(
    OUTPUT_DIR / "test_metrics.json",
    "w",
) as file:
    json.dump(
        metrics,
        file,
        indent=2,
    )


print("\nTEST RESULTS")

for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# Found 2691 validated image filenames belonging to 35 classes.
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step
#
# TEST RESULTS
# model: Custom CNN
# split: test
# samples: 2691
# loss: 0.426957368850708
# accuracy: 0.8684503901895206
# macro_precision: 0.6272562017405309
# macro_recall: 0.5666855268635947
# macro_f1: 0.5705442721549261
# top2_accuracy: 0.9472315124489038
# best_epoch: 46
# seed: 12345

# %%
classification_results = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=CLASS_NAMES,
    output_dict=True,
    zero_division=0,
)


classification_df = (
    pd.DataFrame(classification_results)
    .transpose()
)

classification_df.to_csv(
    OUTPUT_DIR / "classification_report.csv"
)


predictions_df = pd.DataFrame({
    "image_name": [
        Path(path).name
        for path in test_generator.filepaths
    ],
    "true_class": [
        CLASS_NAMES[index]
        for index in y_true
    ],
    "predicted_class": [
        CLASS_NAMES[index]
        for index in y_pred
    ],
    "confidence": np.max(
        y_prob,
        axis=1,
    ),
    "correct": y_true == y_pred,
})


predictions_df.to_csv(
    OUTPUT_DIR / "test_predictions.csv",
    index=False,
)


np.savez_compressed(
    OUTPUT_DIR / "predictions.npz",
    y_true=y_true,
    y_pred=y_pred,
    y_prob=y_prob.astype(np.float32),
    class_names=np.asarray(CLASS_NAMES),
    image_names=np.asarray(
        [
            Path(path).name
            for path in test_generator.filepaths
        ]
    ),
)


print("Classification report saved.")
print("Test predictions saved.")
print("Prediction arrays saved.")
# Out:
# Classification report saved.
# Test predictions saved.
# Prediction arrays saved.

# %%
cm = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
)


cm_normalized = (
    cm.astype(float)
    / np.maximum(
        cm.sum(axis=1, keepdims=True),
        1,
    )
)


support = cm.sum(axis=1)

sort_order = np.argsort(
    support
)[::-1]


cm_sorted = cm[
    sort_order
][:, sort_order]

cm_normalized_sorted = cm_normalized[
    sort_order
][:, sort_order]


class_names_sorted = [
    CLASS_NAMES[index]
    for index in sort_order
]

support_sorted = support[
    sort_order
]


class_labels_with_support = [
    f"{name} ({int(class_support)})"
    for name, class_support in zip(
        class_names_sorted,
        support_sorted,
    )
]


pd.DataFrame(
    cm_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_counts.csv"
)


pd.DataFrame(
    cm_normalized_sorted,
    index=class_labels_with_support,
    columns=class_names_sorted,
).to_csv(
    OUTPUT_DIR / "confusion_matrix_normalized.csv"
)


figure_size = max(
    12,
    0.38 * NUM_CLASSES,
)

plt.figure(
    figsize=(
        figure_size,
        figure_size,
    )
)


image = plt.imshow(
    cm_normalized_sorted,
    interpolation="nearest",
    cmap="Blues",
    vmin=0,
    vmax=1,
)


plt.colorbar(
    image,
    fraction=0.046,
    pad=0.04,
    label="Normalized count",
)


tick_positions = np.arange(
    NUM_CLASSES
)


plt.xticks(
    tick_positions,
    class_names_sorted,
    rotation=90,
    fontsize=7,
)

plt.yticks(
    tick_positions,
    class_labels_with_support,
    fontsize=7,
)


plt.title(
    "Custom CNN - Normalized Confusion Matrix"
)

plt.xlabel(
    "Predicted class"
)

plt.ylabel(
    "True class"
)


for row in range(NUM_CLASSES):
    for column in range(NUM_CLASSES):

        value = cm_normalized_sorted[
            row,
            column,
        ]

        if row == column or value >= 0.05:

            text_color = (
                "white"
                if value >= 0.50
                else "black"
            )

            plt.text(
                column,
                row,
                f"{value:.2f}",
                ha="center",
                va="center",
                color=text_color,
                fontsize=5,
            )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "confusion_matrix_normalized.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
per_class_df = (
    classification_df
    .loc[CLASS_NAMES]
    .reset_index()
    .rename(
        columns={
            "index": "class",
            "f1-score": "f1_score",
        }
    )
)


per_class_df = per_class_df.sort_values(
    "support",
    ascending=False,
)


per_class_df.to_csv(
    OUTPUT_DIR / "per_class_metrics.csv",
    index=False,
)


per_class_df["class_with_support"] = (
    per_class_df.apply(
        lambda row: (
            f"{row['class']} "
            f"({int(row['support'])})"
        ),
        axis=1,
    )
)


heatmap_data = per_class_df.set_index(
    "class_with_support"
)[
    [
        "precision",
        "recall",
        "f1_score",
    ]
]


figure_height = max(
    8,
    0.35 * len(heatmap_data),
)


plt.figure(
    figsize=(
        8,
        figure_height,
    )
)


image = plt.imshow(
    heatmap_data.values,
    aspect="auto",
    vmin=0,
    vmax=1,
    cmap="RdBu",
)


plt.colorbar(
    image,
    label="Score",
)


plt.xticks(
    np.arange(3),
    [
        "Precision",
        "Recall",
        "F1-score",
    ],
)


plt.yticks(
    np.arange(
        len(heatmap_data)
    ),
    heatmap_data.index,
)


plt.title(
    "Custom CNN - Per-Class Metrics"
)

plt.xlabel(
    "Metric"
)

plt.ylabel(
    "Class"
)


for row in range(
    len(heatmap_data)
):
    for column in range(3):

        value = heatmap_data.values[
            row,
            column,
        ]

        text_color = (
            "white"
            if value >= 0.75
            else "black"
        )

        plt.text(
            column,
            row,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontsize=8,
        )


plt.tight_layout()

plt.savefig(
    OUTPUT_DIR / "per_class_metrics.png",
    dpi=300,
    bbox_inches="tight",
)

plt.show()

# %%
run_config = {
    "run_name": RUN_NAME,
    "model": "Custom CNN",
    "training_type": "from scratch",
    "seed": SEED,
    "image_size": list(IMAGE_SIZE),
    "batch_size": BATCH_SIZE,
    "classes": NUM_CLASSES,
    "train_samples": len(train_df),
    "validation_samples": len(val_df),
    "test_samples": len(test_df),
    "learning_rate": LEARNING_RATE,
    "maximum_epochs": MAX_EPOCHS,
    "early_stopping_patience": EARLY_STOPPING_PATIENCE,
    "checkpoint_monitor": "val_loss",
    "loss": "categorical_crossentropy",
    "sampling": "natural",
    "class_weights": None,
    "augmentation": {
        "rotation_range": 180,
        "horizontal_flip": True,
        "vertical_flip": True,
        "zoom_range": 0.20,
        "shear_range": 10,
    },
}


with open(
    OUTPUT_DIR / "run_config.json",
    "w",
) as file:
    json.dump(
        run_config,
        file,
        indent=2,
    )


pd.DataFrame(
    [metrics]
).to_csv(
    OUTPUT_DIR / "summary_metrics.csv",
    index=False,
)


with open(
    OUTPUT_DIR / "model_summary.txt",
    "w",
) as file:

    best_model.summary(
        print_fn=lambda line: file.write(
            line + "\n"
        )
    )


ARCHIVE_PATH = (
    Path("/kaggle/working")
    / f"{RUN_NAME}_results.zip"
)


with zipfile.ZipFile(
    ARCHIVE_PATH,
    "w",
    compression=zipfile.ZIP_DEFLATED,
) as archive:

    for path in sorted(
        OUTPUT_DIR.rglob("*")
    ):
        if path.is_file():

            archive.write(
                path,
                arcname=path.relative_to(
                    OUTPUT_DIR
                ),
            )


print("Final results archive:")
print(ARCHIVE_PATH)

print("\nFiles included:")

for path in sorted(
    OUTPUT_DIR.rglob("*")
):
    if path.is_file():
        print(" -", path.name)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final results archive:
# /kaggle/working/custom_cnn_clean_split_nearest_seed12345_results.zip
#
# Files included:
#  - best_custom_cnn.keras
#  - classification_report.csv
#  - confusion_matrix_counts.csv
#  - confusion_matrix_normalized.csv
#  - confusion_matrix_normalized.png
#  - model_summary.txt
#  - per_class_metrics.csv
#  - per_class_metrics.png
#  - predictions.npz
#  - run_config.json
#  - summary_metrics.csv
#  - test_metrics.json
#  - test_predictions.csv
#  - training_curves.png
#  - training_history.csv
#  - training_info.json
